# %% [markdown]
# # Data Analyst Job Postings Analysis

# %% [markdown]
# ## Import Needed Libraries

# %%
#import needed libraries
from bs4 import BeautifulSoup
import requests
import pandas as pd 
import urllib.parse 
import matplotlib.pyplot as plt
import seaborn as sb

from matplotlib import style
# %matplotlib inline

# %% [markdown]
# ## Extract Webpage Content

# %%
#store website into a variable
website = 'https://ai-jobs.net/analyst-jobs/'

# %%
#make request to the website specified above
response = requests.get(website)

# %%
#confirm if the request made was successful
response.status_code
# Out:
# 200

# %%
#create a soup object to get access to the html content of the website
soup = BeautifulSoup(response.content, 'html.parser')

# %%
# view soup content
soup
# Out:
# <!DOCTYPE html>
#
# <html class="h-100" lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>
# <meta content="max-snippet:-1, max-image-preview:large, max-video-preview:-1" name="robots">
# <meta content="Jobs in AI/ML and Big Data - find open Analyst roles." name="description"/>
# <title>Find Analyst Jobs | ai-jobs.net</title>
# <link href="/static/css/style_ai.min.css?v=1.4.1" rel="stylesheet"/>
# <link href="/static/fa/css/all.min.css?v=5.13.0" rel="stylesheet"/>
# <link href="https://ai-jobs.net/analyst-jobs/" rel="canonical"/>
# <link href="https://insights.ai-jobs.net" rel="dns-prefetch"/>
# <link href="https://salaries.ai-jobs.net" rel="dns-prefetch"/>
# <link href="https://ai-jobs.net/feed/" rel="alternate" title="ai-jobs.net - Job feed" type="application/rss+xml"/>
# <link href="/static/img/favicons_ai/apple-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/>
# <link href="/static/img/favicons_ai/apple-icon-60x60.png" rel="apple-touch-icon" sizes="60x60"/>
# <link href="/static/img/favicons_ai/apple-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/>
# <link href="/static/img/favicons_ai/apple-icon-76x76.png" rel="apple-touch-icon" sizes="76x76"/>
# <link href="/static/img/favicons_ai/apple-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/>
# <link href="/static/img/favicons_ai/apple-icon-120x120.png" rel="apple-touch-icon" sizes="120x120"/>
# <link href="/static/img/favicons_ai/apple-icon-144x144.png" rel="apple-touch-icon" sizes="144x144"/>
# <link href="/static/img/favicons_ai/apple-icon-152x152.png" rel="apple-touch-icon" sizes="152x152"/>
# <link href="/static/img/favicons_ai/apple-icon-180x180.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="/static/img/favicons_ai/android-icon-192x192.png" rel="icon" sizes="192x192" type="image/png"/>
# <link href="/static/img/favicons_ai/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="/static/img/favicons_ai/favicon-96x96.png" rel="icon" sizes="96x96" type="image/png"/>
# <link href="/static/img/favicons_ai/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
# <link href="/manifest.json" rel="manifest"/>
# <meta content="yes" name="mobile-web-app-capable"/>
# <meta content="yes" name="apple-mobile-web-app-capable"/>
# <meta content="#ffffff" name="msapplication-TileColor"/>
# <meta content="/static/img/favicons_ai/ms-icon-144x144.png" name="msapplication-TileImage"/>
# <meta content="/static/img/favicons_ai/browserconfig.xml" name="msapplication-config"/>
# <meta content="#ffffff" name="theme-color"/>
# <meta content="en_US" property="og:locale"/>
# <meta content="website" property="og:type"/>
# <meta content="ai-jobs.net - Jobs in AI and Big Data" property="og:title"/>
# <meta content="Your gateway to awesome jobs and talents in AI, ML, Data Science and Big Data." property="og:description"/>
# <meta content="https://ai-jobs.net/analyst-jobs/" property="og:url"/>
# <meta content="ai-jobs.net" property="og:site_name"/>
# <meta content="https://ai-jobs.net/static/img/ai-jobs.jpg" property="og:image"/>
# <meta content="https://ai-jobs.net/static/img/ai-jobs.jpg" property="og:image:secure_url"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="Your gateway to awesome jobs and talents in AI, ML, Data Science and Big Data." name="twitter:description"/>
# <meta content="ai-jobs.net - Jobs in AI and Big Data" name="twitter:title"/>
# <meta content="@ai_jobsNET" name="twitter:site"/>
# <meta content="@ai_jobsNET" name="twitter:creator"/>
# <meta content="https://ai-jobs.net/static/img/ai-jobs.jpg" name="twitter:image"/>
# <style>
#   body { font-size: .975rem; }
#   main { min-height: 50rem; }
#   .display-4 { font-size: 3rem; }
#   footer h3 { color: #FCFCFC !important; }
#   footer a { font-weight: normal; }
#   .lead { font-weight: 400; }
#   .badge { font-weight: 500; }
#   .list-group-flush .list-group-item:first-child { border-top-width: 1px; }
#   .dropdown-toggle { padding: .3rem; }
#   .select2-container--default .select2-selection--multiple { border: 1px solid #ced4da !important; }
#   .jumbotron.jumbotron-fluid { color: white; background: #360033; background: -webkit-linear-gradient(to right, #0b8793, #360033); background: linear-gradient(to right, #0b8793, #360033); }
#
#   a { color: #325D88; font-weight: 400; }
#   .btn-link { color: #325D88; font-weight: 400; }
#   footer .text-muted { color: #aaa !important; }
#   .dropdown-divider { border-top: 1px solid #ddd; }
#   .list-group-flush .list-group-item { border-color: #eee; }
#
# </style>
# <script src="/static/js/jquery.min.js?v=3.6.0"></script>
# <script async="" src="/static/js/bootstrap.bundle.min.js"></script>
# <link href="/static/css/select2.min.css" media="screen" rel="stylesheet"/>
# <link href="/static/django_select2/django_select2.css" media="screen" rel="stylesheet"/>
# <style>
#   .custom-control.custom-checkbox.custom-control-inline { width: 6.1rem; margin: .4rem .8rem .4rem 0; }
#   #div_id_filter_types { margin-bottom: .6rem; }
# </style>
# <script>
#   var _paq = window._paq || [];
#   _paq.push(['setDoNotTrack', true]);
#   _paq.push(['trackPageView']);
#   _paq.push(['enableLinkTracking']);
#   (function() {
#       var u="https://stats.foorilla.com/";
#       _paq.push(['setTrackerUrl', u+'matomo.php']);
#       _paq.push(['setSiteId', '7']);
#       var d=document, g=d.createElement('script'), s=d.getElementsByTagName('script')[0];
#       g.type='text/javascript'; g.async=true; g.defer=true; g.src=u+'matomo.js'; s.parentNode.insertBefore(g,s);
#   })();
# </script>
# </meta></head>
# <body class="d-flex flex-column h-100 pt-5 mt-2">
# <header class="navbar navbar-expand-md navbar-light bg-white fixed-top border-0 px-md-2 shadow-sm">
# <div class="container-xl">
# <a class="navbar-brand" href="/">
# <img alt="ai-jobs.net logo" height="32" src="/static/img/ai-jobs-logo.png" width="32"/>
# <strong>ai-jobs.net</strong>
# </a>
# <button aria-controls="navbarResponsive" aria-expanded="false" aria-label="Toggle navigation" class="navbar-toggler border-0" data-target="#navbarResponsive" data-toggle="collapse" type="button">
# <span class="navbar-toggler-icon"></span>
# </button>
# <div class="collapse navbar-collapse" id="navbarResponsive">
# <ul class="navbar-nav ml-auto">
# <li class="nav-item">
# <a class="nav-link text-dark" href="/"><i class="fas fa-search"></i> Search<span class="d-md-none d-lg-inline"> jobs</span></a>
# </li>
# <li class="nav-item">
# <a class="nav-link text-dark" href="/job/emails/"><i class="far fa-envelope"></i> <span class="d-md-none d-lg-inline">Job </span>Emails</a>
# </li>
# <li class="nav-item">
# <a class="nav-link text-dark" href="/job/marks/"><i class="fas fa-list-ol"></i> Saved<span class="d-md-none d-lg-inline"> Jobs</span></a>
# </li>
# <li class="nav-item">
# <a class="nav-link text-dark" href="https://salaries.ai-jobs.net/"><i class="fas fa-dollar-sign"></i> Salaries</a>
# </li>
# <li class="nav-item">
# <a class="nav-link text-dark" href="https://insights.ai-jobs.net/"><i class="far fa-lightbulb"></i> Insights</a>
# </li>
# <li class="nav-item">
# <a class="btn btn-primary mx-1 d-none d-md-block" href="/post-a-job/">Post a Job</a>
# <a class="nav-link text-dark d-block d-md-none" href="/post-a-job/"><i class="fas fa-bullhorn"></i> Post a Job</a>
# </li>
# <li class="nav-item">
# <a class="btn btn-primary mx-1 d-none d-md-block" href="/register/">Sign up</a>
# <a class="nav-link text-dark d-block d-md-none" href="/register/"><i class="fas fa-user-plus"></i> Sign up</a>
# </li>
# <li class="nav-item">
# <a class="btn btn-outline-primary mx-1 d-none d-md-block" href="/accounts/login/">Log in</a>
# <a class="nav-link text-dark d-block d-md-none" href="/accounts/login/"><i class="fas fa-sign-in-alt"></i> Log in</a>
# </li>
# <li class="nav-item">
# <a class="nav-link text-dark" href="/dark/mode/" title="Switch to dark mode">
# <i class="fas fa-moon"></i> / <i class="fas fa-sun"></i>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </header>
# <main class="flex-shrink-0" id="content">
# <div class="container-xl pt-3">
# <div class="row">
# <div class="col-lg-10 mx-auto pl-2">
# <h1 class="py-2 d-md-block h5">
#   Your prime source for jobs in AI/ML and Big Data. 🧠🐱‍💻🤖🚗🚀
#   <strong>— Analyst Jobs worldwide <small><a href="/countries/">(or search by country📍)</a></small></strong>
# </h1>
# </div>
# </div>
# <div class="row">
# <div class="col-lg-10 mx-auto px-1">
# <ul class="nav nav-pills nav-fill" id="job-categories">
# <li class="nav-item">
# <a class="nav-link btn btn-outline-dark p-1 m-1" href="/" title="Show all jobs">All<span class="d-none d-sm-inline"> Jobs</span></a>
# </li>
# <li class="nav-item">
# <a class="nav-link btn btn-outline-dark p-1 m-1 active" href="/analyst-jobs/" title="Show Analyst Jobs">Analyst<span class="d-none d-sm-inline"> Jobs</span></a>
# </li>
# <li class="nav-item">
# <a class="nav-link btn btn-outline-dark p-1 m-1" href="/architecture-jobs/" title="Show Architecture Jobs">Architecture<span class="d-none d-sm-inline"> Jobs</span></a>
# </li>
# <li class="nav-item">
# <a class="nav-link btn btn-outline-dark p-1 m-1" href="/big-data-jobs/" title="Show Big Data Jobs">Big Data<span class="d-none d-sm-inline"> Jobs</span></a>
# </li>
# <li class="nav-item">
# <a class="nav-link btn btn-outline-dark p-1 m-1" href="/computer-vision-jobs/" title="Show Computer Vision Jobs">Computer Vision<span class="d-none d-sm-inline"> Jobs</span></a>
# </li>
# <li class="nav-item">
# <a class="nav-link btn btn-outline-dark p-1 m-1" href="/consulting-jobs/" title="Show Consulting Jobs">Consulting<span class="d-none d-sm-inline"> Jobs</span></a>
# </li>
# <li class="nav-item">
# <a class="nav-link btn btn-outline-dark p-1 m-1" href="/data-science-jobs/" title="Show Data Science Jobs">Data Science<span class="d-none d-sm-inline"> Jobs</span></a>
# </li>
# <li class="nav-item">
# <a class="nav-link btn btn-outline-dark p-1 m-1" href="/deep-learning-jobs/" title="Show Deep Learning Jobs">Deep Learning<span class="d-none d-sm-inline"> Jobs</span></a>
# </li>
# <li class="nav-item">
# <a class="nav-link btn btn-outline-dark p-1 m-1" href="/engineering-jobs/" title="Show Engineering Jobs">Engineering<span class="d-none d-sm-inline"> Jobs</span></a>
# </li>
# <li class="nav-item">
# <a class="nav-link btn btn-outline-dark p-1 m-1" href="/leadership-jobs/" title="Show Leadership Jobs">Leadership<span class="d-none d-sm-inline"> Jobs</span></a>
# </li>
# <li class="nav-item">
# <a class="nav-link btn btn-outline-dark p-1 m-1" href="/machine-learning-jobs/" title="Show Machine Learning Jobs">Machine Learning<span class="d-none d-sm-inline"> Jobs</span></a>
# </li>
# <li class="nav-item">
# <a class="nav-link btn btn-outline-dark p-1 m-1" href="/ml-ops-jobs/" title="Show ML Ops Jobs">ML Ops<span class="d-none d-sm-inline"> Jobs</span></a>
# </li>
# <li class="nav-item">
# <a class="nav-link btn btn-outline-dark p-1 m-1" href="/nlp-jobs/" title="Show NLP Jobs">NLP<span class="d-none d-sm-inline"> Jobs</span></a>
# </li>
# <li class="nav-item">
# <a class="nav-link btn btn-outline-dark p-1 m-1" href="/research-jobs/" title="Show Research Jobs">Research<span class="d-none d-sm-inline"> Jobs</span></a>
# </li>
# </ul>
# </div>
# </div>
# <div class="row">
# <div class="col-lg-10 mx-auto px-2">
# <form class="pt-2" id="job-filter">
# <input name="csrfmiddlewaretoken" type="hidden" value="mseOkA4ghgW11XfKyiK6v38thK7ovXOcyTk8vQ52mOrWogc09DfJ7zovff2YO1OQ"/> <fieldset> <div class="form-row"> <div class="col"> <div class="form-group" id="div_id_search_keywords"> <div> <input class="textinput textInput form-control" id="id_search_keywords" maxlength="60" name="search_keywords" placeholder="Keywords" type="text"/> </div> </div> </div>
# <div class="col"> <div class="form-group" id="div_id_search_location"> <div> <input class="textinput textInput form-control" id="id_search_location" maxlength="60" name="search_location" placeholder="Location" type="text"/> </div> </div> </div>
# <div class="col-12 col-md-3"> <div class="form-group" id="div_id_filter_experience"> <div> <select class="select custom-select" id="id_filter_experience" name="filter_experience"> <option selected="" value="">All Experience Levels</option> <option value="EN">Entry-level / Junior</option> <option value="MI">Mid-level / Intermediate</option> <option value="SE">Senior-level / Expert</option> <option value="EX">Executive-level / Director</option>
# </select> </div> </div> </div>
# </div>
# <div class="form-row"> <div class="col-9 col-md-11"> <div class="form-group" id="div_id_filter_regions"> <div> <select class="select2multiplewidget custom-select django-select2" data-allow-clear="false" data-minimum-input-length="0" data-theme="default" id="id_filter_regions" lang="None" multiple="" name="filter_regions" required=""> <option value="7">Remote/Anywhere</option> <option value="1">Africa</option> <option value="2">Asia/Pacific</option> <option value="3">Europe</option> <option value="4">Middle East</option> <option value="5">North America</option> <option value="6">South America</option>
# </select> </div> </div> </div>
# <div class="col-3 col-md-1">
# <div class="dropdown"> <a aria-expanded="false" aria-haspopup="true" class="btn btn-outline-dark btn-block dropdown-toggle" data-toggle="dropdown" href="#" id="dropdownDisplaySettings" role="button" title="Edit display settings"> <i class="fas fa-cogs"></i> </a> <div aria-labelledby="dropdownDisplaySettings" class="dropdown-menu dropdown-menu-right"> <a class="dropdown-item display-setting" href="#" id="compact_mode"> <i class="fas fa-list"></i>
#       Compact mode: <strong>off</strong> </a> <a class="dropdown-item display-setting" href="#" id="open_new_tab"> <i class="fas fa-external-link-alt"></i>
#       Open in new tab: <strong>off</strong></a> </div>
# </div>
# </div>
# </div> <div class="form-group" id="div_id_filter_types"> <div> <div class="custom-control custom-checkbox custom-control-inline"> <input checked="" class="custom-control-input" id="id_filter_types_0" name="filter_types" type="checkbox" value="1"/> <label class="custom-control-label" for="id_filter_types_0">
#             Full Time
#         </label> </div> <div class="custom-control custom-checkbox custom-control-inline"> <input checked="" class="custom-control-input" id="id_filter_types_1" name="filter_types" type="checkbox" value="2"/> <label class="custom-control-label" for="id_filter_types_1">
#             Part Time
#         </label> </div> <div class="custom-control custom-checkbox custom-control-inline"> <input checked="" class="custom-control-input" id="id_filter_types_2" name="filter_types" type="checkbox" value="3"/> <label class="custom-control-label" for="id_filter_types_2">
#             Temporary
#         </label> </div> <div class="custom-control custom-checkbox custom-control-inline"> <input checked="" class="custom-control-input" id="id_filter_types_3" name="filter_types" type="checkbox" value="4"/> <label class="custom-control-label" for="id_filter_types_3">
#             Internship
#         </label> </div> <div class="custom-control custom-checkbox custom-control-inline"> <input checked="" class="custom-control-input" id="id_filter_types_4" name="filter_types" type="checkbox" value="5"/> <label class="custom-control-label" for="id_filter_types_4">
#             Freelance
#         </label> </div> <div class="custom-control custom-checkbox custom-control-inline"> <input checked="" class="custom-control-input" id="id_filter_types_5" name="filter_types" type="checkbox" value="6"/> <label class="custom-control-label" for="id_filter_types_5">
#             Contract
#         </label> </div> </div> </div> <input id="id_category" name="category" type="hidden" value="12"/> </fieldset>
# <div class="text-right mb-2" id="search-buttons">
# <em class="float-left" id="job-search-count">526 jobs<span class="d-none d-sm-inline"> found</span></em>
# <a class="btn btn-outline-primary btn-sm" href="/job/email/create/">Subscribe to job emails</a>
# <a class="btn btn-outline-primary btn-sm ml-2" href="/">Reset</a>
# </div>
# </form>
# </div>
# </div>
# <div class="row">
# <div class="col-lg-10 mx-auto px-2">
# <div class="list-group list-group-flush mb-5" id="job-list">
# <div class="list-group-item px-2 px-lg-3 py-0">
# <div class="row">
# <div class="col-2 col-sm-1 px-2 py-3">
# <a href="/jobs-at-amica-mutual-insurance-company/" title="Show all open positions at Amica Mutual Insurance Company">
# <img alt="Amica Mutual Insurance Company logo" class="mx-auto my-1 d-block" height="48" loading="lazy" src="/media/cache/39/95/39951b7ffbfd5608fb202f6de1e0ca38.jpg" width="48"/>
# </a>
# <div class="d-flex justify-content-center mt-3">
# <a class="btn-direct-apply text-dark p-1" href="/J24108/apply/" id="24108" rel="nofollow noopener" target="_blank" title="Apply for this job directly on Amica Mutual Insurance Company's career site"><i class="fas fa-edit"></i></a>
# <a class="btn-direct-apply text-dark p-1" href="/job/mark/24108/create/" rel="nofollow" title="Save this job for later application"><i class="fas fa-list-ol"></i></a>
# </div>
# </div>
# <a class="col list-group-item-action px-2 py-3" href="/job/24108-business-intelligence-analyst/" title="View full details of `Business Intelligence Analyst` vacancy">
# <div class="float-right text-right d-inline-block w-25 ml-2">
# <span class="d-block d-md-none text-break job-list-item-location">Lincoln, RI, 02865</span>
# <span class="d-none d-md-block text-break job-list-item-location">Lincoln, RI, 02865</span>
# <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
# <div class="d-block">
# <span class="badge badge-info badge-pill my-md-1 d-md-none">Mid</span>
# <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Mid-level</span>
# </div>
# </div>
# <p class="m-0 text-muted job-list-item-company">Amica Mutual Insurance Company</p>
# <h2 class="h4 mb-1">Business Intelligence Analyst</h2>
# <span class="badge badge-light badge-pill">Business Intelligence</span>
# <span class="badge badge-light badge-pill">Data management</span>
# <span class="badge badge-light badge-pill">Power BI</span>
# <span class="badge badge-light badge-pill">Python</span>
# <span class="badge badge-light badge-pill">R</span>
# <span class="badge badge-light badge-pill">SAS</span>
# <span class="badge badge-light badge-pill">SQL</span>
# <span class="badge badge-light badge-pill">+2</span>
# <br/>
# <span class="badge badge-success badge-pill">Competitive pay</span>
# <span class="badge badge-success badge-pill">Conferences</span>
# <span class="badge badge-success badge-pill">Fitness / gym</span>
# <span class="badge badge-success badge-pill">Health care</span>
# <span class="badge badge-success badge-pill">Insurance</span>
# <span class="badge badge-success badge-pill">+3</span>
# </a>
# </div>
# </div>
# <div class="list-group-item px-2 px-lg-3 py-0">
# <div class="row">
# <div class="col-2 col-sm-1 px-2 py-3">
# <a href="/jobs-at-amica-mutual-insurance-company/" title="Show all open positions at Amica Mutual Insurance Company">
# <img alt="Amica Mutual Insurance Company logo" class="mx-auto my-1 d-block" height="48" loading="lazy" src="/media/cache/39/95/39951b7ffbfd5608fb202f6de1e0ca38.jpg" width="48"/>
# </a>
# <div class="d-flex justify-content-center mt-3">
# <a class="btn-direct-apply text-dark p-1" href="/J24107/apply/" id="24107" rel="nofollow noopener" target="_blank" title="Apply for this job directly on Amica Mutual Insurance Company's career site"><i class="fas fa-edit"></i></a>
# <a class="btn-direct-apply text-dark p-1" href="/job/mark/24107/create/" rel="nofollow" title="Save this job for later application"><i class="fas fa-list-ol"></i></a>
# </div>
# </div>
# <a class="col list-group-item-action px-2 py-3" href="/job/24107-lead-business-intelligence-analyst/" title="View full details of `Lead Business Intelligence Analyst` vacancy">
# <div class="float-right text-right d-inline-block w-25 ml-2">
# <span class="d-block d-md-none text-break job-list-item-location">Lincoln, RI, 02865</span>
# <span class="d-none d-md-block text-break job-list-item-location">Lincoln, RI, 02865</span>
# <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
# <div class="d-block">
# <span class="badge badge-info badge-pill my-md-1 d-md-none">Senior</span>
# <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Senior-level</span>
# </div>
# </div>
# <p class="m-0 text-muted job-list-item-company">Amica Mutual Insurance Company</p>
# <h2 class="h4 mb-1">Lead Business Intelligence Analyst</h2>
# <span class="badge badge-light badge-pill">Business Intelligence</span>
# <span class="badge badge-light badge-pill">Data management</span>
# <span class="badge badge-light badge-pill">KPIs</span>
# <span class="badge badge-light badge-pill">Python</span>
# <span class="badge badge-light badge-pill">R</span>
# <span class="badge badge-light badge-pill">SAS</span>
# <span class="badge badge-light badge-pill">SQL</span>
# <span class="badge badge-light badge-pill">+1</span>
# <br/>
# <span class="badge badge-success badge-pill">Competitive pay</span>
# <span class="badge badge-success badge-pill">Conferences</span>
# <span class="badge badge-success badge-pill">Fitness / gym</span>
# <span class="badge badge-success badge-pill">Flex vacation</span>
# <span class="badge badge-success badge-pill">Health care</span>
# <span class="badge badge-success badge-pill">+4</span>
# </a>
# </div>
# </div>
# <div class="list-group-item px-2 px-lg-3 py-0">
# <div class="row">
# <div class="col-2 col-sm-1 px-2 py-3">
# <a href="/jobs-at-nielsen/" title="Show all open positions at Nielsen">
# <img alt="Nielsen logo" class="mx-auto my-1 d-block" height="48" loading="lazy" src="/media/cache/de/d0/ded0b2c0dc41b8e8637cc335e7b6a5e7.jpg" width="48"/>
# </a>
# <div class="d-flex justify-content-center mt-3">
# <a class="btn-direct-apply text-dark p-1" href="/J26580/apply/" id="26580" rel="nofollow noopener" target="_blank" title="Apply for this job directly on Nielsen's career site"><i class="fas fa-edit"></i></a>
# <a class="btn-direct-apply text-dark p-1" href="/job/mark/26580/create/" rel="nofollow" title="Save this job for later application"><i class="fas fa-list-ol"></i></a>
# </div>
# </div>
# <a class="col list-group-item-action px-2 py-3" href="/job/26580-junior-data-analyst/" title="View full details of `Junior Data Analyst` vacancy">
# <div class="float-right text-right d-inline-block w-25 ml-2">
# <span class="d-block d-md-none text-break job-list-item-location">Poland</span>
# <span class="d-none d-md-block text-break job-list-item-location">Poland</span>
# <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
# <div class="d-block">
# <span class="badge badge-info badge-pill my-md-1 d-md-none">Entry</span>
# <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Entry-level</span>
# </div>
# <div class="d-block">
# <span class="badge badge-success badge-pill d-none d-md-inline-block">USD 30K - 80K *</span>
# <span class="badge badge-success badge-pill d-md-none">USD 30K+ *</span>
# </div>
# </div>
# <p class="m-0 text-muted job-list-item-company">Nielsen</p>
# <h2 class="h4 mb-1">Junior Data Analyst</h2>
# <span class="badge badge-light badge-pill">Consulting</span>
# <span class="badge badge-light badge-pill">Data analysis</span>
# <span class="badge badge-light badge-pill">Econometrics</span>
# <span class="badge badge-light badge-pill">Excel</span>
# <span class="badge badge-light badge-pill">Market research</span>
# <span class="badge badge-light badge-pill">Python</span>
# <span class="badge badge-light badge-pill">R</span>
# <span class="badge badge-light badge-pill">+5</span>
# <br/>
# <span class="badge badge-success badge-pill">Career development</span>
# </a>
# </div>
# </div>
# <div class="list-group-item px-2 px-lg-3 py-0">
# <div class="row">
# <div class="col-2 col-sm-1 px-2 py-3">
# <a href="/jobs-at-athletic-greens/" title="Show all open positions at Athletic Greens">
# <img alt="Athletic Greens logo" class="mx-auto my-1 d-block" height="48" loading="lazy" src="/media/cache/6d/55/6d55b3d5009b61f26b4c9ca80603e2fb.jpg" width="48"/>
# </a>
# <div class="d-flex justify-content-center mt-3">
# <a class="btn-direct-apply text-dark p-1" href="/J26584/apply/" id="26584" rel="nofollow noopener" target="_blank" title="Apply for this job directly on Athletic Greens's career site"><i class="fas fa-edit"></i></a>
# <a class="btn-direct-apply text-dark p-1" href="/job/mark/26584/create/" rel="nofollow" title="Save this job for later application"><i class="fas fa-list-ol"></i></a>
# </div>
# </div>
# <a class="col list-group-item-action px-2 py-3" href="/job/26584-senior-vice-president-data-analytics-bi/" title="View full details of `Senior Vice President, Data Analytics &amp; BI` vacancy">
# <div class="float-right text-right d-inline-block w-25 ml-2">
# <span class="d-block d-md-none text-break job-list-item-location">Los Angeles, California, United …</span>
# <span class="d-none d-md-block text-break job-list-item-location">Los Angeles, California, United States - Remote</span>
# <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
# <div class="d-block">
# <span class="badge badge-info badge-pill my-md-1 d-md-none">Senior</span>
# <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Senior-level</span>
# </div>
# </div>
# <p class="m-0 text-muted job-list-item-company">Athletic Greens</p>
# <h2 class="h4 mb-1">Senior Vice President, Data Analytics &amp; BI</h2>
# <span class="badge badge-light badge-pill">Airflow</span>
# <span class="badge badge-light badge-pill">BigQuery</span>
# <span class="badge badge-light badge-pill">Business Intelligence</span>
# <span class="badge badge-light badge-pill">Data Analytics</span>
# <span class="badge badge-light badge-pill">Data management</span>
# <span class="badge badge-light badge-pill">Data strategy</span>
# <span class="badge badge-light badge-pill">E-commerce</span>
# <span class="badge badge-light badge-pill">+6</span>
# <br/>
# <span class="badge badge-success badge-pill">401(k) matching</span>
# <span class="badge badge-success badge-pill">Flex vacation</span>
# <span class="badge badge-success badge-pill">Gear</span>
# <span class="badge badge-success badge-pill">Health care</span>
# <span class="badge badge-success badge-pill">Home office stipend</span>
# <span class="badge badge-success badge-pill">+5</span>
# </a>
# </div>
# </div>
# <div class="list-group-item px-2 px-lg-3 py-0">
# <div class="row">
# <div class="col-2 col-sm-1 px-2 py-3">
# <a href="/jobs-at-airbnb/" title="Show all open positions at Airbnb">
# <img alt="Airbnb logo" class="mx-auto my-1 d-block" height="48" loading="lazy" src="/media/cache/6b/ba/6bba22fad2cd698715cd02b1239a1819.jpg" width="48"/>
# </a>
# <div class="d-flex justify-content-center mt-3">
# <a class="btn-direct-apply text-dark p-1" href="/J26569/apply/" id="26569" rel="nofollow noopener" target="_blank" title="Apply for this job directly on Airbnb's career site"><i class="fas fa-edit"></i></a>
# <a class="btn-direct-apply text-dark p-1" href="/job/mark/26569/create/" rel="nofollow" title="Save this job for later application"><i class="fas fa-list-ol"></i></a>
# </div>
# </div>
# <a class="col list-group-item-action px-2 py-3" href="/job/26569-staff-analytics-engineer-central-data/" title="View full details of `Staff Analytics Engineer, Central Data` vacancy">
# <div class="float-right text-right d-inline-block w-25 ml-2">
# <span class="d-block d-md-none text-break job-list-item-location">United States</span>
# <span class="d-none d-md-block text-break job-list-item-location">United States</span>
# <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
# <div class="d-block">
# <span class="badge badge-info badge-pill my-md-1 d-md-none">Senior</span>
# <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Senior-level</span>
# </div>
# <div class="d-block">
# <span class="badge badge-success badge-pill d-none d-md-inline-block">USD 180K - 245K</span>
# <span class="badge badge-success badge-pill d-md-none">USD 180K+</span>
# </div>
# </div>
# <p class="m-0 text-muted job-list-item-company">Airbnb</p>
# <h2 class="h4 mb-1">Staff Analytics Engineer, Central Data</h2>
# <span class="badge badge-light badge-pill">Airflow</span>
# <span class="badge badge-light badge-pill">Data analysis</span>
# <span class="badge badge-light badge-pill">Engineering</span>
# <span class="badge badge-light badge-pill">ETL</span>
# <span class="badge badge-light badge-pill">Machine Learning</span>
# <span class="badge badge-light badge-pill">Pipelines</span>
# <span class="badge badge-light badge-pill">Predictive modeling</span>
# <span class="badge badge-light badge-pill">+6</span>
# <br/>
# <span class="badge badge-success badge-pill">Career development</span>
# <span class="badge badge-success badge-pill">Salary bonus</span>
# </a>
# </div>
# </div>
# <div class="list-group-item px-2 px-lg-3 py-0">
# <div class="row">
# <div class="col-2 col-sm-1 px-2 py-3">
# <a href="/jobs-at-tempus/" title="Show all open positions at Tempus">
# <img alt="Tempus logo" class="mx-auto my-1 d-block" height="48" loading="lazy" src="/media/cache/ce/3e/ce3e2833beb0398e8444b6f2dcabf02a.jpg" width="48"/>
# </a>
# <div class="d-flex justify-content-center mt-3">
# <a class="btn-direct-apply text-dark p-1" href="/J26572/apply/" id="26572" rel="nofollow noopener" target="_blank" title="Apply for this job directly on Tempus's career site"><i class="fas fa-edit"></i></a>
# <a class="btn-direct-apply text-dark p-1" href="/job/mark/26572/create/" rel="nofollow" title="Save this job for later application"><i class="fas fa-list-ol"></i></a>
# </div>
# </div>
# <a class="col list-group-item-action px-2 py-3" href="/job/26572-data-analyst-clinical-informatics/" title="View full details of `Data Analyst - Clinical Informatics` vacancy">
# <div class="float-right text-right d-inline-block w-25 ml-2">
# <span class="d-block d-md-none text-break job-list-item-location">Chicago, IL</span>
# <span class="d-none d-md-block text-break job-list-item-location">Chicago, IL</span>
# <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
# <div class="d-block">
# <span class="badge badge-success badge-pill d-none d-md-inline-block">USD 50K - 85K *</span>
# <span class="badge badge-success badge-pill d-md-none">USD 50K+ *</span>
# </div>
# </div>
# <p class="m-0 text-muted job-list-item-company">Tempus</p>
# <h2 class="h4 mb-1">Data Analyst - Clinical Informatics</h2>
# <span class="badge badge-light badge-pill">Data pipelines</span>
# <span class="badge badge-light badge-pill">Pipelines</span>
# <span class="badge badge-light badge-pill">Python</span>
# <span class="badge badge-light badge-pill">SQL</span>
# <br/>
# </a>
# </div>
# </div>
# <div class="list-group-item px-2 px-lg-3 py-0">
# <div class="row">
# <div class="col-2 col-sm-1 px-2 py-3">
# <a href="/jobs-at-adyen/" title="Show all open positions at Adyen">
# <img alt="Adyen logo" class="mx-auto my-1 d-block" height="48" loading="lazy" src="/media/cache/3a/99/3a9928a0aef5b8275d5cd169ea03ddc3.jpg" width="48"/>
# </a>
# <div class="d-flex justify-content-center mt-3">
# <a class="btn-direct-apply text-dark p-1" href="/J26573/apply/" id="26573" rel="nofollow noopener" target="_blank" title="Apply for this job directly on Adyen's career site"><i class="fas fa-edit"></i></a>
# <a class="btn-direct-apply text-dark p-1" href="/job/mark/26573/create/" rel="nofollow" title="Save this job for later application"><i class="fas fa-list-ol"></i></a>
# </div>
# </div>
# <a class="col list-group-item-action px-2 py-3" href="/job/26573-senior-product-data-analytics/" title="View full details of `Senior Product Data Analytics` vacancy">
# <div class="float-right text-right d-inline-block w-25 ml-2">
# <span class="d-block d-md-none text-break job-list-item-location">Sao Paulo</span>
# <span class="d-none d-md-block text-break job-list-item-location">Sao Paulo</span>
# <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
# <div class="d-block">
# <span class="badge badge-info badge-pill my-md-1 d-md-none">Senior</span>
# <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Senior-level</span>
# </div>
# </div>
# <p class="m-0 text-muted job-list-item-company">Adyen</p>
# <h2 class="h4 mb-1">Senior Product Data Analytics</h2>
# <span class="badge badge-light badge-pill">Airflow</span>
# <span class="badge badge-light badge-pill">Big Data</span>
# <span class="badge badge-light badge-pill">Data Analytics</span>
# <span class="badge badge-light badge-pill">Data pipelines</span>
# <span class="badge badge-light badge-pill">Engineering</span>
# <span class="badge badge-light badge-pill">ETL</span>
# <span class="badge badge-light badge-pill">Pipelines</span>
# <span class="badge badge-light badge-pill">+5</span>
# <br/>
# <span class="badge badge-success badge-pill">Startup environment</span>
# </a>
# </div>
# </div>
# <div class="list-group-item px-2 px-lg-3 py-0">
# <div class="row">
# <div class="col-2 col-sm-1 px-2 py-3">
# <a href="/jobs-at-doordash/" title="Show all open positions at DoorDash">
# <img alt="DoorDash logo" class="mx-auto my-1 d-block" height="48" loading="lazy" src="/media/cache/fc/87/fc87cb38476d66ea026815302d94c848.jpg" width="48"/>
# </a>
# <div class="d-flex justify-content-center mt-3">
# <a class="btn-direct-apply text-dark p-1" href="/J26526/apply/" id="26526" rel="nofollow noopener" target="_blank" title="Apply for this job directly on DoorDash's career site"><i class="fas fa-edit"></i></a>
# <a class="btn-direct-apply text-dark p-1" href="/job/mark/26526/create/" rel="nofollow" title="Save this job for later application"><i class="fas fa-list-ol"></i></a>
# </div>
# </div>
# <a class="col list-group-item-action px-2 py-3" href="/job/26526-data-scientist-international-analytics/" title="View full details of `Data Scientist, International Analytics` vacancy">
# <div class="float-right text-right d-inline-block w-25 ml-2">
# <span class="d-block d-md-none text-break job-list-item-location">Toronto, ON</span>
# <span class="d-none d-md-block text-break job-list-item-location">Toronto, ON</span>
# <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
# <div class="d-block">
# <span class="badge badge-info badge-pill my-md-1 d-md-none">Senior</span>
# <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Senior-level</span>
# </div>
# <div class="d-block">
# <span class="badge badge-success badge-pill d-none d-md-inline-block">USD 68K - 135K *</span>
# <span class="badge badge-success badge-pill d-md-none">USD 68K+ *</span>
# </div>
# </div>
# <p class="m-0 text-muted job-list-item-company">DoorDash</p>
# <h2 class="h4 mb-1">Data Scientist, International Analytics</h2>
# <span class="badge badge-light badge-pill">A/B testing</span>
# <span class="badge badge-light badge-pill">Consulting</span>
# <span class="badge badge-light badge-pill">Data Analytics</span>
# <span class="badge badge-light badge-pill">Economics</span>
# <span class="badge badge-light badge-pill">ETL</span>
# <span class="badge badge-light badge-pill">Excel</span>
# <span class="badge badge-light badge-pill">Looker</span>
# <span class="badge badge-light badge-pill">+8</span>
# <br/>
# <span class="badge badge-success badge-pill">Flex vacation</span>
# </a>
# </div>
# </div>
# <div class="list-group-item px-2 px-lg-3 py-0">
# <div class="row">
# <div class="col-2 col-sm-1 px-2 py-3">
# <a href="/jobs-at-archive/" title="Show all open positions at Archive">
# <img alt="Archive logo" class="mx-auto my-1 d-block" height="48" loading="lazy" src="/media/cache/6f/2d/6f2da1f2766f34438b3a4dd78e00470f.jpg" width="48"/>
# </a>
# <div class="d-flex justify-content-center mt-3">
# <a class="btn-direct-apply text-dark p-1" href="/J26575/apply/" id="26575" rel="nofollow noopener" target="_blank" title="Apply for this job directly on Archive's career site"><i class="fas fa-edit"></i></a>
# <a class="btn-direct-apply text-dark p-1" href="/job/mark/26575/create/" rel="nofollow" title="Save this job for later application"><i class="fas fa-list-ol"></i></a>
# </div>
# </div>
# <a class="col list-group-item-action px-2 py-3" href="/job/26575-data-analyst/" title="View full details of `Data Analyst` vacancy">
# <div class="float-right text-right d-inline-block w-25 ml-2">
# <span class="d-block d-md-none text-break job-list-item-location">Remote</span>
# <span class="d-none d-md-block text-break job-list-item-location">Remote</span>
# <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
# <div class="d-block">
# <span class="badge badge-info badge-pill my-md-1 d-md-none">Senior</span>
# <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Senior-level</span>
# </div>
# <div class="d-block">
# <span class="badge badge-success badge-pill d-none d-md-inline-block">USD 50K - 85K *</span>
# <span class="badge badge-success badge-pill d-md-none">USD 50K+ *</span>
# </div>
# </div>
# <p class="m-0 text-muted job-list-item-company">Archive</p>
# <h2 class="h4 mb-1">Data Analyst</h2>
# <span class="badge badge-light badge-pill">Data visualization</span>
# <span class="badge badge-light badge-pill">Looker</span>
# <span class="badge badge-light badge-pill">SQL</span>
# <span class="badge badge-light badge-pill">Tableau</span>
# <br/>
# </a>
# </div>
# </div>
# <div class="list-group-item px-2 px-lg-3 py-0">
# <div class="row">
# <div class="col-2 col-sm-1 px-2 py-3">
# <a href="/jobs-at-koho/" title="Show all open positions at KOHO">
# <img alt="KOHO logo" class="mx-auto my-1 d-block" height="48" loading="lazy" src="/media/cache/d2/d6/d2d6222f2ad1a6e09e27dadc92805b88.jpg" width="48"/>
# </a>
# <div class="d-flex justify-content-center mt-3">
# <a class="btn-direct-apply text-dark p-1" href="/J26570/apply/" id="26570" rel="nofollow noopener" target="_blank" title="Apply for this job directly on KOHO's career site"><i class="fas fa-edit"></i></a>
# <a class="btn-direct-apply text-dark p-1" href="/job/mark/26570/create/" rel="nofollow" title="Save this job for later application"><i class="fas fa-list-ol"></i></a>
# </div>
# </div>
# <a class="col list-group-item-action px-2 py-3" href="/job/26570-analytics-engineer-remote/" title="View full details of `Analytics Engineer - Remote` vacancy">
# <div class="float-right text-right d-inline-block w-25 ml-2">
# <span class="d-block d-md-none text-break job-list-item-location">Canada</span>
# <span class="d-none d-md-block text-break job-list-item-location">Canada</span>
# <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
# <div class="d-block">
# <span class="badge badge-info badge-pill my-md-1 d-md-none">Senior</span>
# <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Senior-level</span>
# </div>
# </div>
# <p class="m-0 text-muted job-list-item-company">KOHO</p>
# <h2 class="h4 mb-1">Analytics Engineer - Remote</h2>
# <span class="badge badge-light badge-pill">Data Analytics</span>
# <span class="badge badge-light badge-pill">Engineering</span>
# <span class="badge badge-light badge-pill">Machine Learning</span>
# <span class="badge badge-light badge-pill">Python</span>
# <span class="badge badge-light badge-pill">SQL</span>
# <span class="badge badge-light badge-pill">Testing</span>
# <br/>
# <span class="badge badge-success badge-pill">Home office stipend</span>
# </a>
# </div>
# </div>
# <div class="list-group-item px-2 px-lg-3 py-0">
# <div class="row">
# <div class="col-2 col-sm-1 px-2 py-3">
# <a href="/jobs-at-sosafe/" title="Show all open positions at SoSafe">
# <img alt="SoSafe logo" class="mx-auto my-1 d-block" height="48" loading="lazy" src="/media/cache/62/50/62508571fb1dae6a176f8550cec711d9.jpg" width="48"/>
# </a>
# <div class="d-flex justify-content-center mt-3">
# <a class="btn-direct-apply text-dark p-1" href="/J26541/apply/" id="26541" rel="nofollow noopener" target="_blank" title="Apply for this job directly on SoSafe's career site"><i class="fas fa-edit"></i></a>
# <a class="btn-direct-apply text-dark p-1" href="/job/mark/26541/create/" rel="nofollow" title="Save this job for later application"><i class="fas fa-list-ol"></i></a>
# </div>
# </div>
# <a class="col list-group-item-action px-2 py-3" href="/job/26541-data-analyst-bi-developer-mfd/" title="View full details of `Data Analyst / BI Developer (m/f/d)` vacancy">
# <div class="float-right text-right d-inline-block w-25 ml-2">
# <span class="d-block d-md-none text-break job-list-item-location">Remote</span>
# <span class="d-none d-md-block text-break job-list-item-location">Remote</span>
# <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
# <div class="d-block">
# <span class="badge badge-info badge-pill my-md-1 d-md-none">Senior</span>
# <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Senior-level</span>
# </div>
# </div>
# <p class="m-0 text-muted job-list-item-company">SoSafe</p>
# <h2 class="h4 mb-1">Data Analyst / BI Developer (m/f/d)</h2>
# <span class="badge badge-light badge-pill">Business Intelligence</span>
# <span class="badge badge-light badge-pill">Data analysis</span>
# <span class="badge badge-light badge-pill">Data visualization</span>
# <span class="badge badge-light badge-pill">KPIs</span>
# <span class="badge badge-light badge-pill">Power BI</span>
# <span class="badge badge-light badge-pill">Python</span>
# <span class="badge badge-light badge-pill">Security</span>
# <span class="badge badge-light badge-pill">+3</span>
# <br/>
# <span class="badge badge-success badge-pill">Career development</span>
# <span class="badge badge-success badge-pill">Competitive pay</span>
# <span class="badge badge-success badge-pill">Flex vacation</span>
# <span class="badge badge-success badge-pill">Lunch / meals</span>
# <span class="badge badge-success badge-pill">Salary bonus</span>
# <span class="badge badge-success badge-pill">+1</span>
# </a>
# </div>
# </div>
# <div class="list-group-item px-2 px-lg-3 py-0">
# <div class="row">
# <div class="col-2 col-sm-1 px-2 py-3">
# <a href="/jobs-at-mintel/" title="Show all open positions at Mintel">
# <img alt="Mintel logo" class="mx-auto my-1 d-block" height="48" loading="lazy" src="/media/cache/03/ee/03ee755a9fb02e10654b60bcf91a2c27.jpg" width="48"/>
# </a>
# <div class="d-flex justify-content-center mt-3">
# <a class="btn-direct-apply text-dark p-1" href="/J26579/apply/" id="26579" rel="nofollow noopener" target="_blank" title="Apply for this job directly on Mintel's career site"><i class="fas fa-edit"></i></a>
# <a class="btn-direct-apply text-dark p-1" href="/job/mark/26579/create/" rel="nofollow" title="Save this job for later application"><i class="fas fa-list-ol"></i></a>
# </div>
# </div>
# <a class="col list-group-item-action px-2 py-3" href="/job/26579-data-analytics-lead/" title="View full details of `Data Analytics Lead` vacancy">
# <div class="float-right text-right d-inline-block w-25 ml-2">
# <span class="d-block d-md-none text-break job-list-item-location">London</span>
# <span class="d-none d-md-block text-break job-list-item-location">London</span>
# <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
# </div>
# <p class="m-0 text-muted job-list-item-company">Mintel</p>
# <h2 class="h4 mb-1">Data Analytics Lead</h2>
# <span class="badge badge-light badge-pill">Consulting</span>
# <span class="badge badge-light badge-pill">Data Analytics</span>
# <span class="badge badge-light badge-pill">Looker</span>
# <span class="badge badge-light badge-pill">Market research</span>
# <span class="badge badge-light badge-pill">Power BI</span>
# <span class="badge badge-light badge-pill">Research</span>
# <span class="badge badge-light badge-pill">SQL</span>
# <span class="badge badge-light badge-pill">+1</span>
# <br/>
# <span class="badge badge-success badge-pill">Career development</span>
# <span class="badge badge-success badge-pill">Flex vacation</span>
# </a>
# </div>
# </div>
# <div class="list-group-item px-2 px-lg-3 py-0">
# <div class="row">
# <div class="col-2 col-sm-1 px-2 py-3">
# <a href="/jobs-at-fitxr/" title="Show all open positions at FitXR">
# <img alt="FitXR logo" class="mx-auto my-1 d-block" height="48" loading="lazy" src="/media/cache/45/72/4572700f92925420c5e1df1d5e81d637.jpg" width="48"/>
# </a>
# <div class="d-flex justify-content-center mt-3">
# <a class="btn-direct-apply text-dark p-1" href="/J26583/apply/" id="26583" rel="nofollow noopener" target="_blank" title="Apply for this job directly on FitXR's career site"><i class="fas fa-edit"></i></a>
# <a class="btn-direct-apply text-dark p-1" href="/job/mark/26583/create/" rel="nofollow" title="Save this job for later application"><i class="fas fa-list-ol"></i></a>
# </div>
# </div>
# <a class="col list-group-item-action px-2 py-3" href="/job/26583-senior-data-analyst/" title="View full details of `Senior Data Analyst` vacancy">
# <div class="float-right text-right d-inline-block w-25 ml-2">
# <span class="d-block d-md-none text-break job-list-item-location">London, England, United Kingdom …</span>
# <span class="d-none d-md-block text-break job-list-item-location">London, England, United Kingdom - Remote</span>
# <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
# <div class="d-block">
# <span class="badge badge-info badge-pill my-md-1 d-md-none">Mid</span>
# <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Mid-level</span>
# </div>
# <div class="d-block">
# <span class="badge badge-success badge-pill d-none d-md-inline-block">USD 51K - 90K *</span>
# <span class="badge badge-success badge-pill d-md-none">USD 51K+ *</span>
# </div>
# </div>
# <p class="m-0 text-muted job-list-item-company">FitXR</p>
# <h2 class="h4 mb-1">Senior Data Analyst</h2>
# <span class="badge badge-light badge-pill">A/B testing</span>
# <span class="badge badge-light badge-pill">BigQuery</span>
# <span class="badge badge-light badge-pill">DevOps</span>
# <span class="badge badge-light badge-pill">Engineering</span>
# <span class="badge badge-light badge-pill">Julia</span>
# <span class="badge badge-light badge-pill">Python</span>
# <span class="badge badge-light badge-pill">R</span>
# <span class="badge badge-light badge-pill">+2</span>
# <br/>
# <span class="badge badge-success badge-pill">Career development</span>
# <span class="badge badge-success badge-pill">Competitive pay</span>
# <span class="badge badge-success badge-pill">Equity</span>
# <span class="badge badge-success badge-pill">Flex vacation</span>
# <span class="badge badge-success badge-pill">Gear</span>
# <span class="badge badge-success badge-pill">+3</span>
# </a>
# </div>
# </div>
# <div class="list-group-item px-2 px-lg-3 py-0">
# <div class="row">
# <div class="col-2 col-sm-1 px-2 py-3">
# <a href="/jobs-at-lingoace/" title="Show all open positions at LingoAce">
# <img alt="LingoAce logo" class="mx-auto my-1 d-block" height="48" loading="lazy" src="/media/cache/0f/0e/0f0ed92ec77c049e2ad10698ad549c75.jpg" width="48"/>
# </a>
# <div class="d-flex justify-content-center mt-3">
# <a class="btn-direct-apply text-dark p-1" href="/J26582/apply/" id="26582" rel="nofollow noopener" target="_blank" title="Apply for this job directly on LingoAce's career site"><i class="fas fa-edit"></i></a>
# <a class="btn-direct-apply text-dark p-1" href="/job/mark/26582/create/" rel="nofollow" title="Save this job for later application"><i class="fas fa-list-ol"></i></a>
# </div>
# </div>
# <a class="col list-group-item-action px-2 py-3" href="/job/26582-senior-data-analyst-thailand/" title="View full details of `Senior Data Analyst - Thailand` vacancy">
# <div class="float-right text-right d-inline-block w-25 ml-2">
# <span class="d-block d-md-none text-break job-list-item-location">Bangkok, Bangkok, Thailand</span>
# <span class="d-none d-md-block text-break job-list-item-location">Bangkok, Bangkok, Thailand</span>
# <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
# <div class="d-block">
# <span class="badge badge-info badge-pill my-md-1 d-md-none">Mid</span>
# <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Mid-level</span>
# </div>
# <div class="d-block">
# <span class="badge badge-success badge-pill d-none d-md-inline-block">USD 51K - 90K *</span>
# <span class="badge badge-success badge-pill d-md-none">USD 51K+ *</span>
# </div>
# </div>
# <p class="m-0 text-muted job-list-item-company">LingoAce</p>
# <h2 class="h4 mb-1">Senior Data Analyst - Thailand</h2>
# <span class="badge badge-light badge-pill">Data Analytics</span>
# <span class="badge badge-light badge-pill">Economics</span>
# <span class="badge badge-light badge-pill">Statistics</span>
# <br/>
# <span class="badge badge-success badge-pill">Startup environment</span>
# </a>
# </div>
# </div>
# <div class="list-group-item px-2 px-lg-3 py-0">
# <div class="row">
# <div class="col-2 col-sm-1 px-2 py-3">
# <a href="/jobs-at-wpp/" title="Show all open positions at WPP">
# ...
# </div>
# </div>
# </div>
# <div class="row px-2 my-4">
# <div class="col-md-10 mx-auto px-2">
# <h2 class="h3">Explore more AI/ML/Data Science career opportunities</h2>
# <p>Find open roles in Artificial Intelligence (AI), Machine Learning (ML), Natural Language Processing (NLP), Computer Vision (CV), Data Engineering, Data Analytics, Big Data, and Data Science in general, filtered by job title or popular skill, toolset and products used.</p>
# </div>
# <div class="col-sm-5 offset-md-1 my-2 px-2">
# <ul class="list-unstyled">
# <li class="my-1"><a href="/data-engineer-jobs/" title="Find Data Engineer Jobs">Open <strong>Data Engineer</strong> jobs</a></li><li class="my-1"><a href="/senior-data-engineer-jobs/" title="Find Senior Data Engineer Jobs">Open <strong>Senior Data Engineer</strong> jobs</a></li><li class="my-1"><a href="/data-scientist-jobs/" title="Find Data Scientist Jobs">Open <strong>Data Scientist</strong> jobs</a></li><li class="my-1"><a href="/data-analyst-jobs/" title="Find Data Analyst Jobs">Open <strong>Data Analyst</strong> jobs</a></li><li class="my-1"><a href="/senior-data-scientist-jobs/" title="Find Senior Data Scientist Jobs">Open <strong>Senior Data Scientist</strong> jobs</a></li><li class="my-1"><a href="/senior-data-analyst-jobs/" title="Find Senior Data Analyst Jobs">Open <strong>Senior Data Analyst</strong> jobs</a></li><li class="my-1"><a href="/machine-learning-engineer-jobs/" title="Find Machine Learning Engineer Jobs">Open <strong>Machine Learning Engineer</strong> jobs</a></li><li class="my-1"><a href="/senior-machine-learning-engineer-jobs/" title="Find Senior Machine Learning Engineer Jobs">Open <strong>Senior Machine Learning Engineer</strong> jobs</a></li><li class="my-1"><a href="/data-architect-jobs/" title="Find Data Architect Jobs">Open <strong>Data Architect</strong> jobs</a></li><li class="my-1"><a href="/staff-data-engineer-jobs/" title="Find Staff Data Engineer Jobs">Open <strong>Staff Data Engineer</strong> jobs</a></li><li class="my-1"><a href="/lead-data-scientist-jobs/" title="Find Lead Data Scientist Jobs">Open <strong>Lead Data Scientist</strong> jobs</a></li><li class="my-1"><a href="/analytics-engineer-jobs/" title="Find Analytics Engineer Jobs">Open <strong>Analytics Engineer</strong> jobs</a></li><li class="my-1"><a href="/lead-data-engineer-jobs/" title="Find Lead Data Engineer Jobs">Open <strong>Lead Data Engineer</strong> jobs</a></li><li class="my-1"><a href="/sr-data-engineer-jobs/" title="Find Sr. Data Engineer Jobs">Open <strong>Sr. Data Engineer</strong> jobs</a></li><li class="my-1"><a href="/data-engineering-manager-jobs/" title="Find Data Engineering Manager Jobs">Open <strong>Data Engineering Manager</strong> jobs</a></li><li class="my-1"><a href="/sr-data-scientist-jobs/" title="Find Sr. Data Scientist Jobs">Open <strong>Sr. Data Scientist</strong> jobs</a></li><li class="my-1"><a href="/data-science-manager-jobs/" title="Find Data Science Manager Jobs">Open <strong>Data Science Manager</strong> jobs</a></li><li class="my-1"><a href="/staff-machine-learning-engineer-jobs/" title="Find Staff Machine Learning Engineer Jobs">Open <strong>Staff Machine Learning Engineer</strong> jobs</a></li><li class="my-1"><a href="/senior-analytics-engineer-jobs/" title="Find Senior Analytics Engineer Jobs">Open <strong>Senior Analytics Engineer</strong> jobs</a></li><li class="my-1"><a href="/product-data-analyst-jobs/" title="Find Product Data Analyst Jobs">Open <strong>Product Data Analyst</strong> jobs</a></li><li class="my-1"><a href="/principal-data-engineer-jobs/" title="Find Principal Data Engineer Jobs">Open <strong>Principal Data Engineer</strong> jobs</a></li><li class="my-1"><a href="/staff-data-scientist-jobs/" title="Find Staff Data Scientist Jobs">Open <strong>Staff Data Scientist</strong> jobs</a></li><li class="my-1"><a href="/data-science-intern-jobs/" title="Find Data Science Intern Jobs">Open <strong>Data Science Intern</strong> jobs</a></li><li class="my-1"><a href="/principal-data-scientist-jobs/" title="Find Principal Data Scientist Jobs">Open <strong>Principal Data Scientist</strong> jobs</a></li><li class="my-1"><a href="/junior-data-analyst-jobs/" title="Find Junior Data Analyst Jobs">Open <strong>Junior Data Analyst</strong> jobs</a></li>
# </ul>
# </div>
# <div class="col-sm-5 my-2 px-2">
# <ul class="list-unstyled">
# <li class="my-1"><a href="/python-jobs/" title="Find AI/ML/Data Science Jobs related to Python">Open <strong>Python</strong>-related jobs</a></li><li class="my-1"><a href="/engineering-jobs/" title="Find AI/ML/Data Science Jobs related to Engineering">Open <strong>Engineering</strong>-related jobs</a></li><li class="my-1"><a href="/sql-jobs/" title="Find AI/ML/Data Science Jobs related to SQL">Open <strong>SQL</strong>-related jobs</a></li><li class="my-1"><a href="/machine-learning-jobs/" title="Find AI/ML/Data Science Jobs related to Machine Learning">Open <strong>Machine Learning</strong>-related jobs</a></li><li class="my-1"><a href="/research-jobs/" title="Find AI/ML/Data Science Jobs related to Research">Open <strong>Research</strong>-related jobs</a></li><li class="my-1"><a href="/aws-jobs/" title="Find AI/ML/Data Science Jobs related to AWS">Open <strong>AWS</strong>-related jobs</a></li><li class="my-1"><a href="/statistics-jobs/" title="Find AI/ML/Data Science Jobs related to Statistics">Open <strong>Statistics</strong>-related jobs</a></li><li class="my-1"><a href="/pipelines-jobs/" title="Find AI/ML/Data Science Jobs related to Pipelines">Open <strong>Pipelines</strong>-related jobs</a></li><li class="my-1"><a href="/r-jobs/" title="Find AI/ML/Data Science Jobs related to R">Open <strong>R</strong>-related jobs</a></li><li class="my-1"><a href="/ml-jobs/" title="Find AI/ML/Data Science Jobs related to ML">Open <strong>ML</strong>-related jobs</a></li><li class="my-1"><a href="/testing-jobs/" title="Find AI/ML/Data Science Jobs related to Testing">Open <strong>Testing</strong>-related jobs</a></li><li class="my-1"><a href="/spark-jobs/" title="Find AI/ML/Data Science Jobs related to Spark">Open <strong>Spark</strong>-related jobs</a></li><li class="my-1"><a href="/tableau-jobs/" title="Find AI/ML/Data Science Jobs related to Tableau">Open <strong>Tableau</strong>-related jobs</a></li><li class="my-1"><a href="/data-pipelines-jobs/" title="Find AI/ML/Data Science Jobs related to Data pipelines">Open <strong>Data pipelines</strong>-related jobs</a></li><li class="my-1"><a href="/big-data-jobs/" title="Find AI/ML/Data Science Jobs related to Big Data">Open <strong>Big Data</strong>-related jobs</a></li><li class="my-1"><a href="/agile-jobs/" title="Find AI/ML/Data Science Jobs related to Agile">Open <strong>Agile</strong>-related jobs</a></li><li class="my-1"><a href="/etl-jobs/" title="Find AI/ML/Data Science Jobs related to ETL">Open <strong>ETL</strong>-related jobs</a></li><li class="my-1"><a href="/data-analysis-jobs/" title="Find AI/ML/Data Science Jobs related to Data analysis">Open <strong>Data analysis</strong>-related jobs</a></li><li class="my-1"><a href="/security-jobs/" title="Find AI/ML/Data Science Jobs related to Security">Open <strong>Security</strong>-related jobs</a></li><li class="my-1"><a href="/data-analytics-jobs/" title="Find AI/ML/Data Science Jobs related to Data Analytics">Open <strong>Data Analytics</strong>-related jobs</a></li><li class="my-1"><a href="/airflow-jobs/" title="Find AI/ML/Data Science Jobs related to Airflow">Open <strong>Airflow</strong>-related jobs</a></li><li class="my-1"><a href="/finance-jobs/" title="Find AI/ML/Data Science Jobs related to Finance">Open <strong>Finance</strong>-related jobs</a></li><li class="my-1"><a href="/deep-learning-jobs/" title="Find AI/ML/Data Science Jobs related to Deep Learning">Open <strong>Deep Learning</strong>-related jobs</a></li><li class="my-1"><a href="/scala-jobs/" title="Find AI/ML/Data Science Jobs related to Scala">Open <strong>Scala</strong>-related jobs</a></li><li class="my-1"><a href="/phd-jobs/" title="Find AI/ML/Data Science Jobs related to PhD">Open <strong>PhD</strong>-related jobs</a></li>
# </ul>
# </div>
# </div>
# </div>
# </main>
# <footer class="mt-auto py-4 border-top bg-dark">
# <div class="container-lg">
# <div class="row py-4">
# <div class="col-12 col-md">
# <p class="text-muted">
# 	  Got questions, feedback or ideas?
# 	  Drop us a <a class="text-light" href="mailto:mail@ai-jobs.net">message</a>.
# 	</p>
# </div>
# <div class="col">
# <h3 class="h4">For candidates</h3>
# <ul class="list-unstyled">
# <li class="my-1"><a class="text-light" href="/"><i class="fas fa-search"></i> Find a job</a></li>
# <li class="my-1"><a class="text-light" href="/countries/"><i class="fas fa-map-pin"></i> Country search</a></li>
# <li class="my-1"><a class="text-light" href="/job/emails/"><i class="far fa-envelope"></i> Job emails</a></li>
# <li class="my-1"><a class="text-light" href="/job/marks/"><i class="fas fa-list-ol"></i> Saved jobs</a></li>
# <li class="my-1"><a class="text-light" href="/register/"><i class="fas fa-user-plus"></i> Sign up</a></li>
# </ul>
# </div>
# <div class="col">
# <h3 class="h4">For employers</h3>
# <ul class="list-unstyled">
# <li class="my-1"><a class="text-light" href="/post-a-job/"><i class="fas fa-bullhorn"></i> Post a job</a></li>
# <li class="my-1"><a class="text-light" href="/jobs/"><i class="fas fa-list-ul"></i> My job ads</a></li>
# <li class="my-1"><a class="text-light" href="/orders/"><i class="far fa-file-alt"></i> My orders</a></li>
# <li class="my-1"><a class="text-light" href="/accounts/dashboard/"><i class="fas fa-user"></i> My account</a></li>
# </ul>
# </div>
# <div class="col-md">
# <h3 class="h4">Connect</h3>
# <ul class="list-unstyled">
# <li class="my-1">
# <a class="text-light" href="https://twitter.com/ai_jobsNET" rel="noopener" target="_blank">
# <i class="fab fa-twitter"></i> Twitter
# 	    </a>
# </li>
# <li class="my-1">
# <a class="text-light" href="https://www.linkedin.com/company/ai-jobs-net/" rel="noopener" target="_blank">
# <i class="fab fa-linkedin"></i> LinkedIn</a>
# </li>
# <li class="my-1">
# <a class="text-light" href="https://www.reddit.com/user/ai_jobs" rel="noopener" target="_blank">
# <i class="fab fa-reddit"></i> Reddit
# 	    </a>
# </li>
# <li class="my-1">
# <a class="text-light" href="https://ai-jobs.tumblr.com/" rel="noopener" target="_blank">
# <i class="fab fa-tumblr"></i> Tumblr
# 	    </a>
# </li>
# <li class="my-1">
# <a class="text-light" href="/feed/"><i class="fas fa-rss"></i> RSS</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="row py-4 border-top border-secondary">
# <div class="col-md text-muted">
# 	© 2022 <a class="text-light" href="/">ai-jobs.net</a>
# <span>| v2.10.3</span>
# <span class="text-muted">| Made with ♥️  + ☕ in Zürich, Switzerland and around the world.</span>
# </div>
# <div class="col-md text-md-right text-muted">
# <a class="text-light" href="/terms/">Terms and conditions</a> |
# 	<a class="text-light" href="/privacy/">Privacy policy</a> |
# 	<a class="text-light" href="/about/">About</a>
# </div>
# </div>
# </div>
# </footer>
# <script src="/static/js/select2.min.js"></script>
# <script src="/static/django_select2/django_select2.js"></script>
# <script>
#   $(function(){
#
#       $("#id_filter_regions").djangoSelect2({placeholder: ' All Regions + Remote '});
#
#
#       // search stuff
#       var getSearchResults = function() {
# 	  $.post({
# 	      url: '/',
# 	      data: $("#job-filter").serialize(),
# 	      success: function(res) {
# 		  $("#job-list").replaceWith(res);
# 		  $("#job-search-count").text(
# 		      $("#jobs-count").text() + ' jobs found');
# 		  setClickMore();
# 		  setTimeout(function() {
# 		      $("#search-buttons").collapse('show');
# 		  }, 200);
# 	      }
# 	  });
#       }
#       var getMoreResults = function(offset) {
# 	  $.post({
# 	      url: '/',
# 	      data: {
# 		  'csrfmiddlewaretoken': $("input[name=csrfmiddlewaretoken]").val(),
# 		  'offset': offset
# 	      },
# 	      success: function(res) {
# 		  $("#load-more-jobs").replaceWith(res);
# 		  setClickMore();
# 	      }
# 	  });
#       }
#       var setClickMore = function(){
# 	  $("#load-more-jobs").click(function(ev) {
# 	      ev.preventDefault();
# 	      getMoreResults($(this).attr('data-offset'));
# 	  });
#       }
#       search_timeout = null;
#       $("#job-filter").change(function(){ getSearchResults(); });
#       $("#id_search_keywords").keyup(function() {
# 	  clearTimeout(search_timeout);
# 	  search_timeout = setTimeout(function () {
#               getSearchResults();
# 	  }, 400);
#       });
#       $("#id_search_location").keyup(function() {
# 	  clearTimeout(search_timeout);
# 	  search_timeout = setTimeout(function () {
#               getSearchResults();
# 	  }, 400);
#       });
#       setClickMore();
#
#       // display settings
#       var setDisplaySetting = function(val) {
# 	  $.post({
# 	      url: '/',
# 	      data: {
# 		  'csrfmiddlewaretoken': $("input[name=csrfmiddlewaretoken]").val(),
# 		  'display_setting': val
# 	      },
# 	      success: function(res) {
# 		  document.location.reload();
# 	      }
# 	  });
#       }
#       $(".dropdown-item.display-setting").click(function(ev){
# 	  setDisplaySetting(ev.currentTarget.id);
#       });
#   });
# </script>
# </body>
# </html>

# %%
#start to store the website content in a variable 
results = soup.find('div', {'class':'list-group list-group-flush mb-5'})
results
# Out:
# <div class="list-group list-group-flush mb-5" id="job-list">
# <div class="list-group-item px-2 px-lg-3 py-0">
# <div class="row">
# <div class="col-2 col-sm-1 px-2 py-3">
# <a href="/jobs-at-amica-mutual-insurance-company/" title="Show all open positions at Amica Mutual Insurance Company">
# <img alt="Amica Mutual Insurance Company logo" class="mx-auto my-1 d-block" height="48" loading="lazy" src="/media/cache/39/95/39951b7ffbfd5608fb202f6de1e0ca38.jpg" width="48"/>
# </a>
# <div class="d-flex justify-content-center mt-3">
# <a class="btn-direct-apply text-dark p-1" href="/J24108/apply/" id="24108" rel="nofollow noopener" target="_blank" title="Apply for this job directly on Amica Mutual Insurance Company's career site"><i class="fas fa-edit"></i></a>
# <a class="btn-direct-apply text-dark p-1" href="/job/mark/24108/create/" rel="nofollow" title="Save this job for later application"><i class="fas fa-list-ol"></i></a>
# </div>
# </div>
# <a class="col list-group-item-action px-2 py-3" href="/job/24108-business-intelligence-analyst/" title="View full details of `Business Intelligence Analyst` vacancy">
# <div class="float-right text-right d-inline-block w-25 ml-2">
# <span class="d-block d-md-none text-break job-list-item-location">Lincoln, RI, 02865</span>
# <span class="d-none d-md-block text-break job-list-item-location">Lincoln, RI, 02865</span>
# <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
# <div class="d-block">
# <span class="badge badge-info badge-pill my-md-1 d-md-none">Mid</span>
# <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Mid-level</span>
# </div>
# </div>
# <p class="m-0 text-muted job-list-item-company">Amica Mutual Insurance Company</p>
# <h2 class="h4 mb-1">Business Intelligence Analyst</h2>
# <span class="badge badge-light badge-pill">Business Intelligence</span>
# <span class="badge badge-light badge-pill">Data management</span>
# <span class="badge badge-light badge-pill">Power BI</span>
# <span class="badge badge-light badge-pill">Python</span>
# <span class="badge badge-light badge-pill">R</span>
# <span class="badge badge-light badge-pill">SAS</span>
# <span class="badge badge-light badge-pill">SQL</span>
# <span class="badge badge-light badge-pill">+2</span>
# <br/>
# <span class="badge badge-success badge-pill">Competitive pay</span>
# <span class="badge badge-success badge-pill">Conferences</span>
# <span class="badge badge-success badge-pill">Fitness / gym</span>
# <span class="badge badge-success badge-pill">Health care</span>
# <span class="badge badge-success badge-pill">Insurance</span>
# <span class="badge badge-success badge-pill">+3</span>
# </a>
# </div>
# </div>
# <div class="list-group-item px-2 px-lg-3 py-0">
# <div class="row">
# <div class="col-2 col-sm-1 px-2 py-3">
# <a href="/jobs-at-amica-mutual-insurance-company/" title="Show all open positions at Amica Mutual Insurance Company">
# <img alt="Amica Mutual Insurance Company logo" class="mx-auto my-1 d-block" height="48" loading="lazy" src="/media/cache/39/95/39951b7ffbfd5608fb202f6de1e0ca38.jpg" width="48"/>
# </a>
# <div class="d-flex justify-content-center mt-3">
# <a class="btn-direct-apply text-dark p-1" href="/J24107/apply/" id="24107" rel="nofollow noopener" target="_blank" title="Apply for this job directly on Amica Mutual Insurance Company's career site"><i class="fas fa-edit"></i></a>
# <a class="btn-direct-apply text-dark p-1" href="/job/mark/24107/create/" rel="nofollow" title="Save this job for later application"><i class="fas fa-list-ol"></i></a>
# </div>
# </div>
# <a class="col list-group-item-action px-2 py-3" href="/job/24107-lead-business-intelligence-analyst/" title="View full details of `Lead Business Intelligence Analyst` vacancy">
# <div class="float-right text-right d-inline-block w-25 ml-2">
# <span class="d-block d-md-none text-break job-list-item-location">Lincoln, RI, 02865</span>
# <span class="d-none d-md-block text-break job-list-item-location">Lincoln, RI, 02865</span>
# <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
# <div class="d-block">
# <span class="badge badge-info badge-pill my-md-1 d-md-none">Senior</span>
# <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Senior-level</span>
# </div>
# </div>
# <p class="m-0 text-muted job-list-item-company">Amica Mutual Insurance Company</p>
# <h2 class="h4 mb-1">Lead Business Intelligence Analyst</h2>
# <span class="badge badge-light badge-pill">Business Intelligence</span>
# <span class="badge badge-light badge-pill">Data management</span>
# <span class="badge badge-light badge-pill">KPIs</span>
# <span class="badge badge-light badge-pill">Python</span>
# <span class="badge badge-light badge-pill">R</span>
# <span class="badge badge-light badge-pill">SAS</span>
# <span class="badge badge-light badge-pill">SQL</span>
# <span class="badge badge-light badge-pill">+1</span>
# <br/>
# <span class="badge badge-success badge-pill">Competitive pay</span>
# <span class="badge badge-success badge-pill">Conferences</span>
# <span class="badge badge-success badge-pill">Fitness / gym</span>
# <span class="badge badge-success badge-pill">Flex vacation</span>
# <span class="badge badge-success badge-pill">Health care</span>
# <span class="badge badge-success badge-pill">+4</span>
# </a>
# </div>
# </div>
# <div class="list-group-item px-2 px-lg-3 py-0">
# <div class="row">
# <div class="col-2 col-sm-1 px-2 py-3">
# <a href="/jobs-at-nielsen/" title="Show all open positions at Nielsen">
# <img alt="Nielsen logo" class="mx-auto my-1 d-block" height="48" loading="lazy" src="/media/cache/de/d0/ded0b2c0dc41b8e8637cc335e7b6a5e7.jpg" width="48"/>
# </a>
# <div class="d-flex justify-content-center mt-3">
# <a class="btn-direct-apply text-dark p-1" href="/J26580/apply/" id="26580" rel="nofollow noopener" target="_blank" title="Apply for this job directly on Nielsen's career site"><i class="fas fa-edit"></i></a>
# <a class="btn-direct-apply text-dark p-1" href="/job/mark/26580/create/" rel="nofollow" title="Save this job for later application"><i class="fas fa-list-ol"></i></a>
# </div>
# </div>
# <a class="col list-group-item-action px-2 py-3" href="/job/26580-junior-data-analyst/" title="View full details of `Junior Data Analyst` vacancy">
# <div class="float-right text-right d-inline-block w-25 ml-2">
# <span class="d-block d-md-none text-break job-list-item-location">Poland</span>
# <span class="d-none d-md-block text-break job-list-item-location">Poland</span>
# <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
# <div class="d-block">
# <span class="badge badge-info badge-pill my-md-1 d-md-none">Entry</span>
# <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Entry-level</span>
# </div>
# <div class="d-block">
# <span class="badge badge-success badge-pill d-none d-md-inline-block">USD 30K - 80K *</span>
# <span class="badge badge-success badge-pill d-md-none">USD 30K+ *</span>
# </div>
# </div>
# <p class="m-0 text-muted job-list-item-company">Nielsen</p>
# <h2 class="h4 mb-1">Junior Data Analyst</h2>
# <span class="badge badge-light badge-pill">Consulting</span>
# <span class="badge badge-light badge-pill">Data analysis</span>
# <span class="badge badge-light badge-pill">Econometrics</span>
# <span class="badge badge-light badge-pill">Excel</span>
# <span class="badge badge-light badge-pill">Market research</span>
# <span class="badge badge-light badge-pill">Python</span>
# <span class="badge badge-light badge-pill">R</span>
# <span class="badge badge-light badge-pill">+5</span>
# <br/>
# <span class="badge badge-success badge-pill">Career development</span>
# </a>
# </div>
# </div>
# <div class="list-group-item px-2 px-lg-3 py-0">
# <div class="row">
# <div class="col-2 col-sm-1 px-2 py-3">
# <a href="/jobs-at-athletic-greens/" title="Show all open positions at Athletic Greens">
# <img alt="Athletic Greens logo" class="mx-auto my-1 d-block" height="48" loading="lazy" src="/media/cache/6d/55/6d55b3d5009b61f26b4c9ca80603e2fb.jpg" width="48"/>
# </a>
# <div class="d-flex justify-content-center mt-3">
# <a class="btn-direct-apply text-dark p-1" href="/J26584/apply/" id="26584" rel="nofollow noopener" target="_blank" title="Apply for this job directly on Athletic Greens's career site"><i class="fas fa-edit"></i></a>
# <a class="btn-direct-apply text-dark p-1" href="/job/mark/26584/create/" rel="nofollow" title="Save this job for later application"><i class="fas fa-list-ol"></i></a>
# </div>
# </div>
# <a class="col list-group-item-action px-2 py-3" href="/job/26584-senior-vice-president-data-analytics-bi/" title="View full details of `Senior Vice President, Data Analytics &amp; BI` vacancy">
# <div class="float-right text-right d-inline-block w-25 ml-2">
# <span class="d-block d-md-none text-break job-list-item-location">Los Angeles, California, United …</span>
# <span class="d-none d-md-block text-break job-list-item-location">Los Angeles, California, United States - Remote</span>
# <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
# <div class="d-block">
# <span class="badge badge-info badge-pill my-md-1 d-md-none">Senior</span>
# <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Senior-level</span>
# </div>
# </div>
# <p class="m-0 text-muted job-list-item-company">Athletic Greens</p>
# <h2 class="h4 mb-1">Senior Vice President, Data Analytics &amp; BI</h2>
# <span class="badge badge-light badge-pill">Airflow</span>
# <span class="badge badge-light badge-pill">BigQuery</span>
# <span class="badge badge-light badge-pill">Business Intelligence</span>
# <span class="badge badge-light badge-pill">Data Analytics</span>
# <span class="badge badge-light badge-pill">Data management</span>
# <span class="badge badge-light badge-pill">Data strategy</span>
# <span class="badge badge-light badge-pill">E-commerce</span>
# <span class="badge badge-light badge-pill">+6</span>
# <br/>
# <span class="badge badge-success badge-pill">401(k) matching</span>
# <span class="badge badge-success badge-pill">Flex vacation</span>
# <span class="badge badge-success badge-pill">Gear</span>
# <span class="badge badge-success badge-pill">Health care</span>
# <span class="badge badge-success badge-pill">Home office stipend</span>
# <span class="badge badge-success badge-pill">+5</span>
# </a>
# </div>
# </div>
# <div class="list-group-item px-2 px-lg-3 py-0">
# <div class="row">
# <div class="col-2 col-sm-1 px-2 py-3">
# <a href="/jobs-at-airbnb/" title="Show all open positions at Airbnb">
# <img alt="Airbnb logo" class="mx-auto my-1 d-block" height="48" loading="lazy" src="/media/cache/6b/ba/6bba22fad2cd698715cd02b1239a1819.jpg" width="48"/>
# </a>
# <div class="d-flex justify-content-center mt-3">
# <a class="btn-direct-apply text-dark p-1" href="/J26569/apply/" id="26569" rel="nofollow noopener" target="_blank" title="Apply for this job directly on Airbnb's career site"><i class="fas fa-edit"></i></a>
# <a class="btn-direct-apply text-dark p-1" href="/job/mark/26569/create/" rel="nofollow" title="Save this job for later application"><i class="fas fa-list-ol"></i></a>
# </div>
# </div>
# <a class="col list-group-item-action px-2 py-3" href="/job/26569-staff-analytics-engineer-central-data/" title="View full details of `Staff Analytics Engineer, Central Data` vacancy">
# <div class="float-right text-right d-inline-block w-25 ml-2">
# <span class="d-block d-md-none text-break job-list-item-location">United States</span>
# <span class="d-none d-md-block text-break job-list-item-location">United States</span>
# <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
# <div class="d-block">
# <span class="badge badge-info badge-pill my-md-1 d-md-none">Senior</span>
# <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Senior-level</span>
# </div>
# <div class="d-block">
# <span class="badge badge-success badge-pill d-none d-md-inline-block">USD 180K - 245K</span>
# <span class="badge badge-success badge-pill d-md-none">USD 180K+</span>
# </div>
# </div>
# <p class="m-0 text-muted job-list-item-company">Airbnb</p>
# <h2 class="h4 mb-1">Staff Analytics Engineer, Central Data</h2>
# <span class="badge badge-light badge-pill">Airflow</span>
# <span class="badge badge-light badge-pill">Data analysis</span>
# <span class="badge badge-light badge-pill">Engineering</span>
# <span class="badge badge-light badge-pill">ETL</span>
# <span class="badge badge-light badge-pill">Machine Learning</span>
# <span class="badge badge-light badge-pill">Pipelines</span>
# <span class="badge badge-light badge-pill">Predictive modeling</span>
# <span class="badge badge-light badge-pill">+6</span>
# <br/>
# <span class="badge badge-success badge-pill">Career development</span>
# <span class="badge badge-success badge-pill">Salary bonus</span>
# </a>
# </div>
# </div>
# <div class="list-group-item px-2 px-lg-3 py-0">
# <div class="row">
# <div class="col-2 col-sm-1 px-2 py-3">
# <a href="/jobs-at-tempus/" title="Show all open positions at Tempus">
# <img alt="Tempus logo" class="mx-auto my-1 d-block" height="48" loading="lazy" src="/media/cache/ce/3e/ce3e2833beb0398e8444b6f2dcabf02a.jpg" width="48"/>
# </a>
# <div class="d-flex justify-content-center mt-3">
# <a class="btn-direct-apply text-dark p-1" href="/J26572/apply/" id="26572" rel="nofollow noopener" target="_blank" title="Apply for this job directly on Tempus's career site"><i class="fas fa-edit"></i></a>
# <a class="btn-direct-apply text-dark p-1" href="/job/mark/26572/create/" rel="nofollow" title="Save this job for later application"><i class="fas fa-list-ol"></i></a>
# </div>
# </div>
# <a class="col list-group-item-action px-2 py-3" href="/job/26572-data-analyst-clinical-informatics/" title="View full details of `Data Analyst - Clinical Informatics` vacancy">
# <div class="float-right text-right d-inline-block w-25 ml-2">
# <span class="d-block d-md-none text-break job-list-item-location">Chicago, IL</span>
# <span class="d-none d-md-block text-break job-list-item-location">Chicago, IL</span>
# <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
# <div class="d-block">
# <span class="badge badge-success badge-pill d-none d-md-inline-block">USD 50K - 85K *</span>
# <span class="badge badge-success badge-pill d-md-none">USD 50K+ *</span>
# </div>
# </div>
# <p class="m-0 text-muted job-list-item-company">Tempus</p>
# <h2 class="h4 mb-1">Data Analyst - Clinical Informatics</h2>
# <span class="badge badge-light badge-pill">Data pipelines</span>
# <span class="badge badge-light badge-pill">Pipelines</span>
# <span class="badge badge-light badge-pill">Python</span>
# <span class="badge badge-light badge-pill">SQL</span>
# <br/>
# </a>
# </div>
# </div>
# <div class="list-group-item px-2 px-lg-3 py-0">
# <div class="row">
# <div class="col-2 col-sm-1 px-2 py-3">
# <a href="/jobs-at-adyen/" title="Show all open positions at Adyen">
# <img alt="Adyen logo" class="mx-auto my-1 d-block" height="48" loading="lazy" src="/media/cache/3a/99/3a9928a0aef5b8275d5cd169ea03ddc3.jpg" width="48"/>
# </a>
# <div class="d-flex justify-content-center mt-3">
# <a class="btn-direct-apply text-dark p-1" href="/J26573/apply/" id="26573" rel="nofollow noopener" target="_blank" title="Apply for this job directly on Adyen's career site"><i class="fas fa-edit"></i></a>
# <a class="btn-direct-apply text-dark p-1" href="/job/mark/26573/create/" rel="nofollow" title="Save this job for later application"><i class="fas fa-list-ol"></i></a>
# </div>
# </div>
# <a class="col list-group-item-action px-2 py-3" href="/job/26573-senior-product-data-analytics/" title="View full details of `Senior Product Data Analytics` vacancy">
# <div class="float-right text-right d-inline-block w-25 ml-2">
# <span class="d-block d-md-none text-break job-list-item-location">Sao Paulo</span>
# <span class="d-none d-md-block text-break job-list-item-location">Sao Paulo</span>
# <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
# <div class="d-block">
# <span class="badge badge-info badge-pill my-md-1 d-md-none">Senior</span>
# <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Senior-level</span>
# </div>
# </div>
# <p class="m-0 text-muted job-list-item-company">Adyen</p>
# <h2 class="h4 mb-1">Senior Product Data Analytics</h2>
# <span class="badge badge-light badge-pill">Airflow</span>
# <span class="badge badge-light badge-pill">Big Data</span>
# <span class="badge badge-light badge-pill">Data Analytics</span>
# <span class="badge badge-light badge-pill">Data pipelines</span>
# <span class="badge badge-light badge-pill">Engineering</span>
# <span class="badge badge-light badge-pill">ETL</span>
# <span class="badge badge-light badge-pill">Pipelines</span>
# <span class="badge badge-light badge-pill">+5</span>
# <br/>
# <span class="badge badge-success badge-pill">Startup environment</span>
# </a>
# </div>
# </div>
# <div class="list-group-item px-2 px-lg-3 py-0">
# <div class="row">
# <div class="col-2 col-sm-1 px-2 py-3">
# <a href="/jobs-at-doordash/" title="Show all open positions at DoorDash">
# <img alt="DoorDash logo" class="mx-auto my-1 d-block" height="48" loading="lazy" src="/media/cache/fc/87/fc87cb38476d66ea026815302d94c848.jpg" width="48"/>
# </a>
# <div class="d-flex justify-content-center mt-3">
# <a class="btn-direct-apply text-dark p-1" href="/J26526/apply/" id="26526" rel="nofollow noopener" target="_blank" title="Apply for this job directly on DoorDash's career site"><i class="fas fa-edit"></i></a>
# <a class="btn-direct-apply text-dark p-1" href="/job/mark/26526/create/" rel="nofollow" title="Save this job for later application"><i class="fas fa-list-ol"></i></a>
# </div>
# </div>
# <a class="col list-group-item-action px-2 py-3" href="/job/26526-data-scientist-international-analytics/" title="View full details of `Data Scientist, International Analytics` vacancy">
# <div class="float-right text-right d-inline-block w-25 ml-2">
# <span class="d-block d-md-none text-break job-list-item-location">Toronto, ON</span>
# <span class="d-none d-md-block text-break job-list-item-location">Toronto, ON</span>
# <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
# <div class="d-block">
# <span class="badge badge-info badge-pill my-md-1 d-md-none">Senior</span>
# <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Senior-level</span>
# </div>
# <div class="d-block">
# <span class="badge badge-success badge-pill d-none d-md-inline-block">USD 68K - 135K *</span>
# <span class="badge badge-success badge-pill d-md-none">USD 68K+ *</span>
# </div>
# </div>
# <p class="m-0 text-muted job-list-item-company">DoorDash</p>
# <h2 class="h4 mb-1">Data Scientist, International Analytics</h2>
# <span class="badge badge-light badge-pill">A/B testing</span>
# <span class="badge badge-light badge-pill">Consulting</span>
# <span class="badge badge-light badge-pill">Data Analytics</span>
# <span class="badge badge-light badge-pill">Economics</span>
# <span class="badge badge-light badge-pill">ETL</span>
# <span class="badge badge-light badge-pill">Excel</span>
# <span class="badge badge-light badge-pill">Looker</span>
# <span class="badge badge-light badge-pill">+8</span>
# <br/>
# <span class="badge badge-success badge-pill">Flex vacation</span>
# </a>
# </div>
# </div>
# <div class="list-group-item px-2 px-lg-3 py-0">
# <div class="row">
# <div class="col-2 col-sm-1 px-2 py-3">
# <a href="/jobs-at-archive/" title="Show all open positions at Archive">
# <img alt="Archive logo" class="mx-auto my-1 d-block" height="48" loading="lazy" src="/media/cache/6f/2d/6f2da1f2766f34438b3a4dd78e00470f.jpg" width="48"/>
# </a>
# <div class="d-flex justify-content-center mt-3">
# <a class="btn-direct-apply text-dark p-1" href="/J26575/apply/" id="26575" rel="nofollow noopener" target="_blank" title="Apply for this job directly on Archive's career site"><i class="fas fa-edit"></i></a>
# <a class="btn-direct-apply text-dark p-1" href="/job/mark/26575/create/" rel="nofollow" title="Save this job for later application"><i class="fas fa-list-ol"></i></a>
# </div>
# </div>
# <a class="col list-group-item-action px-2 py-3" href="/job/26575-data-analyst/" title="View full details of `Data Analyst` vacancy">
# <div class="float-right text-right d-inline-block w-25 ml-2">
# <span class="d-block d-md-none text-break job-list-item-location">Remote</span>
# <span class="d-none d-md-block text-break job-list-item-location">Remote</span>
# <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
# <div class="d-block">
# <span class="badge badge-info badge-pill my-md-1 d-md-none">Senior</span>
# <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Senior-level</span>
# </div>
# <div class="d-block">
# <span class="badge badge-success badge-pill d-none d-md-inline-block">USD 50K - 85K *</span>
# <span class="badge badge-success badge-pill d-md-none">USD 50K+ *</span>
# </div>
# </div>
# <p class="m-0 text-muted job-list-item-company">Archive</p>
# <h2 class="h4 mb-1">Data Analyst</h2>
# <span class="badge badge-light badge-pill">Data visualization</span>
# <span class="badge badge-light badge-pill">Looker</span>
# <span class="badge badge-light badge-pill">SQL</span>
# <span class="badge badge-light badge-pill">Tableau</span>
# <br/>
# </a>
# </div>
# </div>
# <div class="list-group-item px-2 px-lg-3 py-0">
# <div class="row">
# <div class="col-2 col-sm-1 px-2 py-3">
# <a href="/jobs-at-koho/" title="Show all open positions at KOHO">
# <img alt="KOHO logo" class="mx-auto my-1 d-block" height="48" loading="lazy" src="/media/cache/d2/d6/d2d6222f2ad1a6e09e27dadc92805b88.jpg" width="48"/>
# </a>
# <div class="d-flex justify-content-center mt-3">
# <a class="btn-direct-apply text-dark p-1" href="/J26570/apply/" id="26570" rel="nofollow noopener" target="_blank" title="Apply for this job directly on KOHO's career site"><i class="fas fa-edit"></i></a>
# <a class="btn-direct-apply text-dark p-1" href="/job/mark/26570/create/" rel="nofollow" title="Save this job for later application"><i class="fas fa-list-ol"></i></a>
# </div>
# </div>
# <a class="col list-group-item-action px-2 py-3" href="/job/26570-analytics-engineer-remote/" title="View full details of `Analytics Engineer - Remote` vacancy">
# <div class="float-right text-right d-inline-block w-25 ml-2">
# <span class="d-block d-md-none text-break job-list-item-location">Canada</span>
# <span class="d-none d-md-block text-break job-list-item-location">Canada</span>
# <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
# <div class="d-block">
# <span class="badge badge-info badge-pill my-md-1 d-md-none">Senior</span>
# <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Senior-level</span>
# </div>
# </div>
# <p class="m-0 text-muted job-list-item-company">KOHO</p>
# <h2 class="h4 mb-1">Analytics Engineer - Remote</h2>
# <span class="badge badge-light badge-pill">Data Analytics</span>
# <span class="badge badge-light badge-pill">Engineering</span>
# <span class="badge badge-light badge-pill">Machine Learning</span>
# <span class="badge badge-light badge-pill">Python</span>
# <span class="badge badge-light badge-pill">SQL</span>
# <span class="badge badge-light badge-pill">Testing</span>
# <br/>
# <span class="badge badge-success badge-pill">Home office stipend</span>
# </a>
# </div>
# </div>
# <div class="list-group-item px-2 px-lg-3 py-0">
# <div class="row">
# <div class="col-2 col-sm-1 px-2 py-3">
# <a href="/jobs-at-sosafe/" title="Show all open positions at SoSafe">
# <img alt="SoSafe logo" class="mx-auto my-1 d-block" height="48" loading="lazy" src="/media/cache/62/50/62508571fb1dae6a176f8550cec711d9.jpg" width="48"/>
# </a>
# <div class="d-flex justify-content-center mt-3">
# <a class="btn-direct-apply text-dark p-1" href="/J26541/apply/" id="26541" rel="nofollow noopener" target="_blank" title="Apply for this job directly on SoSafe's career site"><i class="fas fa-edit"></i></a>
# <a class="btn-direct-apply text-dark p-1" href="/job/mark/26541/create/" rel="nofollow" title="Save this job for later application"><i class="fas fa-list-ol"></i></a>
# </div>
# </div>
# <a class="col list-group-item-action px-2 py-3" href="/job/26541-data-analyst-bi-developer-mfd/" title="View full details of `Data Analyst / BI Developer (m/f/d)` vacancy">
# <div class="float-right text-right d-inline-block w-25 ml-2">
# <span class="d-block d-md-none text-break job-list-item-location">Remote</span>
# <span class="d-none d-md-block text-break job-list-item-location">Remote</span>
# <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
# <div class="d-block">
# <span class="badge badge-info badge-pill my-md-1 d-md-none">Senior</span>
# <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Senior-level</span>
# </div>
# </div>
# <p class="m-0 text-muted job-list-item-company">SoSafe</p>
# <h2 class="h4 mb-1">Data Analyst / BI Developer (m/f/d)</h2>
# <span class="badge badge-light badge-pill">Business Intelligence</span>
# <span class="badge badge-light badge-pill">Data analysis</span>
# <span class="badge badge-light badge-pill">Data visualization</span>
# <span class="badge badge-light badge-pill">KPIs</span>
# <span class="badge badge-light badge-pill">Power BI</span>
# <span class="badge badge-light badge-pill">Python</span>
# <span class="badge badge-light badge-pill">Security</span>
# <span class="badge badge-light badge-pill">+3</span>
# <br/>
# <span class="badge badge-success badge-pill">Career development</span>
# <span class="badge badge-success badge-pill">Competitive pay</span>
# <span class="badge badge-success badge-pill">Flex vacation</span>
# <span class="badge badge-success badge-pill">Lunch / meals</span>
# <span class="badge badge-success badge-pill">Salary bonus</span>
# <span class="badge badge-success badge-pill">+1</span>
# </a>
# </div>
# </div>
# <div class="list-group-item px-2 px-lg-3 py-0">
# <div class="row">
# <div class="col-2 col-sm-1 px-2 py-3">
# <a href="/jobs-at-mintel/" title="Show all open positions at Mintel">
# <img alt="Mintel logo" class="mx-auto my-1 d-block" height="48" loading="lazy" src="/media/cache/03/ee/03ee755a9fb02e10654b60bcf91a2c27.jpg" width="48"/>
# </a>
# <div class="d-flex justify-content-center mt-3">
# <a class="btn-direct-apply text-dark p-1" href="/J26579/apply/" id="26579" rel="nofollow noopener" target="_blank" title="Apply for this job directly on Mintel's career site"><i class="fas fa-edit"></i></a>
# <a class="btn-direct-apply text-dark p-1" href="/job/mark/26579/create/" rel="nofollow" title="Save this job for later application"><i class="fas fa-list-ol"></i></a>
# </div>
# </div>
# <a class="col list-group-item-action px-2 py-3" href="/job/26579-data-analytics-lead/" title="View full details of `Data Analytics Lead` vacancy">
# <div class="float-right text-right d-inline-block w-25 ml-2">
# <span class="d-block d-md-none text-break job-list-item-location">London</span>
# <span class="d-none d-md-block text-break job-list-item-location">London</span>
# <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
# </div>
# <p class="m-0 text-muted job-list-item-company">Mintel</p>
# <h2 class="h4 mb-1">Data Analytics Lead</h2>
# <span class="badge badge-light badge-pill">Consulting</span>
# <span class="badge badge-light badge-pill">Data Analytics</span>
# <span class="badge badge-light badge-pill">Looker</span>
# <span class="badge badge-light badge-pill">Market research</span>
# <span class="badge badge-light badge-pill">Power BI</span>
# <span class="badge badge-light badge-pill">Research</span>
# <span class="badge badge-light badge-pill">SQL</span>
# <span class="badge badge-light badge-pill">+1</span>
# <br/>
# <span class="badge badge-success badge-pill">Career development</span>
# <span class="badge badge-success badge-pill">Flex vacation</span>
# </a>
# </div>
# </div>
# <div class="list-group-item px-2 px-lg-3 py-0">
# <div class="row">
# <div class="col-2 col-sm-1 px-2 py-3">
# <a href="/jobs-at-fitxr/" title="Show all open positions at FitXR">
# <img alt="FitXR logo" class="mx-auto my-1 d-block" height="48" loading="lazy" src="/media/cache/45/72/4572700f92925420c5e1df1d5e81d637.jpg" width="48"/>
# </a>
# <div class="d-flex justify-content-center mt-3">
# <a class="btn-direct-apply text-dark p-1" href="/J26583/apply/" id="26583" rel="nofollow noopener" target="_blank" title="Apply for this job directly on FitXR's career site"><i class="fas fa-edit"></i></a>
# <a class="btn-direct-apply text-dark p-1" href="/job/mark/26583/create/" rel="nofollow" title="Save this job for later application"><i class="fas fa-list-ol"></i></a>
# </div>
# </div>
# <a class="col list-group-item-action px-2 py-3" href="/job/26583-senior-data-analyst/" title="View full details of `Senior Data Analyst` vacancy">
# <div class="float-right text-right d-inline-block w-25 ml-2">
# <span class="d-block d-md-none text-break job-list-item-location">London, England, United Kingdom …</span>
# <span class="d-none d-md-block text-break job-list-item-location">London, England, United Kingdom - Remote</span>
# <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
# <div class="d-block">
# <span class="badge badge-info badge-pill my-md-1 d-md-none">Mid</span>
# <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Mid-level</span>
# </div>
# <div class="d-block">
# <span class="badge badge-success badge-pill d-none d-md-inline-block">USD 51K - 90K *</span>
# <span class="badge badge-success badge-pill d-md-none">USD 51K+ *</span>
# </div>
# </div>
# <p class="m-0 text-muted job-list-item-company">FitXR</p>
# <h2 class="h4 mb-1">Senior Data Analyst</h2>
# <span class="badge badge-light badge-pill">A/B testing</span>
# <span class="badge badge-light badge-pill">BigQuery</span>
# <span class="badge badge-light badge-pill">DevOps</span>
# <span class="badge badge-light badge-pill">Engineering</span>
# <span class="badge badge-light badge-pill">Julia</span>
# <span class="badge badge-light badge-pill">Python</span>
# <span class="badge badge-light badge-pill">R</span>
# <span class="badge badge-light badge-pill">+2</span>
# <br/>
# <span class="badge badge-success badge-pill">Career development</span>
# <span class="badge badge-success badge-pill">Competitive pay</span>
# <span class="badge badge-success badge-pill">Equity</span>
# <span class="badge badge-success badge-pill">Flex vacation</span>
# <span class="badge badge-success badge-pill">Gear</span>
# <span class="badge badge-success badge-pill">+3</span>
# </a>
# </div>
# </div>
# <div class="list-group-item px-2 px-lg-3 py-0">
# <div class="row">
# <div class="col-2 col-sm-1 px-2 py-3">
# <a href="/jobs-at-lingoace/" title="Show all open positions at LingoAce">
# <img alt="LingoAce logo" class="mx-auto my-1 d-block" height="48" loading="lazy" src="/media/cache/0f/0e/0f0ed92ec77c049e2ad10698ad549c75.jpg" width="48"/>
# </a>
# <div class="d-flex justify-content-center mt-3">
# <a class="btn-direct-apply text-dark p-1" href="/J26582/apply/" id="26582" rel="nofollow noopener" target="_blank" title="Apply for this job directly on LingoAce's career site"><i class="fas fa-edit"></i></a>
# <a class="btn-direct-apply text-dark p-1" href="/job/mark/26582/create/" rel="nofollow" title="Save this job for later application"><i class="fas fa-list-ol"></i></a>
# </div>
# </div>
# <a class="col list-group-item-action px-2 py-3" href="/job/26582-senior-data-analyst-thailand/" title="View full details of `Senior Data Analyst - Thailand` vacancy">
# <div class="float-right text-right d-inline-block w-25 ml-2">
# <span class="d-block d-md-none text-break job-list-item-location">Bangkok, Bangkok, Thailand</span>
# <span class="d-none d-md-block text-break job-list-item-location">Bangkok, Bangkok, Thailand</span>
# <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
# <div class="d-block">
# <span class="badge badge-info badge-pill my-md-1 d-md-none">Mid</span>
# <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Mid-level</span>
# </div>
# <div class="d-block">
# <span class="badge badge-success badge-pill d-none d-md-inline-block">USD 51K - 90K *</span>
# <span class="badge badge-success badge-pill d-md-none">USD 51K+ *</span>
# </div>
# </div>
# <p class="m-0 text-muted job-list-item-company">LingoAce</p>
# <h2 class="h4 mb-1">Senior Data Analyst - Thailand</h2>
# <span class="badge badge-light badge-pill">Data Analytics</span>
# <span class="badge badge-light badge-pill">Economics</span>
# <span class="badge badge-light badge-pill">Statistics</span>
# <br/>
# <span class="badge badge-success badge-pill">Startup environment</span>
# </a>
# </div>
# </div>
# <div class="list-group-item px-2 px-lg-3 py-0">
# <div class="row">
# <div class="col-2 col-sm-1 px-2 py-3">
# <a href="/jobs-at-wpp/" title="Show all open positions at WPP">
# <img alt="WPP logo" class="mx-auto my-1 d-block" height="48" loading="lazy" src="/media/cache/53/42/53420b3557ad17fcf92350447316fc5b.jpg" width="48"/>
# </a>
# <div class="d-flex justify-content-center mt-3">
# <a class="btn-direct-apply text-dark p-1" href="/J26576/apply/" id="26576" rel="nofollow noopener" target="_blank" title="Apply for this job directly on WPP's career site"><i class="fas fa-edit"></i></a>
# <a class="btn-direct-apply text-dark p-1" href="/job/mark/26576/create/" rel="nofollow" title="Save this job for later application"><i class="fas fa-list-ol"></i></a>
# </div>
# </div>
# <a class="col list-group-item-action px-2 py-3" href="/job/26576-financial-data-analyst-latam-remote/" title="View full details of `Financial Data Analyst - LATAM- REMOTE` vacancy">
# <div class="float-right text-right d-inline-block w-25 ml-2">
# <span class="d-block d-md-none text-break job-list-item-location">Mexico City</span>
# <span class="d-none d-md-block text-break job-list-item-location">Mexico City</span>
# <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
# <div class="d-block">
# <span class="badge badge-info badge-pill my-md-1 d-md-none">Senior</span>
# <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Senior-level</span>
# </div>
# <div class="d-block">
# <span class="badge badge-success badge-pill d-none d-md-inline-block">USD 50K - 85K *</span>
# <span class="badge badge-success badge-pill d-md-none">USD 50K+ *</span>
# </div>
# </div>
# <p class="m-0 text-muted job-list-item-company">WPP</p>
# <h2 class="h4 mb-1">Financial Data Analyst - LATAM- REMOTE</h2>
# <span class="badge badge-light badge-pill">Consulting</span>
# <span class="badge badge-light badge-pill">ETL</span>
# <span class="badge badge-light badge-pill">Finance</span>
# <span class="badge badge-light badge-pill">Oracle</span>
# <br/>
# </a>
# </div>
# </div>
# <div class="list-group-item px-2 px-lg-3 py-0">
# <div class="row">
# <div class="col-2 col-sm-1 px-2 py-3">
# <a href="/jobs-at-deepsource/" title="Show all open positions at DeepSource">
# <img alt="DeepSource logo" class="mx-auto my-1 d-block" height="48" loading="lazy" src="/media/cache/dc/8a/dc8a3d793c8b59129c0a858886abd226.jpg" width="48"/>
# </a>
# <div class="d-flex justify-content-center mt-3">
# <a class="btn-direct-apply text-dark p-1" href="/J26542/apply/" id="26542" rel="nofollow noopener" target="_blank" title="Apply for this job directly on DeepSource's career site"><i class="fas fa-edit"></i></a>
# <a class="btn-direct-apply text-dark p-1" href="/job/mark/26542/create/" rel="nofollow" title="Save this job for later application"><i class="fas fa-list-ol"></i></a>
# </div>
# </div>
# <a class="col list-group-item-action px-2 py-3" href="/job/26542-research-engineer-static-analysis-web3/" title="View full details of `Research Engineer, Static Analysis - Web3` vacancy">
# <div class="float-right text-right d-inline-block w-25 ml-2">
# <span class="d-block d-md-none text-break job-list-item-location">Bangalore, India</span>
# <span class="d-none d-md-block text-break job-list-item-location">Bangalore, India</span>
# <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
# <div class="d-block">
# <span class="badge badge-info badge-pill my-md-1 d-md-none">Senior</span>
# <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Senior-level</span>
# </div>
# </div>
# <p class="m-0 text-muted job-list-item-company">DeepSource</p>
# <h2 class="h4 mb-1">Research Engineer, Static Analysis - Web3</h2>
# <span class="badge badge-light badge-pill">Engineering</span>
# <span class="badge badge-light badge-pill">Research</span>
# <span class="badge badge-light badge-pill">Testing</span>
# <br/>
# </a>
# </div>
# </div>
# <div class="list-group-item px-2 px-lg-3 py-0">
# <div class="row">
# <div class="col-2 col-sm-1 px-2 py-3">
# <a href="/jobs-at-argo-group/" title="Show all open positions at Argo Group">
# <img alt="Argo Group logo" class="mx-auto my-1 d-block" height="48" loading="lazy" src="/media/cache/59/92/5992574f929915fb8a3b6488168b481d.jpg" width="48"/>
# </a>
# <div class="d-flex justify-content-center mt-3">
# <a class="btn-direct-apply text-dark p-1" href="/J26574/apply/" id="26574" rel="nofollow noopener" target="_blank" title="Apply for this job directly on Argo Group's career site"><i class="fas fa-edit"></i></a>
# <a class="btn-direct-apply text-dark p-1" href="/job/mark/26574/create/" rel="nofollow" title="Save this job for later application"><i class="fas fa-list-ol"></i></a>
# </div>
# </div>
# <a class="col list-group-item-action px-2 py-3" href="/job/26574-data-analyst-business-delivery-services/" title="View full details of `Data Analyst, Business Delivery Services` vacancy">
# <div class="float-right text-right d-inline-block w-25 ml-2">
# <span class="d-block d-md-none text-break job-list-item-location">Remote</span>
# <span class="d-none d-md-block text-break job-list-item-location">Remote</span>
# <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
# <div class="d-block">
# <span class="badge badge-info badge-pill my-md-1 d-md-none">Senior</span>
# <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Senior-level</span>
# </div>
# <div class="d-block">
# <span class="badge badge-success badge-pill d-none d-md-inline-block">USD 80K - 92K</span>
# <span class="badge badge-success badge-pill d-md-none">USD 80K+</span>
# </div>
# </div>
# <p class="m-0 text-muted job-list-item-company">Argo Group</p>
# <h2 class="h4 mb-1">Data Analyst, Business Delivery Services</h2>
# <span class="badge badge-light badge-pill">Agile</span>
# <span class="badge badge-light badge-pill">Data analysis</span>
# <span class="badge badge-light badge-pill">Data Mining</span>
# <span class="badge badge-light badge-pill">Excel</span>
# <span class="badge badge-light badge-pill">Python</span>
# <span class="badge badge-light badge-pill">SQL</span>
# <span class="badge badge-light badge-pill">Statistics</span>
# <br/>
# <span class="badge badge-success badge-pill">401(k) matching</span>
# <span class="badge badge-success badge-pill">Career development</span>
# <span class="badge badge-success badge-pill">Competitive pay</span>
# <span class="badge badge-success badge-pill">Equity</span>
# <span class="badge badge-success badge-pill">Flex hours</span>
# <span class="badge badge-success badge-pill">+9</span>
# </a>
# </div>
# </div>
# <div class="list-group-item px-2 px-lg-3 py-0">
# <div class="row">
# <div class="col-2 col-sm-1 px-2 py-3">
# <a href="/jobs-at-horangi-cyber-security/" title="Show all open positions at Horangi Cyber Security">
# <img alt="Horangi Cyber Security logo" class="mx-auto my-1 d-block" height="48" loading="lazy" src="/media/cache/50/5a/505a30b6c4bd03740a5ed9ce0a82ac26.jpg" width="48"/>
# </a>
# <div class="d-flex justify-content-center mt-3">
# <a class="btn-direct-apply text-dark p-1" href="/J26581/apply/" id="26581" rel="nofollow noopener" target="_blank" title="Apply for this job directly on Horangi Cyber Security's career site"><i class="fas fa-edit"></i></a>
# <a class="btn-direct-apply text-dark p-1" href="/job/mark/26581/create/" rel="nofollow" title="Save this job for later application"><i class="fas fa-list-ol"></i></a>
# </div>
# </div>
# <a class="col list-group-item-action px-2 py-3" href="/job/26581-data-analyst/" title="View full details of `Data Analyst` vacancy">
# <div class="float-right text-right d-inline-block w-25 ml-2">
# <span class="d-block d-md-none text-break job-list-item-location">Jakarta</span>
# <span class="d-none d-md-block text-break job-list-item-location">Jakarta</span>
# <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
# <div class="d-block">
# <span class="badge badge-info badge-pill my-md-1 d-md-none">Senior</span>
# <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Senior-level</span>
# </div>
# <div class="d-block">
# <span class="badge badge-success badge-pill d-none d-md-inline-block">USD 50K - 85K *</span>
# <span class="badge badge-success badge-pill d-md-none">USD 50K+ *</span>
# </div>
# </div>
# <p class="m-0 text-muted job-list-item-company">Horangi Cyber Security</p>
# <h2 class="h4 mb-1">Data Analyst</h2>
# <span class="badge badge-light badge-pill">Agile</span>
# <span class="badge badge-light badge-pill">AWS</span>
# <span class="badge badge-light badge-pill">Consulting</span>
# <span class="badge badge-light badge-pill">Data visualization</span>
# <span class="badge badge-light badge-pill">Docker</span>
# <span class="badge badge-light badge-pill">Economics</span>
# <span class="badge badge-light badge-pill">Engineering</span>
# <span class="badge badge-light badge-pill">+10</span>
# <br/>
# <span class="badge badge-success badge-pill">Team events</span>
# </a>
# </div>
# </div>
# <div class="list-group-item px-2 px-lg-3 py-0">
# <div class="row">
# <div class="col-2 col-sm-1 px-2 py-3">
# <a href="/jobs-at-nuvei/" title="Show all open positions at Nuvei">
# <img alt="Nuvei logo" class="mx-auto my-1 d-block" height="48" loading="lazy" src="/media/cache/e9/bd/e9bdb6b75d75ccdd5fd77caadb705061.jpg" width="48"/>
# </a>
# <div class="d-flex justify-content-center mt-3">
# <a class="btn-direct-apply text-dark p-1" href="/J26585/apply/" id="26585" rel="nofollow noopener" target="_blank" title="Apply for this job directly on Nuvei's career site"><i class="fas fa-edit"></i></a>
# <a class="btn-direct-apply text-dark p-1" href="/job/mark/26585/create/" rel="nofollow" title="Save this job for later application"><i class="fas fa-list-ol"></i></a>
# </div>
# </div>
# <a class="col list-group-item-action px-2 py-3" href="/job/26585-compliance-data-analyst/" title="View full details of `Compliance Data Analyst` vacancy">
# <div class="float-right text-right d-inline-block w-25 ml-2">
# <span class="d-block d-md-none text-break job-list-item-location">Scottsdale, Arizona, United States …</span>
# <span class="d-none d-md-block text-break job-list-item-location">Scottsdale, Arizona, United States - Remote</span>
# <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
# <div class="d-block">
# <span class="badge badge-info badge-pill my-md-1 d-md-none">Entry</span>
# <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Entry-level</span>
# </div>
# <div class="d-block">
# <span class="badge badge-success badge-pill d-none d-md-inline-block">USD 30K - 80K *</span>
# <span class="badge badge-success badge-pill d-md-none">USD 30K+ *</span>
# </div>
# </div>
# <p class="m-0 text-muted job-list-item-company">Nuvei</p>
# <h2 class="h4 mb-1">Compliance Data Analyst</h2>
# <span class="badge badge-light badge-pill">Data analysis</span>
# <span class="badge badge-light badge-pill">Data Mining</span>
# <br/>
# <span class="badge badge-success badge-pill">401(k) matching</span>
# <span class="badge badge-success badge-pill">Health care</span>
# <span class="badge badge-success badge-pill">Yoga</span>
# </a>
# </div>
# </div>
# <div class="list-group-item px-2 px-lg-3 py-0">
# <div class="row">
# <div class="col-2 col-sm-1 px-2 py-3">
# <a href="/jobs-at-trustly/" title="Show all open positions at Trustly">
# <img alt="Trustly logo" class="mx-auto my-1 d-block" height="48" loading="lazy" src="/media/cache/c6/1c/c61c875a5f55302b67c5953f0e13c6e1.jpg" width="48"/>
# </a>
# <div class="d-flex justify-content-center mt-3">
# <a class="btn-direct-apply text-dark p-1" href="/J26578/apply/" id="26578" rel="nofollow noopener" target="_blank" title="Apply for this job directly on Trustly's career site"><i class="fas fa-edit"></i></a>
# <a class="btn-direct-apply text-dark p-1" href="/job/mark/26578/create/" rel="nofollow" title="Save this job for later application"><i class="fas fa-list-ol"></i></a>
# </div>
# </div>
# <a class="col list-group-item-action px-2 py-3" href="/job/26578-senior-data-analyst/" title="View full details of `Senior Data Analyst` vacancy">
# <div class="float-right text-right d-inline-block w-25 ml-2">
# <span class="d-block d-md-none text-break job-list-item-location">Vitoria, Brazil or Remote, …</span>
# <span class="d-none d-md-block text-break job-list-item-location">Vitoria, Brazil or Remote, Brazil</span>
# <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
# <div class="d-block">
# <span class="badge badge-info badge-pill my-md-1 d-md-none">Senior</span>
# <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Senior-level</span>
# </div>
# <div class="d-block">
# <span class="badge badge-success badge-pill d-none d-md-inline-block">USD 50K - 85K *</span>
# <span class="badge badge-success badge-pill d-md-none">USD 50K+ *</span>
# </div>
# </div>
# <p class="m-0 text-muted job-list-item-company">Trustly</p>
# <h2 class="h4 mb-1">Senior Data Analyst</h2>
# <span class="badge badge-light badge-pill">AWS</span>
# <span class="badge badge-light badge-pill">Banking</span>
# <span class="badge badge-light badge-pill">Big Data</span>
# <span class="badge badge-light badge-pill">Data Analytics</span>
# <span class="badge badge-light badge-pill">Data Mining</span>
# <span class="badge badge-light badge-pill">Data pipelines</span>
# <span class="badge badge-light badge-pill">Engineering</span>
# <span class="badge badge-light badge-pill">+7</span>
# <br/>
# <span class="badge badge-success badge-pill">Career development</span>
# <span class="badge badge-success badge-pill">Flex hours</span>
# <span class="badge badge-success badge-pill">Flex vacation</span>
# <span class="badge badge-success badge-pill">Health care</span>
# <span class="badge badge-success badge-pill">Home office stipend</span>
# <span class="badge badge-success badge-pill">+5</span>
# </a>
# </div>
# </div>
# <div class="list-group-item px-2 px-lg-3 py-0">
# <div class="row">
# <div class="col-2 col-sm-1 px-2 py-3">
# <a href="/jobs-at-argo-group/" title="Show all open positions at Argo Group">
# <img alt="Argo Group logo" class="mx-auto my-1 d-block" height="48" loading="lazy" src="/media/cache/59/92/5992574f929915fb8a3b6488168b481d.jpg" width="48"/>
# </a>
# <div class="d-flex justify-content-center mt-3">
# <a class="btn-direct-apply text-dark p-1" href="/J26577/apply/" id="26577" rel="nofollow noopener" target="_blank" title="Apply for this job directly on Argo Group's career site"><i class="fas fa-edit"></i></a>
# <a class="btn-direct-apply text-dark p-1" href="/job/mark/26577/create/" rel="nofollow" title="Save this job for later application"><i class="fas fa-list-ol"></i></a>
# </div>
# </div>
# <a class="col list-group-item-action px-2 py-3" href="/job/26577-technical-data-analyst/" title="View full details of `Technical Data Analyst` vacancy">
# <div class="float-right text-right d-inline-block w-25 ml-2">
# <span class="d-block d-md-none text-break job-list-item-location">Remote</span>
# <span class="d-none d-md-block text-break job-list-item-location">Remote</span>
# <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
# <div class="d-block">
# <span class="badge badge-info badge-pill my-md-1 d-md-none">Senior</span>
# <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Senior-level</span>
# </div>
# <div class="d-block">
# <span class="badge badge-success badge-pill d-none d-md-inline-block">USD 90K - 108K</span>
# <span class="badge badge-success badge-pill d-md-none">USD 90K+</span>
# </div>
# </div>
# <p class="m-0 text-muted job-list-item-company">Argo Group</p>
# <h2 class="h4 mb-1">Technical Data Analyst</h2>
# <span class="badge badge-light badge-pill">Agile</span>
# <span class="badge badge-light badge-pill">Data Mining</span>
# <span class="badge badge-light badge-pill">Excel</span>
# <span class="badge badge-light badge-pill">MS SQL</span>
# <span class="badge badge-light badge-pill">Oracle</span>
# <span class="badge badge-light badge-pill">Power BI</span>
# <span class="badge badge-light badge-pill">Snowflake</span>
# <span class="badge badge-light badge-pill">+1</span>
# <br/>
# <span class="badge badge-success badge-pill">401(k) matching</span>
# <span class="badge badge-success badge-pill">Career development</span>
# <span class="badge badge-success badge-pill">Competitive pay</span>
# <span class="badge badge-success badge-pill">Equity</span>
# ...
# <img alt="Wonolo logo" class="mx-auto my-1 d-block" height="48" loading="lazy" src="/media/cache/c1/d1/c1d1241f0d274431e54838b16ab3c6ad.jpg" width="48"/>
# </a>
# <div class="d-flex justify-content-center mt-3">
# <a class="btn-direct-apply text-dark p-1" href="/J26118/apply/" id="26118" rel="nofollow noopener" target="_blank" title="Apply for this job directly on Wonolo's career site"><i class="fas fa-edit"></i></a>
# <a class="btn-direct-apply text-dark p-1" href="/job/mark/26118/create/" rel="nofollow" title="Save this job for later application"><i class="fas fa-list-ol"></i></a>
# </div>
# </div>
# <a class="col list-group-item-action px-2 py-3" href="/job/26118-data-analytics-engineer-co-op-fall-2022/" title="View full details of `Data Analytics Engineer Co-op - Fall 2022` vacancy">
# <div class="float-right text-right d-inline-block w-25 ml-2">
# <span class="d-block d-md-none text-break job-list-item-location">Canada, Remote</span>
# <span class="d-none d-md-block text-break job-list-item-location">Canada, Remote</span>
# <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
# </div>
# <p class="m-0 text-muted job-list-item-company">Wonolo</p>
# <h2 class="h4 mb-1">Data Analytics Engineer Co-op - Fall 2022</h2>
# <span class="badge badge-light badge-pill">CAD</span>
# <span class="badge badge-light badge-pill">Data Analytics</span>
# <span class="badge badge-light badge-pill">Data pipelines</span>
# <span class="badge badge-light badge-pill">Engineering</span>
# <span class="badge badge-light badge-pill">ETL</span>
# <span class="badge badge-light badge-pill">Pipelines</span>
# <span class="badge badge-light badge-pill">Python</span>
# <span class="badge badge-light badge-pill">+1</span>
# <br/>
# <span class="badge badge-success badge-pill">Career development</span>
# <span class="badge badge-success badge-pill">Competitive pay</span>
# <span class="badge badge-success badge-pill">Equity</span>
# <span class="badge badge-success badge-pill">Flex hours</span>
# <span class="badge badge-success badge-pill">Startup environment</span>
# <span class="badge badge-success badge-pill">+2</span>
# </a>
# </div>
# </div>
# <div class="list-group-item px-2 px-lg-3 py-0">
# <div class="row">
# <div class="col-2 col-sm-1 px-2 py-3">
# <a href="/jobs-at-quantium/" title="Show all open positions at Quantium">
# <img alt="Quantium logo" class="mx-auto my-1 d-block" height="48" loading="lazy" src="/media/cache/f0/e0/f0e03ad36641a363f818938e2fb07ca0.jpg" width="48"/>
# </a>
# <div class="d-flex justify-content-center mt-3">
# <a class="btn-direct-apply text-dark p-1" href="/J26111/apply/" id="26111" rel="nofollow noopener" target="_blank" title="Apply for this job directly on Quantium's career site"><i class="fas fa-edit"></i></a>
# <a class="btn-direct-apply text-dark p-1" href="/job/mark/26111/create/" rel="nofollow" title="Save this job for later application"><i class="fas fa-list-ol"></i></a>
# </div>
# </div>
# <a class="col list-group-item-action px-2 py-3" href="/job/26111-lead-analyst-data-management/" title="View full details of `Lead Analyst, Data Management` vacancy">
# <div class="float-right text-right d-inline-block w-25 ml-2">
# <span class="d-block d-md-none text-break job-list-item-location">Sydney, New South Wales, …</span>
# <span class="d-none d-md-block text-break job-list-item-location">Sydney, New South Wales, Australia</span>
# <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
# <div class="d-block">
# <span class="badge badge-info badge-pill my-md-1 d-md-none">Executive</span>
# <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Executive-level</span>
# </div>
# </div>
# <p class="m-0 text-muted job-list-item-company">Quantium</p>
# <h2 class="h4 mb-1">Lead Analyst, Data Management</h2>
# <span class="badge badge-light badge-pill">Agile</span>
# <span class="badge badge-light badge-pill">Big Data</span>
# <span class="badge badge-light badge-pill">Consulting</span>
# <span class="badge badge-light badge-pill">Data analysis</span>
# <span class="badge badge-light badge-pill">Data Analytics</span>
# <span class="badge badge-light badge-pill">Data management</span>
# <span class="badge badge-light badge-pill">Engineering</span>
# <span class="badge badge-light badge-pill">+4</span>
# <br/>
# <span class="badge badge-success badge-pill">Career development</span>
# <span class="badge badge-success badge-pill">Startup environment</span>
# <span class="badge badge-success badge-pill">Team events</span>
# </a>
# </div>
# </div>
# <div class="list-group-item px-2 px-lg-3 py-0">
# <div class="row">
# <div class="col-2 col-sm-1 px-2 py-3">
# <a href="/jobs-at-coupang/" title="Show all open positions at Coupang">
# <img alt="Coupang logo" class="mx-auto my-1 d-block" height="48" loading="lazy" src="/media/cache/23/12/2312ea7afa0dacf6f4b8babc85653d46.jpg" width="48"/>
# </a>
# <div class="d-flex justify-content-center mt-3">
# <a class="btn-direct-apply text-dark p-1" href="/J26114/apply/" id="26114" rel="nofollow noopener" target="_blank" title="Apply for this job directly on Coupang's career site"><i class="fas fa-edit"></i></a>
# <a class="btn-direct-apply text-dark p-1" href="/job/mark/26114/create/" rel="nofollow" title="Save this job for later application"><i class="fas fa-list-ol"></i></a>
# </div>
# </div>
# <a class="col list-group-item-action px-2 py-3" href="/job/26114-sr-data-analyst-cmg-analytics/" title="View full details of `Sr. Data Analyst (CMG Analytics)` vacancy">
# <div class="float-right text-right d-inline-block w-25 ml-2">
# <span class="d-block d-md-none text-break job-list-item-location">Seoul, South Korea</span>
# <span class="d-none d-md-block text-break job-list-item-location">Seoul, South Korea</span>
# <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
# <div class="d-block">
# <span class="badge badge-info badge-pill my-md-1 d-md-none">Senior</span>
# <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Senior-level</span>
# </div>
# <div class="d-block">
# <span class="badge badge-success badge-pill d-none d-md-inline-block">USD 50K - 85K *</span>
# <span class="badge badge-success badge-pill d-md-none">USD 50K+ *</span>
# </div>
# </div>
# <p class="m-0 text-muted job-list-item-company">Coupang</p>
# <h2 class="h4 mb-1">Sr. Data Analyst (CMG Analytics)</h2>
# <span class="badge badge-light badge-pill">Airflow</span>
# <span class="badge badge-light badge-pill">E-commerce</span>
# <span class="badge badge-light badge-pill">Looker</span>
# <span class="badge badge-light badge-pill">Power BI</span>
# <span class="badge badge-light badge-pill">Python</span>
# <span class="badge badge-light badge-pill">Qlik</span>
# <span class="badge badge-light badge-pill">R</span>
# <span class="badge badge-light badge-pill">+2</span>
# <br/>
# </a>
# </div>
# </div>
# <div class="list-group-item px-2 px-lg-3 py-0">
# <div class="row">
# <div class="col-2 col-sm-1 px-2 py-3">
# <a href="/jobs-at-clari/" title="Show all open positions at Clari">
# <img alt="Clari logo" class="mx-auto my-1 d-block" height="48" loading="lazy" src="/media/cache/0e/c1/0ec1ac3db7ad44c9bcc3c61381b91f8a.jpg" width="48"/>
# </a>
# <div class="d-flex justify-content-center mt-3">
# <a class="btn-direct-apply text-dark p-1" href="/J26117/apply/" id="26117" rel="nofollow noopener" target="_blank" title="Apply for this job directly on Clari's career site"><i class="fas fa-edit"></i></a>
# <a class="btn-direct-apply text-dark p-1" href="/job/mark/26117/create/" rel="nofollow" title="Save this job for later application"><i class="fas fa-list-ol"></i></a>
# </div>
# </div>
# <a class="col list-group-item-action px-2 py-3" href="/job/26117-sr-data-analyst-marketing/" title="View full details of `Sr. Data Analyst, Marketing` vacancy">
# <div class="float-right text-right d-inline-block w-25 ml-2">
# <span class="d-block d-md-none text-break job-list-item-location">Seattle, WA</span>
# <span class="d-none d-md-block text-break job-list-item-location">Seattle, WA</span>
# <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
# <div class="d-block">
# <span class="badge badge-info badge-pill my-md-1 d-md-none">Senior</span>
# <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Senior-level</span>
# </div>
# <div class="d-block">
# <span class="badge badge-success badge-pill d-none d-md-inline-block">USD 50K - 85K *</span>
# <span class="badge badge-success badge-pill d-md-none">USD 50K+ *</span>
# </div>
# </div>
# <p class="m-0 text-muted job-list-item-company">Clari</p>
# <h2 class="h4 mb-1">Sr. Data Analyst, Marketing</h2>
# <span class="badge badge-light badge-pill">A/B testing</span>
# <span class="badge badge-light badge-pill">Consulting</span>
# <span class="badge badge-light badge-pill">Finance</span>
# <span class="badge badge-light badge-pill">Python</span>
# <span class="badge badge-light badge-pill">R</span>
# <span class="badge badge-light badge-pill">SQL</span>
# <span class="badge badge-light badge-pill">Tableau</span>
# <span class="badge badge-light badge-pill">+1</span>
# <br/>
# <span class="badge badge-success badge-pill">Equity</span>
# <span class="badge badge-success badge-pill">Fertility benefits</span>
# <span class="badge badge-success badge-pill">Flex hours</span>
# <span class="badge badge-success badge-pill">Parental leave</span>
# <span class="badge badge-success badge-pill">Startup environment</span>
# <span class="badge badge-success badge-pill">+1</span>
# </a>
# </div>
# </div>
# <div class="list-group-item px-2 px-lg-3 py-0">
# <div class="row">
# <div class="col-2 col-sm-1 px-2 py-3">
# <a href="/jobs-at-mintel/" title="Show all open positions at Mintel">
# <img alt="Mintel logo" class="mx-auto my-1 d-block" height="48" loading="lazy" src="/media/cache/03/ee/03ee755a9fb02e10654b60bcf91a2c27.jpg" width="48"/>
# </a>
# <div class="d-flex justify-content-center mt-3">
# <a class="btn-direct-apply text-dark p-1" href="/J26115/apply/" id="26115" rel="nofollow noopener" target="_blank" title="Apply for this job directly on Mintel's career site"><i class="fas fa-edit"></i></a>
# <a class="btn-direct-apply text-dark p-1" href="/job/mark/26115/create/" rel="nofollow" title="Save this job for later application"><i class="fas fa-list-ol"></i></a>
# </div>
# </div>
# <a class="col list-group-item-action px-2 py-3" href="/job/26115-consumer-research-data-analyst/" title="View full details of `Consumer Research &amp; Data Analyst` vacancy">
# <div class="float-right text-right d-inline-block w-25 ml-2">
# <span class="d-block d-md-none text-break job-list-item-location">Chicago</span>
# <span class="d-none d-md-block text-break job-list-item-location">Chicago</span>
# <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
# <div class="d-block">
# <span class="badge badge-info badge-pill my-md-1 d-md-none">Senior</span>
# <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Senior-level</span>
# </div>
# <div class="d-block">
# <span class="badge badge-success badge-pill d-none d-md-inline-block">USD 50K - 85K *</span>
# <span class="badge badge-success badge-pill d-md-none">USD 50K+ *</span>
# </div>
# </div>
# <p class="m-0 text-muted job-list-item-company">Mintel</p>
# <h2 class="h4 mb-1">Consumer Research &amp; Data Analyst</h2>
# <span class="badge badge-light badge-pill">Data analysis</span>
# <span class="badge badge-light badge-pill">Data Analytics</span>
# <span class="badge badge-light badge-pill">Finance</span>
# <span class="badge badge-light badge-pill">R</span>
# <span class="badge badge-light badge-pill">Research</span>
# <span class="badge badge-light badge-pill">Statistics</span>
# <span class="badge badge-light badge-pill">Survey data</span>
# <br/>
# <span class="badge badge-success badge-pill">Career development</span>
# </a>
# </div>
# </div>
# <div class="list-group-item px-2 px-lg-3 py-0">
# <div class="row">
# <div class="col-2 col-sm-1 px-2 py-3">
# <a href="/jobs-at-so-energy/" title="Show all open positions at So Energy">
# <img alt="So Energy logo" class="mx-auto my-1 d-block" height="48" loading="lazy" src="/media/cache/22/af/22affff2cd2e26756bec1f7a4e888357.jpg" width="48"/>
# </a>
# <div class="d-flex justify-content-center mt-3">
# <a class="btn-direct-apply text-dark p-1" href="/J26166/apply/" id="26166" rel="nofollow noopener" target="_blank" title="Apply for this job directly on So Energy's career site"><i class="fas fa-edit"></i></a>
# <a class="btn-direct-apply text-dark p-1" href="/job/mark/26166/create/" rel="nofollow" title="Save this job for later application"><i class="fas fa-list-ol"></i></a>
# </div>
# </div>
# <a class="col list-group-item-action px-2 py-3" href="/job/26166-insight-analyst/" title="View full details of `Insight Analyst` vacancy">
# <div class="float-right text-right d-inline-block w-25 ml-2">
# <span class="d-block d-md-none text-break job-list-item-location">United Kingdom</span>
# <span class="d-none d-md-block text-break job-list-item-location">United Kingdom</span>
# <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
# <div class="d-block">
# <span class="badge badge-info badge-pill my-md-1 d-md-none">Mid</span>
# <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Mid-level</span>
# </div>
# </div>
# <p class="m-0 text-muted job-list-item-company">So Energy</p>
# <h2 class="h4 mb-1">Insight Analyst</h2>
# <span class="badge badge-light badge-pill">Agile</span>
# <span class="badge badge-light badge-pill">BigQuery</span>
# <span class="badge badge-light badge-pill">Consulting</span>
# <span class="badge badge-light badge-pill">Data analysis</span>
# <span class="badge badge-light badge-pill">Data Analytics</span>
# <span class="badge badge-light badge-pill">Data Mining</span>
# <span class="badge badge-light badge-pill">Data visualization</span>
# <span class="badge badge-light badge-pill">+12</span>
# <br/>
# <span class="badge badge-success badge-pill">Career development</span>
# <span class="badge badge-success badge-pill">Competitive pay</span>
# </a>
# </div>
# </div>
# <div class="list-group-item px-2 px-lg-3 py-0">
# <div class="row">
# <div class="col-2 col-sm-1 px-2 py-3">
# <a href="/jobs-at-ninja-van/" title="Show all open positions at Ninja Van">
# <img alt="Ninja Van logo" class="mx-auto my-1 d-block" height="48" loading="lazy" src="/media/cache/24/4f/244fdc8cfbb230f51b7755faa1688f55.jpg" width="48"/>
# </a>
# <div class="d-flex justify-content-center mt-3">
# <a class="btn-direct-apply text-dark p-1" href="/J26120/apply/" id="26120" rel="nofollow noopener" target="_blank" title="Apply for this job directly on Ninja Van's career site"><i class="fas fa-edit"></i></a>
# <a class="btn-direct-apply text-dark p-1" href="/job/mark/26120/create/" rel="nofollow" title="Save this job for later application"><i class="fas fa-list-ol"></i></a>
# </div>
# </div>
# <a class="col list-group-item-action px-2 py-3" href="/job/26120-regional-data-analyst-cross-border-based-in-malaysia/" title="View full details of `Regional Data Analyst, Cross Border (based in Malaysia)` vacancy">
# <div class="float-right text-right d-inline-block w-25 ml-2">
# <span class="d-block d-md-none text-break job-list-item-location">Shah Alam, Malaysia</span>
# <span class="d-none d-md-block text-break job-list-item-location">Shah Alam, Malaysia</span>
# <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
# <div class="d-block">
# <span class="badge badge-success badge-pill d-none d-md-inline-block">USD 50K - 85K *</span>
# <span class="badge badge-success badge-pill d-md-none">USD 50K+ *</span>
# </div>
# </div>
# <p class="m-0 text-muted job-list-item-company">Ninja Van</p>
# <h2 class="h4 mb-1">Regional Data Analyst, Cross Border (based in Malaysia)</h2>
# <span class="badge badge-light badge-pill">Business Intelligence</span>
# <span class="badge badge-light badge-pill">Data Analytics</span>
# <span class="badge badge-light badge-pill">Excel</span>
# <span class="badge badge-light badge-pill">KPIs</span>
# <span class="badge badge-light badge-pill">Python</span>
# <span class="badge badge-light badge-pill">SQL</span>
# <br/>
# </a>
# </div>
# </div>
# <a class="list-group-item list-group-item-action text-center" data-offset="100" href="#" id="load-more-jobs">
# <p class="lead text-primary mt-2">Load more</p>
# </a>
# </div>

# %%
results
# Out:
# <div class="list-group list-group-flush mb-5" id="job-list">
# <div class="list-group-item px-2 px-lg-3 py-0">
# <div class="row">
# <div class="col-2 col-sm-1 px-2 py-3">
# <a href="/jobs-at-amica-mutual-insurance-company/" title="Show all open positions at Amica Mutual Insurance Company">
# <img alt="Amica Mutual Insurance Company logo" class="mx-auto my-1 d-block" height="48" loading="lazy" src="/media/cache/39/95/39951b7ffbfd5608fb202f6de1e0ca38.jpg" width="48"/>
# </a>
# <div class="d-flex justify-content-center mt-3">
# <a class="btn-direct-apply text-dark p-1" href="/J24108/apply/" id="24108" rel="nofollow noopener" target="_blank" title="Apply for this job directly on Amica Mutual Insurance Company's career site"><i class="fas fa-edit"></i></a>
# <a class="btn-direct-apply text-dark p-1" href="/job/mark/24108/create/" rel="nofollow" title="Save this job for later application"><i class="fas fa-list-ol"></i></a>
# </div>
# </div>
# <a class="col list-group-item-action px-2 py-3" href="/job/24108-business-intelligence-analyst/" title="View full details of `Business Intelligence Analyst` vacancy">
# <div class="float-right text-right d-inline-block w-25 ml-2">
# <span class="d-block d-md-none text-break job-list-item-location">Lincoln, RI, 02865</span>
# <span class="d-none d-md-block text-break job-list-item-location">Lincoln, RI, 02865</span>
# <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
# <div class="d-block">
# <span class="badge badge-info badge-pill my-md-1 d-md-none">Mid</span>
# <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Mid-level</span>
# </div>
# </div>
# <p class="m-0 text-muted job-list-item-company">Amica Mutual Insurance Company</p>
# <h2 class="h4 mb-1">Business Intelligence Analyst</h2>
# <span class="badge badge-light badge-pill">Business Intelligence</span>
# <span class="badge badge-light badge-pill">Data management</span>
# <span class="badge badge-light badge-pill">Power BI</span>
# <span class="badge badge-light badge-pill">Python</span>
# <span class="badge badge-light badge-pill">R</span>
# <span class="badge badge-light badge-pill">SAS</span>
# <span class="badge badge-light badge-pill">SQL</span>
# <span class="badge badge-light badge-pill">+2</span>
# <br/>
# <span class="badge badge-success badge-pill">Competitive pay</span>
# <span class="badge badge-success badge-pill">Conferences</span>
# <span class="badge badge-success badge-pill">Fitness / gym</span>
# <span class="badge badge-success badge-pill">Health care</span>
# <span class="badge badge-success badge-pill">Insurance</span>
# <span class="badge badge-success badge-pill">+3</span>
# </a>
# </div>
# </div>
# <div class="list-group-item px-2 px-lg-3 py-0">
# <div class="row">
# <div class="col-2 col-sm-1 px-2 py-3">
# <a href="/jobs-at-amica-mutual-insurance-company/" title="Show all open positions at Amica Mutual Insurance Company">
# <img alt="Amica Mutual Insurance Company logo" class="mx-auto my-1 d-block" height="48" loading="lazy" src="/media/cache/39/95/39951b7ffbfd5608fb202f6de1e0ca38.jpg" width="48"/>
# </a>
# <div class="d-flex justify-content-center mt-3">
# <a class="btn-direct-apply text-dark p-1" href="/J24107/apply/" id="24107" rel="nofollow noopener" target="_blank" title="Apply for this job directly on Amica Mutual Insurance Company's career site"><i class="fas fa-edit"></i></a>
# <a class="btn-direct-apply text-dark p-1" href="/job/mark/24107/create/" rel="nofollow" title="Save this job for later application"><i class="fas fa-list-ol"></i></a>
# </div>
# </div>
# <a class="col list-group-item-action px-2 py-3" href="/job/24107-lead-business-intelligence-analyst/" title="View full details of `Lead Business Intelligence Analyst` vacancy">
# <div class="float-right text-right d-inline-block w-25 ml-2">
# <span class="d-block d-md-none text-break job-list-item-location">Lincoln, RI, 02865</span>
# <span class="d-none d-md-block text-break job-list-item-location">Lincoln, RI, 02865</span>
# <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
# <div class="d-block">
# <span class="badge badge-info badge-pill my-md-1 d-md-none">Senior</span>
# <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Senior-level</span>
# </div>
# </div>
# <p class="m-0 text-muted job-list-item-company">Amica Mutual Insurance Company</p>
# <h2 class="h4 mb-1">Lead Business Intelligence Analyst</h2>
# <span class="badge badge-light badge-pill">Business Intelligence</span>
# <span class="badge badge-light badge-pill">Data management</span>
# <span class="badge badge-light badge-pill">KPIs</span>
# <span class="badge badge-light badge-pill">Python</span>
# <span class="badge badge-light badge-pill">R</span>
# <span class="badge badge-light badge-pill">SAS</span>
# <span class="badge badge-light badge-pill">SQL</span>
# <span class="badge badge-light badge-pill">+1</span>
# <br/>
# <span class="badge badge-success badge-pill">Competitive pay</span>
# <span class="badge badge-success badge-pill">Conferences</span>
# <span class="badge badge-success badge-pill">Fitness / gym</span>
# <span class="badge badge-success badge-pill">Flex vacation</span>
# <span class="badge badge-success badge-pill">Health care</span>
# <span class="badge badge-success badge-pill">+4</span>
# </a>
# </div>
# </div>
# <div class="list-group-item px-2 px-lg-3 py-0">
# <div class="row">
# <div class="col-2 col-sm-1 px-2 py-3">
# <a href="/jobs-at-nielsen/" title="Show all open positions at Nielsen">
# <img alt="Nielsen logo" class="mx-auto my-1 d-block" height="48" loading="lazy" src="/media/cache/de/d0/ded0b2c0dc41b8e8637cc335e7b6a5e7.jpg" width="48"/>
# </a>
# <div class="d-flex justify-content-center mt-3">
# <a class="btn-direct-apply text-dark p-1" href="/J26580/apply/" id="26580" rel="nofollow noopener" target="_blank" title="Apply for this job directly on Nielsen's career site"><i class="fas fa-edit"></i></a>
# <a class="btn-direct-apply text-dark p-1" href="/job/mark/26580/create/" rel="nofollow" title="Save this job for later application"><i class="fas fa-list-ol"></i></a>
# </div>
# </div>
# <a class="col list-group-item-action px-2 py-3" href="/job/26580-junior-data-analyst/" title="View full details of `Junior Data Analyst` vacancy">
# <div class="float-right text-right d-inline-block w-25 ml-2">
# <span class="d-block d-md-none text-break job-list-item-location">Poland</span>
# <span class="d-none d-md-block text-break job-list-item-location">Poland</span>
# <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
# <div class="d-block">
# <span class="badge badge-info badge-pill my-md-1 d-md-none">Entry</span>
# <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Entry-level</span>
# </div>
# <div class="d-block">
# <span class="badge badge-success badge-pill d-none d-md-inline-block">USD 30K - 80K *</span>
# <span class="badge badge-success badge-pill d-md-none">USD 30K+ *</span>
# </div>
# </div>
# <p class="m-0 text-muted job-list-item-company">Nielsen</p>
# <h2 class="h4 mb-1">Junior Data Analyst</h2>
# <span class="badge badge-light badge-pill">Consulting</span>
# <span class="badge badge-light badge-pill">Data analysis</span>
# <span class="badge badge-light badge-pill">Econometrics</span>
# <span class="badge badge-light badge-pill">Excel</span>
# <span class="badge badge-light badge-pill">Market research</span>
# <span class="badge badge-light badge-pill">Python</span>
# <span class="badge badge-light badge-pill">R</span>
# <span class="badge badge-light badge-pill">+5</span>
# <br/>
# <span class="badge badge-success badge-pill">Career development</span>
# </a>
# </div>
# </div>
# <div class="list-group-item px-2 px-lg-3 py-0">
# <div class="row">
# <div class="col-2 col-sm-1 px-2 py-3">
# <a href="/jobs-at-athletic-greens/" title="Show all open positions at Athletic Greens">
# <img alt="Athletic Greens logo" class="mx-auto my-1 d-block" height="48" loading="lazy" src="/media/cache/6d/55/6d55b3d5009b61f26b4c9ca80603e2fb.jpg" width="48"/>
# </a>
# <div class="d-flex justify-content-center mt-3">
# <a class="btn-direct-apply text-dark p-1" href="/J26584/apply/" id="26584" rel="nofollow noopener" target="_blank" title="Apply for this job directly on Athletic Greens's career site"><i class="fas fa-edit"></i></a>
# <a class="btn-direct-apply text-dark p-1" href="/job/mark/26584/create/" rel="nofollow" title="Save this job for later application"><i class="fas fa-list-ol"></i></a>
# </div>
# </div>
# <a class="col list-group-item-action px-2 py-3" href="/job/26584-senior-vice-president-data-analytics-bi/" title="View full details of `Senior Vice President, Data Analytics &amp; BI` vacancy">
# <div class="float-right text-right d-inline-block w-25 ml-2">
# <span class="d-block d-md-none text-break job-list-item-location">Los Angeles, California, United …</span>
# <span class="d-none d-md-block text-break job-list-item-location">Los Angeles, California, United States - Remote</span>
# <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
# <div class="d-block">
# <span class="badge badge-info badge-pill my-md-1 d-md-none">Senior</span>
# <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Senior-level</span>
# </div>
# </div>
# <p class="m-0 text-muted job-list-item-company">Athletic Greens</p>
# <h2 class="h4 mb-1">Senior Vice President, Data Analytics &amp; BI</h2>
# <span class="badge badge-light badge-pill">Airflow</span>
# <span class="badge badge-light badge-pill">BigQuery</span>
# <span class="badge badge-light badge-pill">Business Intelligence</span>
# <span class="badge badge-light badge-pill">Data Analytics</span>
# <span class="badge badge-light badge-pill">Data management</span>
# <span class="badge badge-light badge-pill">Data strategy</span>
# <span class="badge badge-light badge-pill">E-commerce</span>
# <span class="badge badge-light badge-pill">+6</span>
# <br/>
# <span class="badge badge-success badge-pill">401(k) matching</span>
# <span class="badge badge-success badge-pill">Flex vacation</span>
# <span class="badge badge-success badge-pill">Gear</span>
# <span class="badge badge-success badge-pill">Health care</span>
# <span class="badge badge-success badge-pill">Home office stipend</span>
# <span class="badge badge-success badge-pill">+5</span>
# </a>
# </div>
# </div>
# <div class="list-group-item px-2 px-lg-3 py-0">
# <div class="row">
# <div class="col-2 col-sm-1 px-2 py-3">
# <a href="/jobs-at-airbnb/" title="Show all open positions at Airbnb">
# <img alt="Airbnb logo" class="mx-auto my-1 d-block" height="48" loading="lazy" src="/media/cache/6b/ba/6bba22fad2cd698715cd02b1239a1819.jpg" width="48"/>
# </a>
# <div class="d-flex justify-content-center mt-3">
# <a class="btn-direct-apply text-dark p-1" href="/J26569/apply/" id="26569" rel="nofollow noopener" target="_blank" title="Apply for this job directly on Airbnb's career site"><i class="fas fa-edit"></i></a>
# <a class="btn-direct-apply text-dark p-1" href="/job/mark/26569/create/" rel="nofollow" title="Save this job for later application"><i class="fas fa-list-ol"></i></a>
# </div>
# </div>
# <a class="col list-group-item-action px-2 py-3" href="/job/26569-staff-analytics-engineer-central-data/" title="View full details of `Staff Analytics Engineer, Central Data` vacancy">
# <div class="float-right text-right d-inline-block w-25 ml-2">
# <span class="d-block d-md-none text-break job-list-item-location">United States</span>
# <span class="d-none d-md-block text-break job-list-item-location">United States</span>
# <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
# <div class="d-block">
# <span class="badge badge-info badge-pill my-md-1 d-md-none">Senior</span>
# <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Senior-level</span>
# </div>
# <div class="d-block">
# <span class="badge badge-success badge-pill d-none d-md-inline-block">USD 180K - 245K</span>
# <span class="badge badge-success badge-pill d-md-none">USD 180K+</span>
# </div>
# </div>
# <p class="m-0 text-muted job-list-item-company">Airbnb</p>
# <h2 class="h4 mb-1">Staff Analytics Engineer, Central Data</h2>
# <span class="badge badge-light badge-pill">Airflow</span>
# <span class="badge badge-light badge-pill">Data analysis</span>
# <span class="badge badge-light badge-pill">Engineering</span>
# <span class="badge badge-light badge-pill">ETL</span>
# <span class="badge badge-light badge-pill">Machine Learning</span>
# <span class="badge badge-light badge-pill">Pipelines</span>
# <span class="badge badge-light badge-pill">Predictive modeling</span>
# <span class="badge badge-light badge-pill">+6</span>
# <br/>
# <span class="badge badge-success badge-pill">Career development</span>
# <span class="badge badge-success badge-pill">Salary bonus</span>
# </a>
# </div>
# </div>
# <div class="list-group-item px-2 px-lg-3 py-0">
# <div class="row">
# <div class="col-2 col-sm-1 px-2 py-3">
# <a href="/jobs-at-tempus/" title="Show all open positions at Tempus">
# <img alt="Tempus logo" class="mx-auto my-1 d-block" height="48" loading="lazy" src="/media/cache/ce/3e/ce3e2833beb0398e8444b6f2dcabf02a.jpg" width="48"/>
# </a>
# <div class="d-flex justify-content-center mt-3">
# <a class="btn-direct-apply text-dark p-1" href="/J26572/apply/" id="26572" rel="nofollow noopener" target="_blank" title="Apply for this job directly on Tempus's career site"><i class="fas fa-edit"></i></a>
# <a class="btn-direct-apply text-dark p-1" href="/job/mark/26572/create/" rel="nofollow" title="Save this job for later application"><i class="fas fa-list-ol"></i></a>
# </div>
# </div>
# <a class="col list-group-item-action px-2 py-3" href="/job/26572-data-analyst-clinical-informatics/" title="View full details of `Data Analyst - Clinical Informatics` vacancy">
# <div class="float-right text-right d-inline-block w-25 ml-2">
# <span class="d-block d-md-none text-break job-list-item-location">Chicago, IL</span>
# <span class="d-none d-md-block text-break job-list-item-location">Chicago, IL</span>
# <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
# <div class="d-block">
# <span class="badge badge-success badge-pill d-none d-md-inline-block">USD 50K - 85K *</span>
# <span class="badge badge-success badge-pill d-md-none">USD 50K+ *</span>
# </div>
# </div>
# <p class="m-0 text-muted job-list-item-company">Tempus</p>
# <h2 class="h4 mb-1">Data Analyst - Clinical Informatics</h2>
# <span class="badge badge-light badge-pill">Data pipelines</span>
# <span class="badge badge-light badge-pill">Pipelines</span>
# <span class="badge badge-light badge-pill">Python</span>
# <span class="badge badge-light badge-pill">SQL</span>
# <br/>
# </a>
# </div>
# </div>
# <div class="list-group-item px-2 px-lg-3 py-0">
# <div class="row">
# <div class="col-2 col-sm-1 px-2 py-3">
# <a href="/jobs-at-adyen/" title="Show all open positions at Adyen">
# <img alt="Adyen logo" class="mx-auto my-1 d-block" height="48" loading="lazy" src="/media/cache/3a/99/3a9928a0aef5b8275d5cd169ea03ddc3.jpg" width="48"/>
# </a>
# <div class="d-flex justify-content-center mt-3">
# <a class="btn-direct-apply text-dark p-1" href="/J26573/apply/" id="26573" rel="nofollow noopener" target="_blank" title="Apply for this job directly on Adyen's career site"><i class="fas fa-edit"></i></a>
# <a class="btn-direct-apply text-dark p-1" href="/job/mark/26573/create/" rel="nofollow" title="Save this job for later application"><i class="fas fa-list-ol"></i></a>
# </div>
# </div>
# <a class="col list-group-item-action px-2 py-3" href="/job/26573-senior-product-data-analytics/" title="View full details of `Senior Product Data Analytics` vacancy">
# <div class="float-right text-right d-inline-block w-25 ml-2">
# <span class="d-block d-md-none text-break job-list-item-location">Sao Paulo</span>
# <span class="d-none d-md-block text-break job-list-item-location">Sao Paulo</span>
# <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
# <div class="d-block">
# <span class="badge badge-info badge-pill my-md-1 d-md-none">Senior</span>
# <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Senior-level</span>
# </div>
# </div>
# <p class="m-0 text-muted job-list-item-company">Adyen</p>
# <h2 class="h4 mb-1">Senior Product Data Analytics</h2>
# <span class="badge badge-light badge-pill">Airflow</span>
# <span class="badge badge-light badge-pill">Big Data</span>
# <span class="badge badge-light badge-pill">Data Analytics</span>
# <span class="badge badge-light badge-pill">Data pipelines</span>
# <span class="badge badge-light badge-pill">Engineering</span>
# <span class="badge badge-light badge-pill">ETL</span>
# <span class="badge badge-light badge-pill">Pipelines</span>
# <span class="badge badge-light badge-pill">+5</span>
# <br/>
# <span class="badge badge-success badge-pill">Startup environment</span>
# </a>
# </div>
# </div>
# <div class="list-group-item px-2 px-lg-3 py-0">
# <div class="row">
# <div class="col-2 col-sm-1 px-2 py-3">
# <a href="/jobs-at-doordash/" title="Show all open positions at DoorDash">
# <img alt="DoorDash logo" class="mx-auto my-1 d-block" height="48" loading="lazy" src="/media/cache/fc/87/fc87cb38476d66ea026815302d94c848.jpg" width="48"/>
# </a>
# <div class="d-flex justify-content-center mt-3">
# <a class="btn-direct-apply text-dark p-1" href="/J26526/apply/" id="26526" rel="nofollow noopener" target="_blank" title="Apply for this job directly on DoorDash's career site"><i class="fas fa-edit"></i></a>
# <a class="btn-direct-apply text-dark p-1" href="/job/mark/26526/create/" rel="nofollow" title="Save this job for later application"><i class="fas fa-list-ol"></i></a>
# </div>
# </div>
# <a class="col list-group-item-action px-2 py-3" href="/job/26526-data-scientist-international-analytics/" title="View full details of `Data Scientist, International Analytics` vacancy">
# <div class="float-right text-right d-inline-block w-25 ml-2">
# <span class="d-block d-md-none text-break job-list-item-location">Toronto, ON</span>
# <span class="d-none d-md-block text-break job-list-item-location">Toronto, ON</span>
# <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
# <div class="d-block">
# <span class="badge badge-info badge-pill my-md-1 d-md-none">Senior</span>
# <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Senior-level</span>
# </div>
# <div class="d-block">
# <span class="badge badge-success badge-pill d-none d-md-inline-block">USD 68K - 135K *</span>
# <span class="badge badge-success badge-pill d-md-none">USD 68K+ *</span>
# </div>
# </div>
# <p class="m-0 text-muted job-list-item-company">DoorDash</p>
# <h2 class="h4 mb-1">Data Scientist, International Analytics</h2>
# <span class="badge badge-light badge-pill">A/B testing</span>
# <span class="badge badge-light badge-pill">Consulting</span>
# <span class="badge badge-light badge-pill">Data Analytics</span>
# <span class="badge badge-light badge-pill">Economics</span>
# <span class="badge badge-light badge-pill">ETL</span>
# <span class="badge badge-light badge-pill">Excel</span>
# <span class="badge badge-light badge-pill">Looker</span>
# <span class="badge badge-light badge-pill">+8</span>
# <br/>
# <span class="badge badge-success badge-pill">Flex vacation</span>
# </a>
# </div>
# </div>
# <div class="list-group-item px-2 px-lg-3 py-0">
# <div class="row">
# <div class="col-2 col-sm-1 px-2 py-3">
# <a href="/jobs-at-archive/" title="Show all open positions at Archive">
# <img alt="Archive logo" class="mx-auto my-1 d-block" height="48" loading="lazy" src="/media/cache/6f/2d/6f2da1f2766f34438b3a4dd78e00470f.jpg" width="48"/>
# </a>
# <div class="d-flex justify-content-center mt-3">
# <a class="btn-direct-apply text-dark p-1" href="/J26575/apply/" id="26575" rel="nofollow noopener" target="_blank" title="Apply for this job directly on Archive's career site"><i class="fas fa-edit"></i></a>
# <a class="btn-direct-apply text-dark p-1" href="/job/mark/26575/create/" rel="nofollow" title="Save this job for later application"><i class="fas fa-list-ol"></i></a>
# </div>
# </div>
# <a class="col list-group-item-action px-2 py-3" href="/job/26575-data-analyst/" title="View full details of `Data Analyst` vacancy">
# <div class="float-right text-right d-inline-block w-25 ml-2">
# <span class="d-block d-md-none text-break job-list-item-location">Remote</span>
# <span class="d-none d-md-block text-break job-list-item-location">Remote</span>
# <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
# <div class="d-block">
# <span class="badge badge-info badge-pill my-md-1 d-md-none">Senior</span>
# <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Senior-level</span>
# </div>
# <div class="d-block">
# <span class="badge badge-success badge-pill d-none d-md-inline-block">USD 50K - 85K *</span>
# <span class="badge badge-success badge-pill d-md-none">USD 50K+ *</span>
# </div>
# </div>
# <p class="m-0 text-muted job-list-item-company">Archive</p>
# <h2 class="h4 mb-1">Data Analyst</h2>
# <span class="badge badge-light badge-pill">Data visualization</span>
# <span class="badge badge-light badge-pill">Looker</span>
# <span class="badge badge-light badge-pill">SQL</span>
# <span class="badge badge-light badge-pill">Tableau</span>
# <br/>
# </a>
# </div>
# </div>
# <div class="list-group-item px-2 px-lg-3 py-0">
# <div class="row">
# <div class="col-2 col-sm-1 px-2 py-3">
# <a href="/jobs-at-koho/" title="Show all open positions at KOHO">
# <img alt="KOHO logo" class="mx-auto my-1 d-block" height="48" loading="lazy" src="/media/cache/d2/d6/d2d6222f2ad1a6e09e27dadc92805b88.jpg" width="48"/>
# </a>
# <div class="d-flex justify-content-center mt-3">
# <a class="btn-direct-apply text-dark p-1" href="/J26570/apply/" id="26570" rel="nofollow noopener" target="_blank" title="Apply for this job directly on KOHO's career site"><i class="fas fa-edit"></i></a>
# <a class="btn-direct-apply text-dark p-1" href="/job/mark/26570/create/" rel="nofollow" title="Save this job for later application"><i class="fas fa-list-ol"></i></a>
# </div>
# </div>
# <a class="col list-group-item-action px-2 py-3" href="/job/26570-analytics-engineer-remote/" title="View full details of `Analytics Engineer - Remote` vacancy">
# <div class="float-right text-right d-inline-block w-25 ml-2">
# <span class="d-block d-md-none text-break job-list-item-location">Canada</span>
# <span class="d-none d-md-block text-break job-list-item-location">Canada</span>
# <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
# <div class="d-block">
# <span class="badge badge-info badge-pill my-md-1 d-md-none">Senior</span>
# <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Senior-level</span>
# </div>
# </div>
# <p class="m-0 text-muted job-list-item-company">KOHO</p>
# <h2 class="h4 mb-1">Analytics Engineer - Remote</h2>
# <span class="badge badge-light badge-pill">Data Analytics</span>
# <span class="badge badge-light badge-pill">Engineering</span>
# <span class="badge badge-light badge-pill">Machine Learning</span>
# <span class="badge badge-light badge-pill">Python</span>
# <span class="badge badge-light badge-pill">SQL</span>
# <span class="badge badge-light badge-pill">Testing</span>
# <br/>
# <span class="badge badge-success badge-pill">Home office stipend</span>
# </a>
# </div>
# </div>
# <div class="list-group-item px-2 px-lg-3 py-0">
# <div class="row">
# <div class="col-2 col-sm-1 px-2 py-3">
# <a href="/jobs-at-sosafe/" title="Show all open positions at SoSafe">
# <img alt="SoSafe logo" class="mx-auto my-1 d-block" height="48" loading="lazy" src="/media/cache/62/50/62508571fb1dae6a176f8550cec711d9.jpg" width="48"/>
# </a>
# <div class="d-flex justify-content-center mt-3">
# <a class="btn-direct-apply text-dark p-1" href="/J26541/apply/" id="26541" rel="nofollow noopener" target="_blank" title="Apply for this job directly on SoSafe's career site"><i class="fas fa-edit"></i></a>
# <a class="btn-direct-apply text-dark p-1" href="/job/mark/26541/create/" rel="nofollow" title="Save this job for later application"><i class="fas fa-list-ol"></i></a>
# </div>
# </div>
# <a class="col list-group-item-action px-2 py-3" href="/job/26541-data-analyst-bi-developer-mfd/" title="View full details of `Data Analyst / BI Developer (m/f/d)` vacancy">
# <div class="float-right text-right d-inline-block w-25 ml-2">
# <span class="d-block d-md-none text-break job-list-item-location">Remote</span>
# <span class="d-none d-md-block text-break job-list-item-location">Remote</span>
# <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
# <div class="d-block">
# <span class="badge badge-info badge-pill my-md-1 d-md-none">Senior</span>
# <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Senior-level</span>
# </div>
# </div>
# <p class="m-0 text-muted job-list-item-company">SoSafe</p>
# <h2 class="h4 mb-1">Data Analyst / BI Developer (m/f/d)</h2>
# <span class="badge badge-light badge-pill">Business Intelligence</span>
# <span class="badge badge-light badge-pill">Data analysis</span>
# <span class="badge badge-light badge-pill">Data visualization</span>
# <span class="badge badge-light badge-pill">KPIs</span>
# <span class="badge badge-light badge-pill">Power BI</span>
# <span class="badge badge-light badge-pill">Python</span>
# <span class="badge badge-light badge-pill">Security</span>
# <span class="badge badge-light badge-pill">+3</span>
# <br/>
# <span class="badge badge-success badge-pill">Career development</span>
# <span class="badge badge-success badge-pill">Competitive pay</span>
# <span class="badge badge-success badge-pill">Flex vacation</span>
# <span class="badge badge-success badge-pill">Lunch / meals</span>
# <span class="badge badge-success badge-pill">Salary bonus</span>
# <span class="badge badge-success badge-pill">+1</span>
# </a>
# </div>
# </div>
# <div class="list-group-item px-2 px-lg-3 py-0">
# <div class="row">
# <div class="col-2 col-sm-1 px-2 py-3">
# <a href="/jobs-at-mintel/" title="Show all open positions at Mintel">
# <img alt="Mintel logo" class="mx-auto my-1 d-block" height="48" loading="lazy" src="/media/cache/03/ee/03ee755a9fb02e10654b60bcf91a2c27.jpg" width="48"/>
# </a>
# <div class="d-flex justify-content-center mt-3">
# <a class="btn-direct-apply text-dark p-1" href="/J26579/apply/" id="26579" rel="nofollow noopener" target="_blank" title="Apply for this job directly on Mintel's career site"><i class="fas fa-edit"></i></a>
# <a class="btn-direct-apply text-dark p-1" href="/job/mark/26579/create/" rel="nofollow" title="Save this job for later application"><i class="fas fa-list-ol"></i></a>
# </div>
# </div>
# <a class="col list-group-item-action px-2 py-3" href="/job/26579-data-analytics-lead/" title="View full details of `Data Analytics Lead` vacancy">
# <div class="float-right text-right d-inline-block w-25 ml-2">
# <span class="d-block d-md-none text-break job-list-item-location">London</span>
# <span class="d-none d-md-block text-break job-list-item-location">London</span>
# <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
# </div>
# <p class="m-0 text-muted job-list-item-company">Mintel</p>
# <h2 class="h4 mb-1">Data Analytics Lead</h2>
# <span class="badge badge-light badge-pill">Consulting</span>
# <span class="badge badge-light badge-pill">Data Analytics</span>
# <span class="badge badge-light badge-pill">Looker</span>
# <span class="badge badge-light badge-pill">Market research</span>
# <span class="badge badge-light badge-pill">Power BI</span>
# <span class="badge badge-light badge-pill">Research</span>
# <span class="badge badge-light badge-pill">SQL</span>
# <span class="badge badge-light badge-pill">+1</span>
# <br/>
# <span class="badge badge-success badge-pill">Career development</span>
# <span class="badge badge-success badge-pill">Flex vacation</span>
# </a>
# </div>
# </div>
# <div class="list-group-item px-2 px-lg-3 py-0">
# <div class="row">
# <div class="col-2 col-sm-1 px-2 py-3">
# <a href="/jobs-at-fitxr/" title="Show all open positions at FitXR">
# <img alt="FitXR logo" class="mx-auto my-1 d-block" height="48" loading="lazy" src="/media/cache/45/72/4572700f92925420c5e1df1d5e81d637.jpg" width="48"/>
# </a>
# <div class="d-flex justify-content-center mt-3">
# <a class="btn-direct-apply text-dark p-1" href="/J26583/apply/" id="26583" rel="nofollow noopener" target="_blank" title="Apply for this job directly on FitXR's career site"><i class="fas fa-edit"></i></a>
# <a class="btn-direct-apply text-dark p-1" href="/job/mark/26583/create/" rel="nofollow" title="Save this job for later application"><i class="fas fa-list-ol"></i></a>
# </div>
# </div>
# <a class="col list-group-item-action px-2 py-3" href="/job/26583-senior-data-analyst/" title="View full details of `Senior Data Analyst` vacancy">
# <div class="float-right text-right d-inline-block w-25 ml-2">
# <span class="d-block d-md-none text-break job-list-item-location">London, England, United Kingdom …</span>
# <span class="d-none d-md-block text-break job-list-item-location">London, England, United Kingdom - Remote</span>
# <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
# <div class="d-block">
# <span class="badge badge-info badge-pill my-md-1 d-md-none">Mid</span>
# <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Mid-level</span>
# </div>
# <div class="d-block">
# <span class="badge badge-success badge-pill d-none d-md-inline-block">USD 51K - 90K *</span>
# <span class="badge badge-success badge-pill d-md-none">USD 51K+ *</span>
# </div>
# </div>
# <p class="m-0 text-muted job-list-item-company">FitXR</p>
# <h2 class="h4 mb-1">Senior Data Analyst</h2>
# <span class="badge badge-light badge-pill">A/B testing</span>
# <span class="badge badge-light badge-pill">BigQuery</span>
# <span class="badge badge-light badge-pill">DevOps</span>
# <span class="badge badge-light badge-pill">Engineering</span>
# <span class="badge badge-light badge-pill">Julia</span>
# <span class="badge badge-light badge-pill">Python</span>
# <span class="badge badge-light badge-pill">R</span>
# <span class="badge badge-light badge-pill">+2</span>
# <br/>
# <span class="badge badge-success badge-pill">Career development</span>
# <span class="badge badge-success badge-pill">Competitive pay</span>
# <span class="badge badge-success badge-pill">Equity</span>
# <span class="badge badge-success badge-pill">Flex vacation</span>
# <span class="badge badge-success badge-pill">Gear</span>
# <span class="badge badge-success badge-pill">+3</span>
# </a>
# </div>
# </div>
# <div class="list-group-item px-2 px-lg-3 py-0">
# <div class="row">
# <div class="col-2 col-sm-1 px-2 py-3">
# <a href="/jobs-at-lingoace/" title="Show all open positions at LingoAce">
# <img alt="LingoAce logo" class="mx-auto my-1 d-block" height="48" loading="lazy" src="/media/cache/0f/0e/0f0ed92ec77c049e2ad10698ad549c75.jpg" width="48"/>
# </a>
# <div class="d-flex justify-content-center mt-3">
# <a class="btn-direct-apply text-dark p-1" href="/J26582/apply/" id="26582" rel="nofollow noopener" target="_blank" title="Apply for this job directly on LingoAce's career site"><i class="fas fa-edit"></i></a>
# <a class="btn-direct-apply text-dark p-1" href="/job/mark/26582/create/" rel="nofollow" title="Save this job for later application"><i class="fas fa-list-ol"></i></a>
# </div>
# </div>
# <a class="col list-group-item-action px-2 py-3" href="/job/26582-senior-data-analyst-thailand/" title="View full details of `Senior Data Analyst - Thailand` vacancy">
# <div class="float-right text-right d-inline-block w-25 ml-2">
# <span class="d-block d-md-none text-break job-list-item-location">Bangkok, Bangkok, Thailand</span>
# <span class="d-none d-md-block text-break job-list-item-location">Bangkok, Bangkok, Thailand</span>
# <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
# <div class="d-block">
# <span class="badge badge-info badge-pill my-md-1 d-md-none">Mid</span>
# <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Mid-level</span>
# </div>
# <div class="d-block">
# <span class="badge badge-success badge-pill d-none d-md-inline-block">USD 51K - 90K *</span>
# <span class="badge badge-success badge-pill d-md-none">USD 51K+ *</span>
# </div>
# </div>
# <p class="m-0 text-muted job-list-item-company">LingoAce</p>
# <h2 class="h4 mb-1">Senior Data Analyst - Thailand</h2>
# <span class="badge badge-light badge-pill">Data Analytics</span>
# <span class="badge badge-light badge-pill">Economics</span>
# <span class="badge badge-light badge-pill">Statistics</span>
# <br/>
# <span class="badge badge-success badge-pill">Startup environment</span>
# </a>
# </div>
# </div>
# <div class="list-group-item px-2 px-lg-3 py-0">
# <div class="row">
# <div class="col-2 col-sm-1 px-2 py-3">
# <a href="/jobs-at-wpp/" title="Show all open positions at WPP">
# <img alt="WPP logo" class="mx-auto my-1 d-block" height="48" loading="lazy" src="/media/cache/53/42/53420b3557ad17fcf92350447316fc5b.jpg" width="48"/>
# </a>
# <div class="d-flex justify-content-center mt-3">
# <a class="btn-direct-apply text-dark p-1" href="/J26576/apply/" id="26576" rel="nofollow noopener" target="_blank" title="Apply for this job directly on WPP's career site"><i class="fas fa-edit"></i></a>
# <a class="btn-direct-apply text-dark p-1" href="/job/mark/26576/create/" rel="nofollow" title="Save this job for later application"><i class="fas fa-list-ol"></i></a>
# </div>
# </div>
# <a class="col list-group-item-action px-2 py-3" href="/job/26576-financial-data-analyst-latam-remote/" title="View full details of `Financial Data Analyst - LATAM- REMOTE` vacancy">
# <div class="float-right text-right d-inline-block w-25 ml-2">
# <span class="d-block d-md-none text-break job-list-item-location">Mexico City</span>
# <span class="d-none d-md-block text-break job-list-item-location">Mexico City</span>
# <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
# <div class="d-block">
# <span class="badge badge-info badge-pill my-md-1 d-md-none">Senior</span>
# <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Senior-level</span>
# </div>
# <div class="d-block">
# <span class="badge badge-success badge-pill d-none d-md-inline-block">USD 50K - 85K *</span>
# <span class="badge badge-success badge-pill d-md-none">USD 50K+ *</span>
# </div>
# </div>
# <p class="m-0 text-muted job-list-item-company">WPP</p>
# <h2 class="h4 mb-1">Financial Data Analyst - LATAM- REMOTE</h2>
# <span class="badge badge-light badge-pill">Consulting</span>
# <span class="badge badge-light badge-pill">ETL</span>
# <span class="badge badge-light badge-pill">Finance</span>
# <span class="badge badge-light badge-pill">Oracle</span>
# <br/>
# </a>
# </div>
# </div>
# <div class="list-group-item px-2 px-lg-3 py-0">
# <div class="row">
# <div class="col-2 col-sm-1 px-2 py-3">
# <a href="/jobs-at-deepsource/" title="Show all open positions at DeepSource">
# <img alt="DeepSource logo" class="mx-auto my-1 d-block" height="48" loading="lazy" src="/media/cache/dc/8a/dc8a3d793c8b59129c0a858886abd226.jpg" width="48"/>
# </a>
# <div class="d-flex justify-content-center mt-3">
# <a class="btn-direct-apply text-dark p-1" href="/J26542/apply/" id="26542" rel="nofollow noopener" target="_blank" title="Apply for this job directly on DeepSource's career site"><i class="fas fa-edit"></i></a>
# <a class="btn-direct-apply text-dark p-1" href="/job/mark/26542/create/" rel="nofollow" title="Save this job for later application"><i class="fas fa-list-ol"></i></a>
# </div>
# </div>
# <a class="col list-group-item-action px-2 py-3" href="/job/26542-research-engineer-static-analysis-web3/" title="View full details of `Research Engineer, Static Analysis - Web3` vacancy">
# <div class="float-right text-right d-inline-block w-25 ml-2">
# <span class="d-block d-md-none text-break job-list-item-location">Bangalore, India</span>
# <span class="d-none d-md-block text-break job-list-item-location">Bangalore, India</span>
# <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
# <div class="d-block">
# <span class="badge badge-info badge-pill my-md-1 d-md-none">Senior</span>
# <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Senior-level</span>
# </div>
# </div>
# <p class="m-0 text-muted job-list-item-company">DeepSource</p>
# <h2 class="h4 mb-1">Research Engineer, Static Analysis - Web3</h2>
# <span class="badge badge-light badge-pill">Engineering</span>
# <span class="badge badge-light badge-pill">Research</span>
# <span class="badge badge-light badge-pill">Testing</span>
# <br/>
# </a>
# </div>
# </div>
# <div class="list-group-item px-2 px-lg-3 py-0">
# <div class="row">
# <div class="col-2 col-sm-1 px-2 py-3">
# <a href="/jobs-at-argo-group/" title="Show all open positions at Argo Group">
# <img alt="Argo Group logo" class="mx-auto my-1 d-block" height="48" loading="lazy" src="/media/cache/59/92/5992574f929915fb8a3b6488168b481d.jpg" width="48"/>
# </a>
# <div class="d-flex justify-content-center mt-3">
# <a class="btn-direct-apply text-dark p-1" href="/J26574/apply/" id="26574" rel="nofollow noopener" target="_blank" title="Apply for this job directly on Argo Group's career site"><i class="fas fa-edit"></i></a>
# <a class="btn-direct-apply text-dark p-1" href="/job/mark/26574/create/" rel="nofollow" title="Save this job for later application"><i class="fas fa-list-ol"></i></a>
# </div>
# </div>
# <a class="col list-group-item-action px-2 py-3" href="/job/26574-data-analyst-business-delivery-services/" title="View full details of `Data Analyst, Business Delivery Services` vacancy">
# <div class="float-right text-right d-inline-block w-25 ml-2">
# <span class="d-block d-md-none text-break job-list-item-location">Remote</span>
# <span class="d-none d-md-block text-break job-list-item-location">Remote</span>
# <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
# <div class="d-block">
# <span class="badge badge-info badge-pill my-md-1 d-md-none">Senior</span>
# <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Senior-level</span>
# </div>
# <div class="d-block">
# <span class="badge badge-success badge-pill d-none d-md-inline-block">USD 80K - 92K</span>
# <span class="badge badge-success badge-pill d-md-none">USD 80K+</span>
# </div>
# </div>
# <p class="m-0 text-muted job-list-item-company">Argo Group</p>
# <h2 class="h4 mb-1">Data Analyst, Business Delivery Services</h2>
# <span class="badge badge-light badge-pill">Agile</span>
# <span class="badge badge-light badge-pill">Data analysis</span>
# <span class="badge badge-light badge-pill">Data Mining</span>
# <span class="badge badge-light badge-pill">Excel</span>
# <span class="badge badge-light badge-pill">Python</span>
# <span class="badge badge-light badge-pill">SQL</span>
# <span class="badge badge-light badge-pill">Statistics</span>
# <br/>
# <span class="badge badge-success badge-pill">401(k) matching</span>
# <span class="badge badge-success badge-pill">Career development</span>
# <span class="badge badge-success badge-pill">Competitive pay</span>
# <span class="badge badge-success badge-pill">Equity</span>
# <span class="badge badge-success badge-pill">Flex hours</span>
# <span class="badge badge-success badge-pill">+9</span>
# </a>
# </div>
# </div>
# <div class="list-group-item px-2 px-lg-3 py-0">
# <div class="row">
# <div class="col-2 col-sm-1 px-2 py-3">
# <a href="/jobs-at-horangi-cyber-security/" title="Show all open positions at Horangi Cyber Security">
# <img alt="Horangi Cyber Security logo" class="mx-auto my-1 d-block" height="48" loading="lazy" src="/media/cache/50/5a/505a30b6c4bd03740a5ed9ce0a82ac26.jpg" width="48"/>
# </a>
# <div class="d-flex justify-content-center mt-3">
# <a class="btn-direct-apply text-dark p-1" href="/J26581/apply/" id="26581" rel="nofollow noopener" target="_blank" title="Apply for this job directly on Horangi Cyber Security's career site"><i class="fas fa-edit"></i></a>
# <a class="btn-direct-apply text-dark p-1" href="/job/mark/26581/create/" rel="nofollow" title="Save this job for later application"><i class="fas fa-list-ol"></i></a>
# </div>
# </div>
# <a class="col list-group-item-action px-2 py-3" href="/job/26581-data-analyst/" title="View full details of `Data Analyst` vacancy">
# <div class="float-right text-right d-inline-block w-25 ml-2">
# <span class="d-block d-md-none text-break job-list-item-location">Jakarta</span>
# <span class="d-none d-md-block text-break job-list-item-location">Jakarta</span>
# <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
# <div class="d-block">
# <span class="badge badge-info badge-pill my-md-1 d-md-none">Senior</span>
# <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Senior-level</span>
# </div>
# <div class="d-block">
# <span class="badge badge-success badge-pill d-none d-md-inline-block">USD 50K - 85K *</span>
# <span class="badge badge-success badge-pill d-md-none">USD 50K+ *</span>
# </div>
# </div>
# <p class="m-0 text-muted job-list-item-company">Horangi Cyber Security</p>
# <h2 class="h4 mb-1">Data Analyst</h2>
# <span class="badge badge-light badge-pill">Agile</span>
# <span class="badge badge-light badge-pill">AWS</span>
# <span class="badge badge-light badge-pill">Consulting</span>
# <span class="badge badge-light badge-pill">Data visualization</span>
# <span class="badge badge-light badge-pill">Docker</span>
# <span class="badge badge-light badge-pill">Economics</span>
# <span class="badge badge-light badge-pill">Engineering</span>
# <span class="badge badge-light badge-pill">+10</span>
# <br/>
# <span class="badge badge-success badge-pill">Team events</span>
# </a>
# </div>
# </div>
# <div class="list-group-item px-2 px-lg-3 py-0">
# <div class="row">
# <div class="col-2 col-sm-1 px-2 py-3">
# <a href="/jobs-at-nuvei/" title="Show all open positions at Nuvei">
# <img alt="Nuvei logo" class="mx-auto my-1 d-block" height="48" loading="lazy" src="/media/cache/e9/bd/e9bdb6b75d75ccdd5fd77caadb705061.jpg" width="48"/>
# </a>
# <div class="d-flex justify-content-center mt-3">
# <a class="btn-direct-apply text-dark p-1" href="/J26585/apply/" id="26585" rel="nofollow noopener" target="_blank" title="Apply for this job directly on Nuvei's career site"><i class="fas fa-edit"></i></a>
# <a class="btn-direct-apply text-dark p-1" href="/job/mark/26585/create/" rel="nofollow" title="Save this job for later application"><i class="fas fa-list-ol"></i></a>
# </div>
# </div>
# <a class="col list-group-item-action px-2 py-3" href="/job/26585-compliance-data-analyst/" title="View full details of `Compliance Data Analyst` vacancy">
# <div class="float-right text-right d-inline-block w-25 ml-2">
# <span class="d-block d-md-none text-break job-list-item-location">Scottsdale, Arizona, United States …</span>
# <span class="d-none d-md-block text-break job-list-item-location">Scottsdale, Arizona, United States - Remote</span>
# <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
# <div class="d-block">
# <span class="badge badge-info badge-pill my-md-1 d-md-none">Entry</span>
# <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Entry-level</span>
# </div>
# <div class="d-block">
# <span class="badge badge-success badge-pill d-none d-md-inline-block">USD 30K - 80K *</span>
# <span class="badge badge-success badge-pill d-md-none">USD 30K+ *</span>
# </div>
# </div>
# <p class="m-0 text-muted job-list-item-company">Nuvei</p>
# <h2 class="h4 mb-1">Compliance Data Analyst</h2>
# <span class="badge badge-light badge-pill">Data analysis</span>
# <span class="badge badge-light badge-pill">Data Mining</span>
# <br/>
# <span class="badge badge-success badge-pill">401(k) matching</span>
# <span class="badge badge-success badge-pill">Health care</span>
# <span class="badge badge-success badge-pill">Yoga</span>
# </a>
# </div>
# </div>
# <div class="list-group-item px-2 px-lg-3 py-0">
# <div class="row">
# <div class="col-2 col-sm-1 px-2 py-3">
# <a href="/jobs-at-trustly/" title="Show all open positions at Trustly">
# <img alt="Trustly logo" class="mx-auto my-1 d-block" height="48" loading="lazy" src="/media/cache/c6/1c/c61c875a5f55302b67c5953f0e13c6e1.jpg" width="48"/>
# </a>
# <div class="d-flex justify-content-center mt-3">
# <a class="btn-direct-apply text-dark p-1" href="/J26578/apply/" id="26578" rel="nofollow noopener" target="_blank" title="Apply for this job directly on Trustly's career site"><i class="fas fa-edit"></i></a>
# <a class="btn-direct-apply text-dark p-1" href="/job/mark/26578/create/" rel="nofollow" title="Save this job for later application"><i class="fas fa-list-ol"></i></a>
# </div>
# </div>
# <a class="col list-group-item-action px-2 py-3" href="/job/26578-senior-data-analyst/" title="View full details of `Senior Data Analyst` vacancy">
# <div class="float-right text-right d-inline-block w-25 ml-2">
# <span class="d-block d-md-none text-break job-list-item-location">Vitoria, Brazil or Remote, …</span>
# <span class="d-none d-md-block text-break job-list-item-location">Vitoria, Brazil or Remote, Brazil</span>
# <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
# <div class="d-block">
# <span class="badge badge-info badge-pill my-md-1 d-md-none">Senior</span>
# <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Senior-level</span>
# </div>
# <div class="d-block">
# <span class="badge badge-success badge-pill d-none d-md-inline-block">USD 50K - 85K *</span>
# <span class="badge badge-success badge-pill d-md-none">USD 50K+ *</span>
# </div>
# </div>
# <p class="m-0 text-muted job-list-item-company">Trustly</p>
# <h2 class="h4 mb-1">Senior Data Analyst</h2>
# <span class="badge badge-light badge-pill">AWS</span>
# <span class="badge badge-light badge-pill">Banking</span>
# <span class="badge badge-light badge-pill">Big Data</span>
# <span class="badge badge-light badge-pill">Data Analytics</span>
# <span class="badge badge-light badge-pill">Data Mining</span>
# <span class="badge badge-light badge-pill">Data pipelines</span>
# <span class="badge badge-light badge-pill">Engineering</span>
# <span class="badge badge-light badge-pill">+7</span>
# <br/>
# <span class="badge badge-success badge-pill">Career development</span>
# <span class="badge badge-success badge-pill">Flex hours</span>
# <span class="badge badge-success badge-pill">Flex vacation</span>
# <span class="badge badge-success badge-pill">Health care</span>
# <span class="badge badge-success badge-pill">Home office stipend</span>
# <span class="badge badge-success badge-pill">+5</span>
# </a>
# </div>
# </div>
# <div class="list-group-item px-2 px-lg-3 py-0">
# <div class="row">
# <div class="col-2 col-sm-1 px-2 py-3">
# <a href="/jobs-at-argo-group/" title="Show all open positions at Argo Group">
# <img alt="Argo Group logo" class="mx-auto my-1 d-block" height="48" loading="lazy" src="/media/cache/59/92/5992574f929915fb8a3b6488168b481d.jpg" width="48"/>
# </a>
# <div class="d-flex justify-content-center mt-3">
# <a class="btn-direct-apply text-dark p-1" href="/J26577/apply/" id="26577" rel="nofollow noopener" target="_blank" title="Apply for this job directly on Argo Group's career site"><i class="fas fa-edit"></i></a>
# <a class="btn-direct-apply text-dark p-1" href="/job/mark/26577/create/" rel="nofollow" title="Save this job for later application"><i class="fas fa-list-ol"></i></a>
# </div>
# </div>
# <a class="col list-group-item-action px-2 py-3" href="/job/26577-technical-data-analyst/" title="View full details of `Technical Data Analyst` vacancy">
# <div class="float-right text-right d-inline-block w-25 ml-2">
# <span class="d-block d-md-none text-break job-list-item-location">Remote</span>
# <span class="d-none d-md-block text-break job-list-item-location">Remote</span>
# <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
# <div class="d-block">
# <span class="badge badge-info badge-pill my-md-1 d-md-none">Senior</span>
# <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Senior-level</span>
# </div>
# <div class="d-block">
# <span class="badge badge-success badge-pill d-none d-md-inline-block">USD 90K - 108K</span>
# <span class="badge badge-success badge-pill d-md-none">USD 90K+</span>
# </div>
# </div>
# <p class="m-0 text-muted job-list-item-company">Argo Group</p>
# <h2 class="h4 mb-1">Technical Data Analyst</h2>
# <span class="badge badge-light badge-pill">Agile</span>
# <span class="badge badge-light badge-pill">Data Mining</span>
# <span class="badge badge-light badge-pill">Excel</span>
# <span class="badge badge-light badge-pill">MS SQL</span>
# <span class="badge badge-light badge-pill">Oracle</span>
# <span class="badge badge-light badge-pill">Power BI</span>
# <span class="badge badge-light badge-pill">Snowflake</span>
# <span class="badge badge-light badge-pill">+1</span>
# <br/>
# <span class="badge badge-success badge-pill">401(k) matching</span>
# <span class="badge badge-success badge-pill">Career development</span>
# <span class="badge badge-success badge-pill">Competitive pay</span>
# <span class="badge badge-success badge-pill">Equity</span>
# ...
# <img alt="Wonolo logo" class="mx-auto my-1 d-block" height="48" loading="lazy" src="/media/cache/c1/d1/c1d1241f0d274431e54838b16ab3c6ad.jpg" width="48"/>
# </a>
# <div class="d-flex justify-content-center mt-3">
# <a class="btn-direct-apply text-dark p-1" href="/J26118/apply/" id="26118" rel="nofollow noopener" target="_blank" title="Apply for this job directly on Wonolo's career site"><i class="fas fa-edit"></i></a>
# <a class="btn-direct-apply text-dark p-1" href="/job/mark/26118/create/" rel="nofollow" title="Save this job for later application"><i class="fas fa-list-ol"></i></a>
# </div>
# </div>
# <a class="col list-group-item-action px-2 py-3" href="/job/26118-data-analytics-engineer-co-op-fall-2022/" title="View full details of `Data Analytics Engineer Co-op - Fall 2022` vacancy">
# <div class="float-right text-right d-inline-block w-25 ml-2">
# <span class="d-block d-md-none text-break job-list-item-location">Canada, Remote</span>
# <span class="d-none d-md-block text-break job-list-item-location">Canada, Remote</span>
# <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
# </div>
# <p class="m-0 text-muted job-list-item-company">Wonolo</p>
# <h2 class="h4 mb-1">Data Analytics Engineer Co-op - Fall 2022</h2>
# <span class="badge badge-light badge-pill">CAD</span>
# <span class="badge badge-light badge-pill">Data Analytics</span>
# <span class="badge badge-light badge-pill">Data pipelines</span>
# <span class="badge badge-light badge-pill">Engineering</span>
# <span class="badge badge-light badge-pill">ETL</span>
# <span class="badge badge-light badge-pill">Pipelines</span>
# <span class="badge badge-light badge-pill">Python</span>
# <span class="badge badge-light badge-pill">+1</span>
# <br/>
# <span class="badge badge-success badge-pill">Career development</span>
# <span class="badge badge-success badge-pill">Competitive pay</span>
# <span class="badge badge-success badge-pill">Equity</span>
# <span class="badge badge-success badge-pill">Flex hours</span>
# <span class="badge badge-success badge-pill">Startup environment</span>
# <span class="badge badge-success badge-pill">+2</span>
# </a>
# </div>
# </div>
# <div class="list-group-item px-2 px-lg-3 py-0">
# <div class="row">
# <div class="col-2 col-sm-1 px-2 py-3">
# <a href="/jobs-at-quantium/" title="Show all open positions at Quantium">
# <img alt="Quantium logo" class="mx-auto my-1 d-block" height="48" loading="lazy" src="/media/cache/f0/e0/f0e03ad36641a363f818938e2fb07ca0.jpg" width="48"/>
# </a>
# <div class="d-flex justify-content-center mt-3">
# <a class="btn-direct-apply text-dark p-1" href="/J26111/apply/" id="26111" rel="nofollow noopener" target="_blank" title="Apply for this job directly on Quantium's career site"><i class="fas fa-edit"></i></a>
# <a class="btn-direct-apply text-dark p-1" href="/job/mark/26111/create/" rel="nofollow" title="Save this job for later application"><i class="fas fa-list-ol"></i></a>
# </div>
# </div>
# <a class="col list-group-item-action px-2 py-3" href="/job/26111-lead-analyst-data-management/" title="View full details of `Lead Analyst, Data Management` vacancy">
# <div class="float-right text-right d-inline-block w-25 ml-2">
# <span class="d-block d-md-none text-break job-list-item-location">Sydney, New South Wales, …</span>
# <span class="d-none d-md-block text-break job-list-item-location">Sydney, New South Wales, Australia</span>
# <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
# <div class="d-block">
# <span class="badge badge-info badge-pill my-md-1 d-md-none">Executive</span>
# <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Executive-level</span>
# </div>
# </div>
# <p class="m-0 text-muted job-list-item-company">Quantium</p>
# <h2 class="h4 mb-1">Lead Analyst, Data Management</h2>
# <span class="badge badge-light badge-pill">Agile</span>
# <span class="badge badge-light badge-pill">Big Data</span>
# <span class="badge badge-light badge-pill">Consulting</span>
# <span class="badge badge-light badge-pill">Data analysis</span>
# <span class="badge badge-light badge-pill">Data Analytics</span>
# <span class="badge badge-light badge-pill">Data management</span>
# <span class="badge badge-light badge-pill">Engineering</span>
# <span class="badge badge-light badge-pill">+4</span>
# <br/>
# <span class="badge badge-success badge-pill">Career development</span>
# <span class="badge badge-success badge-pill">Startup environment</span>
# <span class="badge badge-success badge-pill">Team events</span>
# </a>
# </div>
# </div>
# <div class="list-group-item px-2 px-lg-3 py-0">
# <div class="row">
# <div class="col-2 col-sm-1 px-2 py-3">
# <a href="/jobs-at-coupang/" title="Show all open positions at Coupang">
# <img alt="Coupang logo" class="mx-auto my-1 d-block" height="48" loading="lazy" src="/media/cache/23/12/2312ea7afa0dacf6f4b8babc85653d46.jpg" width="48"/>
# </a>
# <div class="d-flex justify-content-center mt-3">
# <a class="btn-direct-apply text-dark p-1" href="/J26114/apply/" id="26114" rel="nofollow noopener" target="_blank" title="Apply for this job directly on Coupang's career site"><i class="fas fa-edit"></i></a>
# <a class="btn-direct-apply text-dark p-1" href="/job/mark/26114/create/" rel="nofollow" title="Save this job for later application"><i class="fas fa-list-ol"></i></a>
# </div>
# </div>
# <a class="col list-group-item-action px-2 py-3" href="/job/26114-sr-data-analyst-cmg-analytics/" title="View full details of `Sr. Data Analyst (CMG Analytics)` vacancy">
# <div class="float-right text-right d-inline-block w-25 ml-2">
# <span class="d-block d-md-none text-break job-list-item-location">Seoul, South Korea</span>
# <span class="d-none d-md-block text-break job-list-item-location">Seoul, South Korea</span>
# <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
# <div class="d-block">
# <span class="badge badge-info badge-pill my-md-1 d-md-none">Senior</span>
# <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Senior-level</span>
# </div>
# <div class="d-block">
# <span class="badge badge-success badge-pill d-none d-md-inline-block">USD 50K - 85K *</span>
# <span class="badge badge-success badge-pill d-md-none">USD 50K+ *</span>
# </div>
# </div>
# <p class="m-0 text-muted job-list-item-company">Coupang</p>
# <h2 class="h4 mb-1">Sr. Data Analyst (CMG Analytics)</h2>
# <span class="badge badge-light badge-pill">Airflow</span>
# <span class="badge badge-light badge-pill">E-commerce</span>
# <span class="badge badge-light badge-pill">Looker</span>
# <span class="badge badge-light badge-pill">Power BI</span>
# <span class="badge badge-light badge-pill">Python</span>
# <span class="badge badge-light badge-pill">Qlik</span>
# <span class="badge badge-light badge-pill">R</span>
# <span class="badge badge-light badge-pill">+2</span>
# <br/>
# </a>
# </div>
# </div>
# <div class="list-group-item px-2 px-lg-3 py-0">
# <div class="row">
# <div class="col-2 col-sm-1 px-2 py-3">
# <a href="/jobs-at-clari/" title="Show all open positions at Clari">
# <img alt="Clari logo" class="mx-auto my-1 d-block" height="48" loading="lazy" src="/media/cache/0e/c1/0ec1ac3db7ad44c9bcc3c61381b91f8a.jpg" width="48"/>
# </a>
# <div class="d-flex justify-content-center mt-3">
# <a class="btn-direct-apply text-dark p-1" href="/J26117/apply/" id="26117" rel="nofollow noopener" target="_blank" title="Apply for this job directly on Clari's career site"><i class="fas fa-edit"></i></a>
# <a class="btn-direct-apply text-dark p-1" href="/job/mark/26117/create/" rel="nofollow" title="Save this job for later application"><i class="fas fa-list-ol"></i></a>
# </div>
# </div>
# <a class="col list-group-item-action px-2 py-3" href="/job/26117-sr-data-analyst-marketing/" title="View full details of `Sr. Data Analyst, Marketing` vacancy">
# <div class="float-right text-right d-inline-block w-25 ml-2">
# <span class="d-block d-md-none text-break job-list-item-location">Seattle, WA</span>
# <span class="d-none d-md-block text-break job-list-item-location">Seattle, WA</span>
# <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
# <div class="d-block">
# <span class="badge badge-info badge-pill my-md-1 d-md-none">Senior</span>
# <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Senior-level</span>
# </div>
# <div class="d-block">
# <span class="badge badge-success badge-pill d-none d-md-inline-block">USD 50K - 85K *</span>
# <span class="badge badge-success badge-pill d-md-none">USD 50K+ *</span>
# </div>
# </div>
# <p class="m-0 text-muted job-list-item-company">Clari</p>
# <h2 class="h4 mb-1">Sr. Data Analyst, Marketing</h2>
# <span class="badge badge-light badge-pill">A/B testing</span>
# <span class="badge badge-light badge-pill">Consulting</span>
# <span class="badge badge-light badge-pill">Finance</span>
# <span class="badge badge-light badge-pill">Python</span>
# <span class="badge badge-light badge-pill">R</span>
# <span class="badge badge-light badge-pill">SQL</span>
# <span class="badge badge-light badge-pill">Tableau</span>
# <span class="badge badge-light badge-pill">+1</span>
# <br/>
# <span class="badge badge-success badge-pill">Equity</span>
# <span class="badge badge-success badge-pill">Fertility benefits</span>
# <span class="badge badge-success badge-pill">Flex hours</span>
# <span class="badge badge-success badge-pill">Parental leave</span>
# <span class="badge badge-success badge-pill">Startup environment</span>
# <span class="badge badge-success badge-pill">+1</span>
# </a>
# </div>
# </div>
# <div class="list-group-item px-2 px-lg-3 py-0">
# <div class="row">
# <div class="col-2 col-sm-1 px-2 py-3">
# <a href="/jobs-at-mintel/" title="Show all open positions at Mintel">
# <img alt="Mintel logo" class="mx-auto my-1 d-block" height="48" loading="lazy" src="/media/cache/03/ee/03ee755a9fb02e10654b60bcf91a2c27.jpg" width="48"/>
# </a>
# <div class="d-flex justify-content-center mt-3">
# <a class="btn-direct-apply text-dark p-1" href="/J26115/apply/" id="26115" rel="nofollow noopener" target="_blank" title="Apply for this job directly on Mintel's career site"><i class="fas fa-edit"></i></a>
# <a class="btn-direct-apply text-dark p-1" href="/job/mark/26115/create/" rel="nofollow" title="Save this job for later application"><i class="fas fa-list-ol"></i></a>
# </div>
# </div>
# <a class="col list-group-item-action px-2 py-3" href="/job/26115-consumer-research-data-analyst/" title="View full details of `Consumer Research &amp; Data Analyst` vacancy">
# <div class="float-right text-right d-inline-block w-25 ml-2">
# <span class="d-block d-md-none text-break job-list-item-location">Chicago</span>
# <span class="d-none d-md-block text-break job-list-item-location">Chicago</span>
# <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
# <div class="d-block">
# <span class="badge badge-info badge-pill my-md-1 d-md-none">Senior</span>
# <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Senior-level</span>
# </div>
# <div class="d-block">
# <span class="badge badge-success badge-pill d-none d-md-inline-block">USD 50K - 85K *</span>
# <span class="badge badge-success badge-pill d-md-none">USD 50K+ *</span>
# </div>
# </div>
# <p class="m-0 text-muted job-list-item-company">Mintel</p>
# <h2 class="h4 mb-1">Consumer Research &amp; Data Analyst</h2>
# <span class="badge badge-light badge-pill">Data analysis</span>
# <span class="badge badge-light badge-pill">Data Analytics</span>
# <span class="badge badge-light badge-pill">Finance</span>
# <span class="badge badge-light badge-pill">R</span>
# <span class="badge badge-light badge-pill">Research</span>
# <span class="badge badge-light badge-pill">Statistics</span>
# <span class="badge badge-light badge-pill">Survey data</span>
# <br/>
# <span class="badge badge-success badge-pill">Career development</span>
# </a>
# </div>
# </div>
# <div class="list-group-item px-2 px-lg-3 py-0">
# <div class="row">
# <div class="col-2 col-sm-1 px-2 py-3">
# <a href="/jobs-at-so-energy/" title="Show all open positions at So Energy">
# <img alt="So Energy logo" class="mx-auto my-1 d-block" height="48" loading="lazy" src="/media/cache/22/af/22affff2cd2e26756bec1f7a4e888357.jpg" width="48"/>
# </a>
# <div class="d-flex justify-content-center mt-3">
# <a class="btn-direct-apply text-dark p-1" href="/J26166/apply/" id="26166" rel="nofollow noopener" target="_blank" title="Apply for this job directly on So Energy's career site"><i class="fas fa-edit"></i></a>
# <a class="btn-direct-apply text-dark p-1" href="/job/mark/26166/create/" rel="nofollow" title="Save this job for later application"><i class="fas fa-list-ol"></i></a>
# </div>
# </div>
# <a class="col list-group-item-action px-2 py-3" href="/job/26166-insight-analyst/" title="View full details of `Insight Analyst` vacancy">
# <div class="float-right text-right d-inline-block w-25 ml-2">
# <span class="d-block d-md-none text-break job-list-item-location">United Kingdom</span>
# <span class="d-none d-md-block text-break job-list-item-location">United Kingdom</span>
# <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
# <div class="d-block">
# <span class="badge badge-info badge-pill my-md-1 d-md-none">Mid</span>
# <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Mid-level</span>
# </div>
# </div>
# <p class="m-0 text-muted job-list-item-company">So Energy</p>
# <h2 class="h4 mb-1">Insight Analyst</h2>
# <span class="badge badge-light badge-pill">Agile</span>
# <span class="badge badge-light badge-pill">BigQuery</span>
# <span class="badge badge-light badge-pill">Consulting</span>
# <span class="badge badge-light badge-pill">Data analysis</span>
# <span class="badge badge-light badge-pill">Data Analytics</span>
# <span class="badge badge-light badge-pill">Data Mining</span>
# <span class="badge badge-light badge-pill">Data visualization</span>
# <span class="badge badge-light badge-pill">+12</span>
# <br/>
# <span class="badge badge-success badge-pill">Career development</span>
# <span class="badge badge-success badge-pill">Competitive pay</span>
# </a>
# </div>
# </div>
# <div class="list-group-item px-2 px-lg-3 py-0">
# <div class="row">
# <div class="col-2 col-sm-1 px-2 py-3">
# <a href="/jobs-at-ninja-van/" title="Show all open positions at Ninja Van">
# <img alt="Ninja Van logo" class="mx-auto my-1 d-block" height="48" loading="lazy" src="/media/cache/24/4f/244fdc8cfbb230f51b7755faa1688f55.jpg" width="48"/>
# </a>
# <div class="d-flex justify-content-center mt-3">
# <a class="btn-direct-apply text-dark p-1" href="/J26120/apply/" id="26120" rel="nofollow noopener" target="_blank" title="Apply for this job directly on Ninja Van's career site"><i class="fas fa-edit"></i></a>
# <a class="btn-direct-apply text-dark p-1" href="/job/mark/26120/create/" rel="nofollow" title="Save this job for later application"><i class="fas fa-list-ol"></i></a>
# </div>
# </div>
# <a class="col list-group-item-action px-2 py-3" href="/job/26120-regional-data-analyst-cross-border-based-in-malaysia/" title="View full details of `Regional Data Analyst, Cross Border (based in Malaysia)` vacancy">
# <div class="float-right text-right d-inline-block w-25 ml-2">
# <span class="d-block d-md-none text-break job-list-item-location">Shah Alam, Malaysia</span>
# <span class="d-none d-md-block text-break job-list-item-location">Shah Alam, Malaysia</span>
# <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
# <div class="d-block">
# <span class="badge badge-success badge-pill d-none d-md-inline-block">USD 50K - 85K *</span>
# <span class="badge badge-success badge-pill d-md-none">USD 50K+ *</span>
# </div>
# </div>
# <p class="m-0 text-muted job-list-item-company">Ninja Van</p>
# <h2 class="h4 mb-1">Regional Data Analyst, Cross Border (based in Malaysia)</h2>
# <span class="badge badge-light badge-pill">Business Intelligence</span>
# <span class="badge badge-light badge-pill">Data Analytics</span>
# <span class="badge badge-light badge-pill">Excel</span>
# <span class="badge badge-light badge-pill">KPIs</span>
# <span class="badge badge-light badge-pill">Python</span>
# <span class="badge badge-light badge-pill">SQL</span>
# <br/>
# </a>
# </div>
# </div>
# <a class="list-group-item list-group-item-action text-center" data-offset="100" href="#" id="load-more-jobs">
# <p class="lead text-primary mt-2">Load more</p>
# </a>
# </div>

# %%
# focus on needed information
needed_info = results.find_all('a', {'class':'col list-group-item-action px-2 py-3'})
needed_info
# Out:
# [<a class="col list-group-item-action px-2 py-3" href="/job/24108-business-intelligence-analyst/" title="View full details of `Business Intelligence Analyst` vacancy">
#  <div class="float-right text-right d-inline-block w-25 ml-2">
#  <span class="d-block d-md-none text-break job-list-item-location">Lincoln, RI, 02865</span>
#  <span class="d-none d-md-block text-break job-list-item-location">Lincoln, RI, 02865</span>
#  <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
#  <div class="d-block">
#  <span class="badge badge-info badge-pill my-md-1 d-md-none">Mid</span>
#  <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Mid-level</span>
#  </div>
#  </div>
#  <p class="m-0 text-muted job-list-item-company">Amica Mutual Insurance Company</p>
#  <h2 class="h4 mb-1">Business Intelligence Analyst</h2>
#  <span class="badge badge-light badge-pill">Business Intelligence</span>
#  <span class="badge badge-light badge-pill">Data management</span>
#  <span class="badge badge-light badge-pill">Power BI</span>
#  <span class="badge badge-light badge-pill">Python</span>
#  <span class="badge badge-light badge-pill">R</span>
#  <span class="badge badge-light badge-pill">SAS</span>
#  <span class="badge badge-light badge-pill">SQL</span>
#  <span class="badge badge-light badge-pill">+2</span>
#  <br/>
#  <span class="badge badge-success badge-pill">Competitive pay</span>
#  <span class="badge badge-success badge-pill">Conferences</span>
#  <span class="badge badge-success badge-pill">Fitness / gym</span>
#  <span class="badge badge-success badge-pill">Health care</span>
#  <span class="badge badge-success badge-pill">Insurance</span>
#  <span class="badge badge-success badge-pill">+3</span>
#  </a>,
#  <a class="col list-group-item-action px-2 py-3" href="/job/24107-lead-business-intelligence-analyst/" title="View full details of `Lead Business Intelligence Analyst` vacancy">
#  <div class="float-right text-right d-inline-block w-25 ml-2">
#  <span class="d-block d-md-none text-break job-list-item-location">Lincoln, RI, 02865</span>
#  <span class="d-none d-md-block text-break job-list-item-location">Lincoln, RI, 02865</span>
#  <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
#  <div class="d-block">
#  <span class="badge badge-info badge-pill my-md-1 d-md-none">Senior</span>
#  <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Senior-level</span>
#  </div>
#  </div>
#  <p class="m-0 text-muted job-list-item-company">Amica Mutual Insurance Company</p>
#  <h2 class="h4 mb-1">Lead Business Intelligence Analyst</h2>
#  <span class="badge badge-light badge-pill">Business Intelligence</span>
#  <span class="badge badge-light badge-pill">Data management</span>
#  <span class="badge badge-light badge-pill">KPIs</span>
#  <span class="badge badge-light badge-pill">Python</span>
#  <span class="badge badge-light badge-pill">R</span>
#  <span class="badge badge-light badge-pill">SAS</span>
#  <span class="badge badge-light badge-pill">SQL</span>
#  <span class="badge badge-light badge-pill">+1</span>
#  <br/>
#  <span class="badge badge-success badge-pill">Competitive pay</span>
#  <span class="badge badge-success badge-pill">Conferences</span>
#  <span class="badge badge-success badge-pill">Fitness / gym</span>
#  <span class="badge badge-success badge-pill">Flex vacation</span>
#  <span class="badge badge-success badge-pill">Health care</span>
#  <span class="badge badge-success badge-pill">+4</span>
#  </a>,
#  <a class="col list-group-item-action px-2 py-3" href="/job/26580-junior-data-analyst/" title="View full details of `Junior Data Analyst` vacancy">
#  <div class="float-right text-right d-inline-block w-25 ml-2">
#  <span class="d-block d-md-none text-break job-list-item-location">Poland</span>
#  <span class="d-none d-md-block text-break job-list-item-location">Poland</span>
#  <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
#  <div class="d-block">
#  <span class="badge badge-info badge-pill my-md-1 d-md-none">Entry</span>
#  <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Entry-level</span>
#  </div>
#  <div class="d-block">
#  <span class="badge badge-success badge-pill d-none d-md-inline-block">USD 30K - 80K *</span>
#  <span class="badge badge-success badge-pill d-md-none">USD 30K+ *</span>
#  </div>
#  </div>
#  <p class="m-0 text-muted job-list-item-company">Nielsen</p>
#  <h2 class="h4 mb-1">Junior Data Analyst</h2>
#  <span class="badge badge-light badge-pill">Consulting</span>
#  <span class="badge badge-light badge-pill">Data analysis</span>
#  <span class="badge badge-light badge-pill">Econometrics</span>
#  <span class="badge badge-light badge-pill">Excel</span>
#  <span class="badge badge-light badge-pill">Market research</span>
#  <span class="badge badge-light badge-pill">Python</span>
#  <span class="badge badge-light badge-pill">R</span>
#  <span class="badge badge-light badge-pill">+5</span>
#  <br/>
#  <span class="badge badge-success badge-pill">Career development</span>
#  </a>,
#  <a class="col list-group-item-action px-2 py-3" href="/job/26584-senior-vice-president-data-analytics-bi/" title="View full details of `Senior Vice President, Data Analytics &amp; BI` vacancy">
#  <div class="float-right text-right d-inline-block w-25 ml-2">
#  <span class="d-block d-md-none text-break job-list-item-location">Los Angeles, California, United …</span>
#  <span class="d-none d-md-block text-break job-list-item-location">Los Angeles, California, United States - Remote</span>
#  <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
#  <div class="d-block">
#  <span class="badge badge-info badge-pill my-md-1 d-md-none">Senior</span>
#  <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Senior-level</span>
#  </div>
#  </div>
#  <p class="m-0 text-muted job-list-item-company">Athletic Greens</p>
#  <h2 class="h4 mb-1">Senior Vice President, Data Analytics &amp; BI</h2>
#  <span class="badge badge-light badge-pill">Airflow</span>
#  <span class="badge badge-light badge-pill">BigQuery</span>
#  <span class="badge badge-light badge-pill">Business Intelligence</span>
#  <span class="badge badge-light badge-pill">Data Analytics</span>
#  <span class="badge badge-light badge-pill">Data management</span>
#  <span class="badge badge-light badge-pill">Data strategy</span>
#  <span class="badge badge-light badge-pill">E-commerce</span>
#  <span class="badge badge-light badge-pill">+6</span>
#  <br/>
#  <span class="badge badge-success badge-pill">401(k) matching</span>
#  <span class="badge badge-success badge-pill">Flex vacation</span>
#  <span class="badge badge-success badge-pill">Gear</span>
#  <span class="badge badge-success badge-pill">Health care</span>
#  <span class="badge badge-success badge-pill">Home office stipend</span>
#  <span class="badge badge-success badge-pill">+5</span>
#  </a>,
#  <a class="col list-group-item-action px-2 py-3" href="/job/26569-staff-analytics-engineer-central-data/" title="View full details of `Staff Analytics Engineer, Central Data` vacancy">
#  <div class="float-right text-right d-inline-block w-25 ml-2">
#  <span class="d-block d-md-none text-break job-list-item-location">United States</span>
#  <span class="d-none d-md-block text-break job-list-item-location">United States</span>
#  <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
#  <div class="d-block">
#  <span class="badge badge-info badge-pill my-md-1 d-md-none">Senior</span>
#  <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Senior-level</span>
#  </div>
#  <div class="d-block">
#  <span class="badge badge-success badge-pill d-none d-md-inline-block">USD 180K - 245K</span>
#  <span class="badge badge-success badge-pill d-md-none">USD 180K+</span>
#  </div>
#  </div>
#  <p class="m-0 text-muted job-list-item-company">Airbnb</p>
#  <h2 class="h4 mb-1">Staff Analytics Engineer, Central Data</h2>
#  <span class="badge badge-light badge-pill">Airflow</span>
#  <span class="badge badge-light badge-pill">Data analysis</span>
#  <span class="badge badge-light badge-pill">Engineering</span>
#  <span class="badge badge-light badge-pill">ETL</span>
#  <span class="badge badge-light badge-pill">Machine Learning</span>
#  <span class="badge badge-light badge-pill">Pipelines</span>
#  <span class="badge badge-light badge-pill">Predictive modeling</span>
#  <span class="badge badge-light badge-pill">+6</span>
#  <br/>
#  <span class="badge badge-success badge-pill">Career development</span>
#  <span class="badge badge-success badge-pill">Salary bonus</span>
#  </a>,
#  <a class="col list-group-item-action px-2 py-3" href="/job/26572-data-analyst-clinical-informatics/" title="View full details of `Data Analyst - Clinical Informatics` vacancy">
#  <div class="float-right text-right d-inline-block w-25 ml-2">
#  <span class="d-block d-md-none text-break job-list-item-location">Chicago, IL</span>
#  <span class="d-none d-md-block text-break job-list-item-location">Chicago, IL</span>
#  <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
#  <div class="d-block">
#  <span class="badge badge-success badge-pill d-none d-md-inline-block">USD 50K - 85K *</span>
#  <span class="badge badge-success badge-pill d-md-none">USD 50K+ *</span>
#  </div>
#  </div>
#  <p class="m-0 text-muted job-list-item-company">Tempus</p>
#  <h2 class="h4 mb-1">Data Analyst - Clinical Informatics</h2>
#  <span class="badge badge-light badge-pill">Data pipelines</span>
#  <span class="badge badge-light badge-pill">Pipelines</span>
#  <span class="badge badge-light badge-pill">Python</span>
#  <span class="badge badge-light badge-pill">SQL</span>
#  <br/>
#  </a>,
#  <a class="col list-group-item-action px-2 py-3" href="/job/26573-senior-product-data-analytics/" title="View full details of `Senior Product Data Analytics` vacancy">
#  <div class="float-right text-right d-inline-block w-25 ml-2">
#  <span class="d-block d-md-none text-break job-list-item-location">Sao Paulo</span>
#  <span class="d-none d-md-block text-break job-list-item-location">Sao Paulo</span>
#  <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
#  <div class="d-block">
#  <span class="badge badge-info badge-pill my-md-1 d-md-none">Senior</span>
#  <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Senior-level</span>
#  </div>
#  </div>
#  <p class="m-0 text-muted job-list-item-company">Adyen</p>
#  <h2 class="h4 mb-1">Senior Product Data Analytics</h2>
#  <span class="badge badge-light badge-pill">Airflow</span>
#  <span class="badge badge-light badge-pill">Big Data</span>
#  <span class="badge badge-light badge-pill">Data Analytics</span>
#  <span class="badge badge-light badge-pill">Data pipelines</span>
#  <span class="badge badge-light badge-pill">Engineering</span>
#  <span class="badge badge-light badge-pill">ETL</span>
#  <span class="badge badge-light badge-pill">Pipelines</span>
#  <span class="badge badge-light badge-pill">+5</span>
#  <br/>
#  <span class="badge badge-success badge-pill">Startup environment</span>
#  </a>,
#  <a class="col list-group-item-action px-2 py-3" href="/job/26526-data-scientist-international-analytics/" title="View full details of `Data Scientist, International Analytics` vacancy">
#  <div class="float-right text-right d-inline-block w-25 ml-2">
#  <span class="d-block d-md-none text-break job-list-item-location">Toronto, ON</span>
#  <span class="d-none d-md-block text-break job-list-item-location">Toronto, ON</span>
#  <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
#  <div class="d-block">
#  <span class="badge badge-info badge-pill my-md-1 d-md-none">Senior</span>
#  <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Senior-level</span>
#  </div>
#  <div class="d-block">
#  <span class="badge badge-success badge-pill d-none d-md-inline-block">USD 68K - 135K *</span>
#  <span class="badge badge-success badge-pill d-md-none">USD 68K+ *</span>
#  </div>
#  </div>
#  <p class="m-0 text-muted job-list-item-company">DoorDash</p>
#  <h2 class="h4 mb-1">Data Scientist, International Analytics</h2>
#  <span class="badge badge-light badge-pill">A/B testing</span>
#  <span class="badge badge-light badge-pill">Consulting</span>
#  <span class="badge badge-light badge-pill">Data Analytics</span>
#  <span class="badge badge-light badge-pill">Economics</span>
#  <span class="badge badge-light badge-pill">ETL</span>
#  <span class="badge badge-light badge-pill">Excel</span>
#  <span class="badge badge-light badge-pill">Looker</span>
#  <span class="badge badge-light badge-pill">+8</span>
#  <br/>
#  <span class="badge badge-success badge-pill">Flex vacation</span>
#  </a>,
#  <a class="col list-group-item-action px-2 py-3" href="/job/26575-data-analyst/" title="View full details of `Data Analyst` vacancy">
#  <div class="float-right text-right d-inline-block w-25 ml-2">
#  <span class="d-block d-md-none text-break job-list-item-location">Remote</span>
#  <span class="d-none d-md-block text-break job-list-item-location">Remote</span>
#  <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
#  <div class="d-block">
#  <span class="badge badge-info badge-pill my-md-1 d-md-none">Senior</span>
#  <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Senior-level</span>
#  </div>
#  <div class="d-block">
#  <span class="badge badge-success badge-pill d-none d-md-inline-block">USD 50K - 85K *</span>
#  <span class="badge badge-success badge-pill d-md-none">USD 50K+ *</span>
#  </div>
#  </div>
#  <p class="m-0 text-muted job-list-item-company">Archive</p>
#  <h2 class="h4 mb-1">Data Analyst</h2>
#  <span class="badge badge-light badge-pill">Data visualization</span>
#  <span class="badge badge-light badge-pill">Looker</span>
#  <span class="badge badge-light badge-pill">SQL</span>
#  <span class="badge badge-light badge-pill">Tableau</span>
#  <br/>
#  </a>,
#  <a class="col list-group-item-action px-2 py-3" href="/job/26570-analytics-engineer-remote/" title="View full details of `Analytics Engineer - Remote` vacancy">
#  <div class="float-right text-right d-inline-block w-25 ml-2">
#  <span class="d-block d-md-none text-break job-list-item-location">Canada</span>
#  <span class="d-none d-md-block text-break job-list-item-location">Canada</span>
#  <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
#  <div class="d-block">
#  <span class="badge badge-info badge-pill my-md-1 d-md-none">Senior</span>
#  <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Senior-level</span>
#  </div>
#  </div>
#  <p class="m-0 text-muted job-list-item-company">KOHO</p>
#  <h2 class="h4 mb-1">Analytics Engineer - Remote</h2>
#  <span class="badge badge-light badge-pill">Data Analytics</span>
#  <span class="badge badge-light badge-pill">Engineering</span>
#  <span class="badge badge-light badge-pill">Machine Learning</span>
#  <span class="badge badge-light badge-pill">Python</span>
#  <span class="badge badge-light badge-pill">SQL</span>
#  <span class="badge badge-light badge-pill">Testing</span>
#  <br/>
#  <span class="badge badge-success badge-pill">Home office stipend</span>
#  </a>,
#  <a class="col list-group-item-action px-2 py-3" href="/job/26541-data-analyst-bi-developer-mfd/" title="View full details of `Data Analyst / BI Developer (m/f/d)` vacancy">
#  <div class="float-right text-right d-inline-block w-25 ml-2">
#  <span class="d-block d-md-none text-break job-list-item-location">Remote</span>
#  <span class="d-none d-md-block text-break job-list-item-location">Remote</span>
#  <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
#  <div class="d-block">
#  <span class="badge badge-info badge-pill my-md-1 d-md-none">Senior</span>
#  <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Senior-level</span>
#  </div>
#  </div>
#  <p class="m-0 text-muted job-list-item-company">SoSafe</p>
#  <h2 class="h4 mb-1">Data Analyst / BI Developer (m/f/d)</h2>
#  <span class="badge badge-light badge-pill">Business Intelligence</span>
#  <span class="badge badge-light badge-pill">Data analysis</span>
#  <span class="badge badge-light badge-pill">Data visualization</span>
#  <span class="badge badge-light badge-pill">KPIs</span>
#  <span class="badge badge-light badge-pill">Power BI</span>
#  <span class="badge badge-light badge-pill">Python</span>
#  <span class="badge badge-light badge-pill">Security</span>
#  <span class="badge badge-light badge-pill">+3</span>
#  <br/>
#  <span class="badge badge-success badge-pill">Career development</span>
#  <span class="badge badge-success badge-pill">Competitive pay</span>
#  <span class="badge badge-success badge-pill">Flex vacation</span>
#  <span class="badge badge-success badge-pill">Lunch / meals</span>
#  <span class="badge badge-success badge-pill">Salary bonus</span>
#  <span class="badge badge-success badge-pill">+1</span>
#  </a>,
#  <a class="col list-group-item-action px-2 py-3" href="/job/26579-data-analytics-lead/" title="View full details of `Data Analytics Lead` vacancy">
#  <div class="float-right text-right d-inline-block w-25 ml-2">
#  <span class="d-block d-md-none text-break job-list-item-location">London</span>
#  <span class="d-none d-md-block text-break job-list-item-location">London</span>
#  <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
#  </div>
#  <p class="m-0 text-muted job-list-item-company">Mintel</p>
#  <h2 class="h4 mb-1">Data Analytics Lead</h2>
#  <span class="badge badge-light badge-pill">Consulting</span>
#  <span class="badge badge-light badge-pill">Data Analytics</span>
#  <span class="badge badge-light badge-pill">Looker</span>
#  <span class="badge badge-light badge-pill">Market research</span>
#  <span class="badge badge-light badge-pill">Power BI</span>
#  <span class="badge badge-light badge-pill">Research</span>
#  <span class="badge badge-light badge-pill">SQL</span>
#  <span class="badge badge-light badge-pill">+1</span>
#  <br/>
#  <span class="badge badge-success badge-pill">Career development</span>
#  <span class="badge badge-success badge-pill">Flex vacation</span>
#  </a>,
#  <a class="col list-group-item-action px-2 py-3" href="/job/26583-senior-data-analyst/" title="View full details of `Senior Data Analyst` vacancy">
#  <div class="float-right text-right d-inline-block w-25 ml-2">
#  <span class="d-block d-md-none text-break job-list-item-location">London, England, United Kingdom …</span>
#  <span class="d-none d-md-block text-break job-list-item-location">London, England, United Kingdom - Remote</span>
#  <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
#  <div class="d-block">
#  <span class="badge badge-info badge-pill my-md-1 d-md-none">Mid</span>
#  <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Mid-level</span>
#  </div>
#  <div class="d-block">
#  <span class="badge badge-success badge-pill d-none d-md-inline-block">USD 51K - 90K *</span>
#  <span class="badge badge-success badge-pill d-md-none">USD 51K+ *</span>
#  </div>
#  </div>
#  <p class="m-0 text-muted job-list-item-company">FitXR</p>
#  <h2 class="h4 mb-1">Senior Data Analyst</h2>
#  <span class="badge badge-light badge-pill">A/B testing</span>
#  <span class="badge badge-light badge-pill">BigQuery</span>
#  <span class="badge badge-light badge-pill">DevOps</span>
#  <span class="badge badge-light badge-pill">Engineering</span>
#  <span class="badge badge-light badge-pill">Julia</span>
#  <span class="badge badge-light badge-pill">Python</span>
#  <span class="badge badge-light badge-pill">R</span>
#  <span class="badge badge-light badge-pill">+2</span>
#  <br/>
#  <span class="badge badge-success badge-pill">Career development</span>
#  <span class="badge badge-success badge-pill">Competitive pay</span>
#  <span class="badge badge-success badge-pill">Equity</span>
#  <span class="badge badge-success badge-pill">Flex vacation</span>
#  <span class="badge badge-success badge-pill">Gear</span>
#  <span class="badge badge-success badge-pill">+3</span>
#  </a>,
#  <a class="col list-group-item-action px-2 py-3" href="/job/26582-senior-data-analyst-thailand/" title="View full details of `Senior Data Analyst - Thailand` vacancy">
#  <div class="float-right text-right d-inline-block w-25 ml-2">
#  <span class="d-block d-md-none text-break job-list-item-location">Bangkok, Bangkok, Thailand</span>
#  <span class="d-none d-md-block text-break job-list-item-location">Bangkok, Bangkok, Thailand</span>
#  <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
#  <div class="d-block">
#  <span class="badge badge-info badge-pill my-md-1 d-md-none">Mid</span>
#  <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Mid-level</span>
#  </div>
#  <div class="d-block">
#  <span class="badge badge-success badge-pill d-none d-md-inline-block">USD 51K - 90K *</span>
#  <span class="badge badge-success badge-pill d-md-none">USD 51K+ *</span>
#  </div>
#  </div>
#  <p class="m-0 text-muted job-list-item-company">LingoAce</p>
#  <h2 class="h4 mb-1">Senior Data Analyst - Thailand</h2>
#  <span class="badge badge-light badge-pill">Data Analytics</span>
#  <span class="badge badge-light badge-pill">Economics</span>
#  <span class="badge badge-light badge-pill">Statistics</span>
#  <br/>
#  <span class="badge badge-success badge-pill">Startup environment</span>
#  </a>,
#  <a class="col list-group-item-action px-2 py-3" href="/job/26576-financial-data-analyst-latam-remote/" title="View full details of `Financial Data Analyst - LATAM- REMOTE` vacancy">
#  <div class="float-right text-right d-inline-block w-25 ml-2">
#  <span class="d-block d-md-none text-break job-list-item-location">Mexico City</span>
#  <span class="d-none d-md-block text-break job-list-item-location">Mexico City</span>
#  <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
#  <div class="d-block">
#  <span class="badge badge-info badge-pill my-md-1 d-md-none">Senior</span>
#  <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Senior-level</span>
#  </div>
#  <div class="d-block">
#  <span class="badge badge-success badge-pill d-none d-md-inline-block">USD 50K - 85K *</span>
#  <span class="badge badge-success badge-pill d-md-none">USD 50K+ *</span>
#  </div>
#  </div>
#  <p class="m-0 text-muted job-list-item-company">WPP</p>
#  <h2 class="h4 mb-1">Financial Data Analyst - LATAM- REMOTE</h2>
#  <span class="badge badge-light badge-pill">Consulting</span>
#  <span class="badge badge-light badge-pill">ETL</span>
#  <span class="badge badge-light badge-pill">Finance</span>
#  <span class="badge badge-light badge-pill">Oracle</span>
#  <br/>
#  </a>,
#  <a class="col list-group-item-action px-2 py-3" href="/job/26542-research-engineer-static-analysis-web3/" title="View full details of `Research Engineer, Static Analysis - Web3` vacancy">
#  <div class="float-right text-right d-inline-block w-25 ml-2">
#  <span class="d-block d-md-none text-break job-list-item-location">Bangalore, India</span>
#  <span class="d-none d-md-block text-break job-list-item-location">Bangalore, India</span>
#  <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
#  <div class="d-block">
#  <span class="badge badge-info badge-pill my-md-1 d-md-none">Senior</span>
#  <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Senior-level</span>
#  </div>
#  </div>
#  <p class="m-0 text-muted job-list-item-company">DeepSource</p>
#  <h2 class="h4 mb-1">Research Engineer, Static Analysis - Web3</h2>
#  <span class="badge badge-light badge-pill">Engineering</span>
#  <span class="badge badge-light badge-pill">Research</span>
#  <span class="badge badge-light badge-pill">Testing</span>
#  <br/>
#  </a>,
#  <a class="col list-group-item-action px-2 py-3" href="/job/26574-data-analyst-business-delivery-services/" title="View full details of `Data Analyst, Business Delivery Services` vacancy">
#  <div class="float-right text-right d-inline-block w-25 ml-2">
#  <span class="d-block d-md-none text-break job-list-item-location">Remote</span>
#  <span class="d-none d-md-block text-break job-list-item-location">Remote</span>
#  <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
#  <div class="d-block">
#  <span class="badge badge-info badge-pill my-md-1 d-md-none">Senior</span>
#  <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Senior-level</span>
#  </div>
#  <div class="d-block">
#  <span class="badge badge-success badge-pill d-none d-md-inline-block">USD 80K - 92K</span>
#  <span class="badge badge-success badge-pill d-md-none">USD 80K+</span>
#  </div>
#  </div>
#  <p class="m-0 text-muted job-list-item-company">Argo Group</p>
#  <h2 class="h4 mb-1">Data Analyst, Business Delivery Services</h2>
#  <span class="badge badge-light badge-pill">Agile</span>
#  <span class="badge badge-light badge-pill">Data analysis</span>
#  <span class="badge badge-light badge-pill">Data Mining</span>
#  <span class="badge badge-light badge-pill">Excel</span>
#  <span class="badge badge-light badge-pill">Python</span>
#  <span class="badge badge-light badge-pill">SQL</span>
#  <span class="badge badge-light badge-pill">Statistics</span>
#  <br/>
#  <span class="badge badge-success badge-pill">401(k) matching</span>
#  <span class="badge badge-success badge-pill">Career development</span>
#  <span class="badge badge-success badge-pill">Competitive pay</span>
#  <span class="badge badge-success badge-pill">Equity</span>
#  <span class="badge badge-success badge-pill">Flex hours</span>
#  <span class="badge badge-success badge-pill">+9</span>
#  </a>,
#  <a class="col list-group-item-action px-2 py-3" href="/job/26581-data-analyst/" title="View full details of `Data Analyst` vacancy">
#  <div class="float-right text-right d-inline-block w-25 ml-2">
#  <span class="d-block d-md-none text-break job-list-item-location">Jakarta</span>
#  <span class="d-none d-md-block text-break job-list-item-location">Jakarta</span>
#  <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
#  <div class="d-block">
#  <span class="badge badge-info badge-pill my-md-1 d-md-none">Senior</span>
#  <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Senior-level</span>
#  </div>
#  <div class="d-block">
#  <span class="badge badge-success badge-pill d-none d-md-inline-block">USD 50K - 85K *</span>
#  <span class="badge badge-success badge-pill d-md-none">USD 50K+ *</span>
#  </div>
#  </div>
#  <p class="m-0 text-muted job-list-item-company">Horangi Cyber Security</p>
#  <h2 class="h4 mb-1">Data Analyst</h2>
#  <span class="badge badge-light badge-pill">Agile</span>
#  <span class="badge badge-light badge-pill">AWS</span>
#  <span class="badge badge-light badge-pill">Consulting</span>
#  <span class="badge badge-light badge-pill">Data visualization</span>
#  <span class="badge badge-light badge-pill">Docker</span>
#  <span class="badge badge-light badge-pill">Economics</span>
#  <span class="badge badge-light badge-pill">Engineering</span>
#  <span class="badge badge-light badge-pill">+10</span>
#  <br/>
#  <span class="badge badge-success badge-pill">Team events</span>
#  </a>,
#  <a class="col list-group-item-action px-2 py-3" href="/job/26585-compliance-data-analyst/" title="View full details of `Compliance Data Analyst` vacancy">
#  <div class="float-right text-right d-inline-block w-25 ml-2">
#  <span class="d-block d-md-none text-break job-list-item-location">Scottsdale, Arizona, United States …</span>
#  <span class="d-none d-md-block text-break job-list-item-location">Scottsdale, Arizona, United States - Remote</span>
#  <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
#  <div class="d-block">
#  <span class="badge badge-info badge-pill my-md-1 d-md-none">Entry</span>
#  <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Entry-level</span>
#  </div>
#  <div class="d-block">
#  <span class="badge badge-success badge-pill d-none d-md-inline-block">USD 30K - 80K *</span>
#  <span class="badge badge-success badge-pill d-md-none">USD 30K+ *</span>
#  </div>
#  </div>
#  <p class="m-0 text-muted job-list-item-company">Nuvei</p>
#  <h2 class="h4 mb-1">Compliance Data Analyst</h2>
#  <span class="badge badge-light badge-pill">Data analysis</span>
#  <span class="badge badge-light badge-pill">Data Mining</span>
#  <br/>
#  <span class="badge badge-success badge-pill">401(k) matching</span>
#  <span class="badge badge-success badge-pill">Health care</span>
#  <span class="badge badge-success badge-pill">Yoga</span>
#  </a>,
#  <a class="col list-group-item-action px-2 py-3" href="/job/26578-senior-data-analyst/" title="View full details of `Senior Data Analyst` vacancy">
#  <div class="float-right text-right d-inline-block w-25 ml-2">
#  <span class="d-block d-md-none text-break job-list-item-location">Vitoria, Brazil or Remote, …</span>
#  <span class="d-none d-md-block text-break job-list-item-location">Vitoria, Brazil or Remote, Brazil</span>
#  <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
#  <div class="d-block">
#  <span class="badge badge-info badge-pill my-md-1 d-md-none">Senior</span>
#  <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Senior-level</span>
#  </div>
#  <div class="d-block">
#  <span class="badge badge-success badge-pill d-none d-md-inline-block">USD 50K - 85K *</span>
#  <span class="badge badge-success badge-pill d-md-none">USD 50K+ *</span>
#  </div>
#  </div>
#  <p class="m-0 text-muted job-list-item-company">Trustly</p>
#  <h2 class="h4 mb-1">Senior Data Analyst</h2>
#  <span class="badge badge-light badge-pill">AWS</span>
#  <span class="badge badge-light badge-pill">Banking</span>
#  <span class="badge badge-light badge-pill">Big Data</span>
#  <span class="badge badge-light badge-pill">Data Analytics</span>
#  <span class="badge badge-light badge-pill">Data Mining</span>
#  <span class="badge badge-light badge-pill">Data pipelines</span>
#  <span class="badge badge-light badge-pill">Engineering</span>
#  <span class="badge badge-light badge-pill">+7</span>
#  <br/>
#  <span class="badge badge-success badge-pill">Career development</span>
#  <span class="badge badge-success badge-pill">Flex hours</span>
#  <span class="badge badge-success badge-pill">Flex vacation</span>
#  <span class="badge badge-success badge-pill">Health care</span>
#  <span class="badge badge-success badge-pill">Home office stipend</span>
#  <span class="badge badge-success badge-pill">+5</span>
#  </a>,
#  <a class="col list-group-item-action px-2 py-3" href="/job/26577-technical-data-analyst/" title="View full details of `Technical Data Analyst` vacancy">
#  <div class="float-right text-right d-inline-block w-25 ml-2">
#  <span class="d-block d-md-none text-break job-list-item-location">Remote</span>
#  <span class="d-none d-md-block text-break job-list-item-location">Remote</span>
#  <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
#  <div class="d-block">
#  <span class="badge badge-info badge-pill my-md-1 d-md-none">Senior</span>
#  <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Senior-level</span>
#  </div>
#  <div class="d-block">
#  <span class="badge badge-success badge-pill d-none d-md-inline-block">USD 90K - 108K</span>
#  <span class="badge badge-success badge-pill d-md-none">USD 90K+</span>
#  </div>
#  </div>
#  <p class="m-0 text-muted job-list-item-company">Argo Group</p>
#  <h2 class="h4 mb-1">Technical Data Analyst</h2>
#  <span class="badge badge-light badge-pill">Agile</span>
#  <span class="badge badge-light badge-pill">Data Mining</span>
#  <span class="badge badge-light badge-pill">Excel</span>
#  <span class="badge badge-light badge-pill">MS SQL</span>
#  <span class="badge badge-light badge-pill">Oracle</span>
#  <span class="badge badge-light badge-pill">Power BI</span>
#  <span class="badge badge-light badge-pill">Snowflake</span>
#  <span class="badge badge-light badge-pill">+1</span>
#  <br/>
#  <span class="badge badge-success badge-pill">401(k) matching</span>
#  <span class="badge badge-success badge-pill">Career development</span>
#  <span class="badge badge-success badge-pill">Competitive pay</span>
#  <span class="badge badge-success badge-pill">Equity</span>
#  <span class="badge badge-success badge-pill">Flex hours</span>
#  <span class="badge badge-success badge-pill">+9</span>
#  </a>,
#  <a class="col list-group-item-action px-2 py-3" href="/job/26503-operations-data-analyst-pune-india/" title="View full details of `Operations Data Analyst - Pune India` vacancy">
#  <div class="float-right text-right d-inline-block w-25 ml-2">
#  <span class="d-block d-md-none text-break job-list-item-location">Pune, Maharashtra, India</span>
#  <span class="d-none d-md-block text-break job-list-item-location">Pune, Maharashtra, India</span>
#  <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
#  <div class="d-block">
#  <span class="badge badge-success badge-pill d-none d-md-inline-block">USD 50K - 85K *</span>
#  <span class="badge badge-success badge-pill d-md-none">USD 50K+ *</span>
#  </div>
#  </div>
#  <p class="m-0 text-muted job-list-item-company">Precision Medicine Group</p>
#  <h2 class="h4 mb-1">Operations Data Analyst - Pune India</h2>
#  <span class="badge badge-light badge-pill">Consulting</span>
#  <span class="badge badge-light badge-pill">Engineering</span>
#  <span class="badge badge-light badge-pill">Excel</span>
#  <span class="badge badge-light badge-pill">Python</span>
#  <span class="badge badge-light badge-pill">Research</span>
#  <span class="badge badge-light badge-pill">Snowflake</span>
#  <span class="badge badge-light badge-pill">SQL</span>
#  <br/>
#  </a>,
#  <a class="col list-group-item-action px-2 py-3" href="/job/26444-senior-analytics-engineer-airbnborg/" title="View full details of `Senior Analytics Engineer, Airbnb.org` vacancy">
#  <div class="float-right text-right d-inline-block w-25 ml-2">
#  <span class="d-block d-md-none text-break job-list-item-location">San Francisco, CA</span>
#  <span class="d-none d-md-block text-break job-list-item-location">San Francisco, CA</span>
#  <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
#  <div class="d-block">
#  <span class="badge badge-info badge-pill my-md-1 d-md-none">Senior</span>
#  <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Senior-level</span>
#  </div>
#  <div class="d-block">
#  <span class="badge badge-success badge-pill d-none d-md-inline-block">USD 152K - 203K</span>
#  <span class="badge badge-success badge-pill d-md-none">USD 152K+</span>
#  </div>
#  </div>
#  <p class="m-0 text-muted job-list-item-company">Airbnb</p>
#  <h2 class="h4 mb-1">Senior Analytics Engineer, Airbnb.org</h2>
#  <span class="badge badge-light badge-pill">Airflow</span>
#  <span class="badge badge-light badge-pill">Data analysis</span>
#  <span class="badge badge-light badge-pill">Engineering</span>
#  <span class="badge badge-light badge-pill">ETL</span>
#  <span class="badge badge-light badge-pill">Machine Learning</span>
#  <span class="badge badge-light badge-pill">Pipelines</span>
#  <span class="badge badge-light badge-pill">Predictive modeling</span>
#  <span class="badge badge-light badge-pill">+5</span>
#  <br/>
#  <span class="badge badge-success badge-pill">Career development</span>
#  <span class="badge badge-success badge-pill">Salary bonus</span>
#  </a>,
#  <a class="col list-group-item-action px-2 py-3" href="/job/26502-business-data-analyst-consultant/" title="View full details of `Business Data Analyst - Consultant` vacancy">
#  <div class="float-right text-right d-inline-block w-25 ml-2">
#  <span class="d-block d-md-none text-break job-list-item-location">Amsterdam, Netherlands</span>
#  <span class="d-none d-md-block text-break job-list-item-location">Amsterdam, Netherlands</span>
#  <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
#  <div class="d-block">
#  <span class="badge badge-info badge-pill my-md-1 d-md-none">Senior</span>
#  <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Senior-level</span>
#  </div>
#  </div>
#  <p class="m-0 text-muted job-list-item-company">sennder</p>
#  <h2 class="h4 mb-1">Business Data Analyst - Consultant</h2>
#  <span class="badge badge-light badge-pill">Banking</span>
#  <span class="badge badge-light badge-pill">Consulting</span>
#  <span class="badge badge-light badge-pill">Data visualization</span>
#  <span class="badge badge-light badge-pill">Excel</span>
#  <span class="badge badge-light badge-pill">KPIs</span>
#  <span class="badge badge-light badge-pill">Looker</span>
#  <span class="badge badge-light badge-pill">SQL</span>
#  <br/>
#  <span class="badge badge-success badge-pill">Career development</span>
#  <span class="badge badge-success badge-pill">Startup environment</span>
#  <span class="badge badge-success badge-pill">Team events</span>
#  </a>,
#  <a class="col list-group-item-action px-2 py-3" href="/job/26505-data-analytics-teamlead/" title="View full details of `Data analytics Teamlead` vacancy">
#  <div class="float-right text-right d-inline-block w-25 ml-2">
#  <span class="d-block d-md-none text-break job-list-item-location">Slovakia</span>
#  <span class="d-none d-md-block text-break job-list-item-location">Slovakia</span>
#  <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
#  <div class="d-block">
#  <span class="badge badge-info badge-pill my-md-1 d-md-none">Mid</span>
#  <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Mid-level</span>
#  </div>
#  </div>
#  <p class="m-0 text-muted job-list-item-company">CloudTalk</p>
#  <h2 class="h4 mb-1">Data analytics Teamlead</h2>
#  <span class="badge badge-light badge-pill">Data analysis</span>
#  <span class="badge badge-light badge-pill">Data Analytics</span>
#  <span class="badge badge-light badge-pill">Data strategy</span>
#  <span class="badge badge-light badge-pill">Data Warehousing</span>
#  <span class="badge badge-light badge-pill">E-commerce</span>
#  <span class="badge badge-light badge-pill">Engineering</span>
#  <span class="badge badge-light badge-pill">Finance</span>
#  <span class="badge badge-light badge-pill">+4</span>
#  <br/>
#  <span class="badge badge-success badge-pill">Career development</span>
#  <span class="badge badge-success badge-pill">Flex hours</span>
#  <span class="badge badge-success badge-pill">Flex vacation</span>
#  <span class="badge badge-success badge-pill">Gear</span>
#  <span class="badge badge-success badge-pill">Health care</span>
#  <span class="badge badge-success badge-pill">+2</span>
#  </a>,
#  <a class="col list-group-item-action px-2 py-3" href="/job/26475-data-engineer-scot-aim-inventory-research-and-analytics/" title="View full details of `Data Engineer, SCOT AIM: Inventory Research and Analytics` vacancy">
#  <div class="float-right text-right d-inline-block w-25 ml-2">
#  <span class="d-block d-md-none text-break job-list-item-location">Austin, Texas, USA</span>
#  <span class="d-none d-md-block text-break job-list-item-location">Austin, Texas, USA</span>
#  <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
#  <div class="d-block">
#  <span class="badge badge-info badge-pill my-md-1 d-md-none">Senior</span>
#  <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Senior-level</span>
#  </div>
#  <div class="d-block">
#  <span class="badge badge-success badge-pill d-none d-md-inline-block">USD 76K - 150K *</span>
#  <span class="badge badge-success badge-pill d-md-none">USD 76K+ *</span>
#  </div>
#  </div>
#  <p class="m-0 text-muted job-list-item-company">Amazon.com</p>
#  <h2 class="h4 mb-1">Data Engineer, SCOT AIM: Inventory Research and Analytics</h2>
#  <span class="badge badge-light badge-pill">Big Data</span>
#  <span class="badge badge-light badge-pill">Business Intelligence</span>
#  <span class="badge badge-light badge-pill">Data management</span>
#  <span class="badge badge-light badge-pill">Data Warehousing</span>
#  <span class="badge badge-light badge-pill">Distributed Systems</span>
#  <span class="badge badge-light badge-pill">Engineering</span>
#  <span class="badge badge-light badge-pill">ETL</span>
#  <span class="badge badge-light badge-pill">+12</span>
#  <br/>
#  </a>,
#  <a class="col list-group-item-action px-2 py-3" href="/job/26445-senior-analytics-engineer/" title="View full details of `Senior Analytics Engineer` vacancy">
#  <div class="float-right text-right d-inline-block w-25 ml-2">
#  <span class="d-block d-md-none text-break job-list-item-location">Porto</span>
#  <span class="d-none d-md-block text-break job-list-item-location">Porto</span>
#  <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
#  <div class="d-block">
#  <span class="badge badge-info badge-pill my-md-1 d-md-none">Senior</span>
#  <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Senior-level</span>
#  </div>
#  </div>
#  <p class="m-0 text-muted job-list-item-company">GetGround</p>
#  <h2 class="h4 mb-1">Senior Analytics Engineer</h2>
#  <span class="badge badge-light badge-pill">Agile</span>
#  <span class="badge badge-light badge-pill">BigQuery</span>
#  <span class="badge badge-light badge-pill">Business Analytics</span>
#  <span class="badge badge-light badge-pill">Data pipelines</span>
#  <span class="badge badge-light badge-pill">DevOps</span>
#  <span class="badge badge-light badge-pill">Engineering</span>
#  <span class="badge badge-light badge-pill">JavaScript</span>
#  <span class="badge badge-light badge-pill">+6</span>
#  <br/>
#  <span class="badge badge-success badge-pill">Career development</span>
#  <span class="badge badge-success badge-pill">Competitive pay</span>
#  <span class="badge badge-success badge-pill">Conferences</span>
#  <span class="badge badge-success badge-pill">Equity</span>
#  <span class="badge badge-success badge-pill">Flex hours</span>
#  <span class="badge badge-success badge-pill">+2</span>
#  </a>,
#  <a class="col list-group-item-action px-2 py-3" href="/job/26497-associate-hr-data-analyst/" title="View full details of `Associate HR Data Analyst` vacancy">
#  <div class="float-right text-right d-inline-block w-25 ml-2">
#  <span class="d-block d-md-none text-break job-list-item-location">United States, Remote</span>
#  <span class="d-none d-md-block text-break job-list-item-location">United States, Remote</span>
#  <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
#  <div class="d-block">
#  <span class="badge badge-info badge-pill my-md-1 d-md-none">Mid</span>
#  <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Mid-level</span>
#  </div>
#  <div class="d-block">
#  <span class="badge badge-success badge-pill d-none d-md-inline-block">USD 51K - 90K *</span>
#  <span class="badge badge-success badge-pill d-md-none">USD 51K+ *</span>
#  </div>
#  </div>
#  <p class="m-0 text-muted job-list-item-company">Ivanti</p>
#  <h2 class="h4 mb-1">Associate HR Data Analyst</h2>
#  <span class="badge badge-light badge-pill">Excel</span>
#  <span class="badge badge-light badge-pill">Finance</span>
#  <span class="badge badge-light badge-pill">Testing</span>
#  <br/>
#  <span class="badge badge-success badge-pill">Competitive pay</span>
#  <span class="badge badge-success badge-pill">Flex vacation</span>
#  </a>,
#  <a class="col list-group-item-action px-2 py-3" href="/job/26499-data-analyst/" title="View full details of `Data Analyst` vacancy">
#  <div class="float-right text-right d-inline-block w-25 ml-2">
#  <span class="d-block d-md-none text-break job-list-item-location">Cluj-Napoca, Cluj, Romania</span>
#  <span class="d-none d-md-block text-break job-list-item-location">Cluj-Napoca, Cluj, Romania</span>
#  <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
#  <div class="d-block">
#  <span class="badge badge-info badge-pill my-md-1 d-md-none">Senior</span>
#  <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Senior-level</span>
#  </div>
#  <div class="d-block">
#  <span class="badge badge-success badge-pill d-none d-md-inline-block">USD 50K - 85K *</span>
#  <span class="badge badge-success badge-pill d-md-none">USD 50K+ *</span>
#  </div>
#  </div>
#  <p class="m-0 text-muted job-list-item-company">ComplyAdvantage</p>
#  <h2 class="h4 mb-1">Data Analyst</h2>
#  <span class="badge badge-light badge-pill">Agile</span>
#  <span class="badge badge-light badge-pill">Data analysis</span>
#  <span class="badge badge-light badge-pill">Data Analytics</span>
#  <span class="badge badge-light badge-pill">Data visualization</span>
#  <span class="badge badge-light badge-pill">Economics</span>
#  <span class="badge badge-light badge-pill">Looker</span>
#  <span class="badge badge-light badge-pill">Python</span>
#  <span class="badge badge-light badge-pill">+4</span>
#  <br/>
#  <span class="badge badge-success badge-pill">Career development</span>
#  <span class="badge badge-success badge-pill">Competitive pay</span>
#  <span class="badge badge-success badge-pill">Equity</span>
#  <span class="badge badge-success badge-pill">Medical leave</span>
#  <span class="badge badge-success badge-pill">Parental leave</span>
#  <span class="badge badge-success badge-pill">+1</span>
#  </a>,
#  <a class="col list-group-item-action px-2 py-3" href="/job/26506-senior-data-analyst/" title="View full details of `Senior Data Analyst` vacancy">
#  <div class="float-right text-right d-inline-block w-25 ml-2">
#  <span class="d-block d-md-none text-break job-list-item-location">Los Angeles, California, United …</span>
#  <span class="d-none d-md-block text-break job-list-item-location">Los Angeles, California, United States - Remote</span>
#  <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
#  <div class="d-block">
#  <span class="badge badge-info badge-pill my-md-1 d-md-none">Mid</span>
#  <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Mid-level</span>
#  </div>
#  <div class="d-block">
#  <span class="badge badge-success badge-pill d-none d-md-inline-block">USD 51K - 90K *</span>
#  <span class="badge badge-success badge-pill d-md-none">USD 51K+ *</span>
#  </div>
#  </div>
#  <p class="m-0 text-muted job-list-item-company">Athletic Greens</p>
#  <h2 class="h4 mb-1">Senior Data Analyst</h2>
#  <span class="badge badge-light badge-pill">BigQuery</span>
#  <span class="badge badge-light badge-pill">Data Studio</span>
#  <span class="badge badge-light badge-pill">Data visualization</span>
#  <span class="badge badge-light badge-pill">E-commerce</span>
#  <span class="badge badge-light badge-pill">Engineering</span>
#  <span class="badge badge-light badge-pill">Finance</span>
#  <span class="badge badge-light badge-pill">KPIs</span>
#  <span class="badge badge-light badge-pill">+12</span>
#  <br/>
#  <span class="badge badge-success badge-pill">401(k) matching</span>
#  <span class="badge badge-success badge-pill">Career development</span>
#  <span class="badge badge-success badge-pill">Flex vacation</span>
#  <span class="badge badge-success badge-pill">Gear</span>
#  <span class="badge badge-success badge-pill">Health care</span>
#  <span class="badge badge-success badge-pill">+6</span>
#  </a>,
#  <a class="col list-group-item-action px-2 py-3" href="/job/26504-research-data-analyst/" title="View full details of `Research &amp; Data Analyst` vacancy">
#  <div class="float-right text-right d-inline-block w-25 ml-2">
#  <span class="d-block d-md-none text-break job-list-item-location">Mexico</span>
#  <span class="d-none d-md-block text-break job-list-item-location">Mexico</span>
#  <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
#  <div class="d-block">
#  <span class="badge badge-info badge-pill my-md-1 d-md-none">Mid</span>
#  <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Mid-level</span>
#  </div>
#  <div class="d-block">
#  <span class="badge badge-success badge-pill d-none d-md-inline-block">USD 51K - 90K *</span>
#  <span class="badge badge-success badge-pill d-md-none">USD 51K+ *</span>
#  </div>
#  </div>
#  <p class="m-0 text-muted job-list-item-company">Euromonitor</p>
#  <h2 class="h4 mb-1">Research &amp; Data Analyst</h2>
#  <span class="badge badge-light badge-pill">Business Intelligence</span>
#  <span class="badge badge-light badge-pill">Excel</span>
#  <span class="badge badge-light badge-pill">Market research</span>
#  <span class="badge badge-light badge-pill">Research</span>
#  <br/>
#  <span class="badge badge-success badge-pill">Career development</span>
#  <span class="badge badge-success badge-pill">Competitive pay</span>
#  <span class="badge badge-success badge-pill">Flex hours</span>
#  <span class="badge badge-success badge-pill">Health care</span>
#  <span class="badge badge-success badge-pill">Insurance</span>
#  <span class="badge badge-success badge-pill">+1</span>
# ...
#  <div class="d-block">
#  <span class="badge badge-info badge-pill my-md-1 d-md-none">Mid</span>
#  <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Mid-level</span>
#  </div>
#  <div class="d-block">
#  <span class="badge badge-success badge-pill d-none d-md-inline-block">USD 51K - 90K *</span>
#  <span class="badge badge-success badge-pill d-md-none">USD 51K+ *</span>
#  </div>
#  </div>
#  <p class="m-0 text-muted job-list-item-company">So Energy</p>
#  <h2 class="h4 mb-1">Data Analyst -MS SQL (SSIS, SSRS, SSAS)</h2>
#  <span class="badge badge-light badge-pill">Engineering</span>
#  <span class="badge badge-light badge-pill">Looker</span>
#  <span class="badge badge-light badge-pill">MS SQL</span>
#  <span class="badge badge-light badge-pill">Power BI</span>
#  <span class="badge badge-light badge-pill">Python</span>
#  <span class="badge badge-light badge-pill">SQL</span>
#  <span class="badge badge-light badge-pill">SSIS</span>
#  <br/>
#  <span class="badge badge-success badge-pill">Career development</span>
#  <span class="badge badge-success badge-pill">Competitive pay</span>
#  <span class="badge badge-success badge-pill">Flex hours</span>
#  <span class="badge badge-success badge-pill">Salary bonus</span>
#  </a>,
#  <a class="col list-group-item-action px-2 py-3" href="/job/26165-insight-analyst/" title="View full details of `Insight Analyst` vacancy">
#  <div class="float-right text-right d-inline-block w-25 ml-2">
#  <span class="d-block d-md-none text-break job-list-item-location">London, England, United Kingdom</span>
#  <span class="d-none d-md-block text-break job-list-item-location">London, England, United Kingdom</span>
#  <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
#  <div class="d-block">
#  <span class="badge badge-info badge-pill my-md-1 d-md-none">Mid</span>
#  <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Mid-level</span>
#  </div>
#  </div>
#  <p class="m-0 text-muted job-list-item-company">Multiverse</p>
#  <h2 class="h4 mb-1">Insight Analyst</h2>
#  <span class="badge badge-light badge-pill">Excel</span>
#  <span class="badge badge-light badge-pill">Machine Learning</span>
#  <span class="badge badge-light badge-pill">SQL</span>
#  <span class="badge badge-light badge-pill">Tableau</span>
#  <br/>
#  <span class="badge badge-success badge-pill">Career development</span>
#  <span class="badge badge-success badge-pill">Health care</span>
#  <span class="badge badge-success badge-pill">Insurance</span>
#  <span class="badge badge-success badge-pill">Team events</span>
#  </a>,
#  <a class="col list-group-item-action px-2 py-3" href="/job/26113-finance-analyst-aws-ai-and-machine-learning-aws-ai-ml-service-finance-aws-aiml/" title="View full details of `Finance Analyst, AWS AI and Machine Learning, AWS AI-ML Service Finance, AWS AI/ML` vacancy">
#  <div class="float-right text-right d-inline-block w-25 ml-2">
#  <span class="d-block d-md-none text-break job-list-item-location">Arlington, Virginia, USA</span>
#  <span class="d-none d-md-block text-break job-list-item-location">Arlington, Virginia, USA</span>
#  <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
#  <div class="d-block">
#  <span class="badge badge-info badge-pill my-md-1 d-md-none">Senior</span>
#  <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Senior-level</span>
#  </div>
#  </div>
#  <p class="m-0 text-muted job-list-item-company">Amazon.com</p>
#  <h2 class="h4 mb-1">Finance Analyst, AWS AI and Machine Learning, AWS AI-ML Service Finance, AWS AI/ML</h2>
#  <span class="badge badge-light badge-pill">AWS</span>
#  <span class="badge badge-light badge-pill">Big Data</span>
#  <span class="badge badge-light badge-pill">Economics</span>
#  <span class="badge badge-light badge-pill">Engineering</span>
#  <span class="badge badge-light badge-pill">Excel</span>
#  <span class="badge badge-light badge-pill">Finance</span>
#  <span class="badge badge-light badge-pill">Machine Learning</span>
#  <span class="badge badge-light badge-pill">+2</span>
#  <br/>
#  </a>,
#  <a class="col list-group-item-action px-2 py-3" href="/job/26116-data-analytics-logistics/" title="View full details of `Data Analytics - Logistics` vacancy">
#  <div class="float-right text-right d-inline-block w-25 ml-2">
#  <span class="d-block d-md-none text-break job-list-item-location">Buenos Aires, Buenos Aires, …</span>
#  <span class="d-none d-md-block text-break job-list-item-location">Buenos Aires, Buenos Aires, Argentina</span>
#  <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
#  <div class="d-block">
#  <span class="badge badge-info badge-pill my-md-1 d-md-none">Senior</span>
#  <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Senior-level</span>
#  </div>
#  </div>
#  <p class="m-0 text-muted job-list-item-company">Shopee</p>
#  <h2 class="h4 mb-1">Data Analytics - Logistics</h2>
#  <span class="badge badge-light badge-pill">Data Analytics</span>
#  <span class="badge badge-light badge-pill">Data Studio</span>
#  <span class="badge badge-light badge-pill">Engineering</span>
#  <span class="badge badge-light badge-pill">Power BI</span>
#  <span class="badge badge-light badge-pill">Python</span>
#  <span class="badge badge-light badge-pill">SQL</span>
#  <span class="badge badge-light badge-pill">Statistics</span>
#  <br/>
#  </a>,
#  <a class="col list-group-item-action px-2 py-3" href="/job/26118-data-analytics-engineer-co-op-fall-2022/" title="View full details of `Data Analytics Engineer Co-op - Fall 2022` vacancy">
#  <div class="float-right text-right d-inline-block w-25 ml-2">
#  <span class="d-block d-md-none text-break job-list-item-location">Canada, Remote</span>
#  <span class="d-none d-md-block text-break job-list-item-location">Canada, Remote</span>
#  <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
#  </div>
#  <p class="m-0 text-muted job-list-item-company">Wonolo</p>
#  <h2 class="h4 mb-1">Data Analytics Engineer Co-op - Fall 2022</h2>
#  <span class="badge badge-light badge-pill">CAD</span>
#  <span class="badge badge-light badge-pill">Data Analytics</span>
#  <span class="badge badge-light badge-pill">Data pipelines</span>
#  <span class="badge badge-light badge-pill">Engineering</span>
#  <span class="badge badge-light badge-pill">ETL</span>
#  <span class="badge badge-light badge-pill">Pipelines</span>
#  <span class="badge badge-light badge-pill">Python</span>
#  <span class="badge badge-light badge-pill">+1</span>
#  <br/>
#  <span class="badge badge-success badge-pill">Career development</span>
#  <span class="badge badge-success badge-pill">Competitive pay</span>
#  <span class="badge badge-success badge-pill">Equity</span>
#  <span class="badge badge-success badge-pill">Flex hours</span>
#  <span class="badge badge-success badge-pill">Startup environment</span>
#  <span class="badge badge-success badge-pill">+2</span>
#  </a>,
#  <a class="col list-group-item-action px-2 py-3" href="/job/26111-lead-analyst-data-management/" title="View full details of `Lead Analyst, Data Management` vacancy">
#  <div class="float-right text-right d-inline-block w-25 ml-2">
#  <span class="d-block d-md-none text-break job-list-item-location">Sydney, New South Wales, …</span>
#  <span class="d-none d-md-block text-break job-list-item-location">Sydney, New South Wales, Australia</span>
#  <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
#  <div class="d-block">
#  <span class="badge badge-info badge-pill my-md-1 d-md-none">Executive</span>
#  <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Executive-level</span>
#  </div>
#  </div>
#  <p class="m-0 text-muted job-list-item-company">Quantium</p>
#  <h2 class="h4 mb-1">Lead Analyst, Data Management</h2>
#  <span class="badge badge-light badge-pill">Agile</span>
#  <span class="badge badge-light badge-pill">Big Data</span>
#  <span class="badge badge-light badge-pill">Consulting</span>
#  <span class="badge badge-light badge-pill">Data analysis</span>
#  <span class="badge badge-light badge-pill">Data Analytics</span>
#  <span class="badge badge-light badge-pill">Data management</span>
#  <span class="badge badge-light badge-pill">Engineering</span>
#  <span class="badge badge-light badge-pill">+4</span>
#  <br/>
#  <span class="badge badge-success badge-pill">Career development</span>
#  <span class="badge badge-success badge-pill">Startup environment</span>
#  <span class="badge badge-success badge-pill">Team events</span>
#  </a>,
#  <a class="col list-group-item-action px-2 py-3" href="/job/26114-sr-data-analyst-cmg-analytics/" title="View full details of `Sr. Data Analyst (CMG Analytics)` vacancy">
#  <div class="float-right text-right d-inline-block w-25 ml-2">
#  <span class="d-block d-md-none text-break job-list-item-location">Seoul, South Korea</span>
#  <span class="d-none d-md-block text-break job-list-item-location">Seoul, South Korea</span>
#  <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
#  <div class="d-block">
#  <span class="badge badge-info badge-pill my-md-1 d-md-none">Senior</span>
#  <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Senior-level</span>
#  </div>
#  <div class="d-block">
#  <span class="badge badge-success badge-pill d-none d-md-inline-block">USD 50K - 85K *</span>
#  <span class="badge badge-success badge-pill d-md-none">USD 50K+ *</span>
#  </div>
#  </div>
#  <p class="m-0 text-muted job-list-item-company">Coupang</p>
#  <h2 class="h4 mb-1">Sr. Data Analyst (CMG Analytics)</h2>
#  <span class="badge badge-light badge-pill">Airflow</span>
#  <span class="badge badge-light badge-pill">E-commerce</span>
#  <span class="badge badge-light badge-pill">Looker</span>
#  <span class="badge badge-light badge-pill">Power BI</span>
#  <span class="badge badge-light badge-pill">Python</span>
#  <span class="badge badge-light badge-pill">Qlik</span>
#  <span class="badge badge-light badge-pill">R</span>
#  <span class="badge badge-light badge-pill">+2</span>
#  <br/>
#  </a>,
#  <a class="col list-group-item-action px-2 py-3" href="/job/26117-sr-data-analyst-marketing/" title="View full details of `Sr. Data Analyst, Marketing` vacancy">
#  <div class="float-right text-right d-inline-block w-25 ml-2">
#  <span class="d-block d-md-none text-break job-list-item-location">Seattle, WA</span>
#  <span class="d-none d-md-block text-break job-list-item-location">Seattle, WA</span>
#  <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
#  <div class="d-block">
#  <span class="badge badge-info badge-pill my-md-1 d-md-none">Senior</span>
#  <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Senior-level</span>
#  </div>
#  <div class="d-block">
#  <span class="badge badge-success badge-pill d-none d-md-inline-block">USD 50K - 85K *</span>
#  <span class="badge badge-success badge-pill d-md-none">USD 50K+ *</span>
#  </div>
#  </div>
#  <p class="m-0 text-muted job-list-item-company">Clari</p>
#  <h2 class="h4 mb-1">Sr. Data Analyst, Marketing</h2>
#  <span class="badge badge-light badge-pill">A/B testing</span>
#  <span class="badge badge-light badge-pill">Consulting</span>
#  <span class="badge badge-light badge-pill">Finance</span>
#  <span class="badge badge-light badge-pill">Python</span>
#  <span class="badge badge-light badge-pill">R</span>
#  <span class="badge badge-light badge-pill">SQL</span>
#  <span class="badge badge-light badge-pill">Tableau</span>
#  <span class="badge badge-light badge-pill">+1</span>
#  <br/>
#  <span class="badge badge-success badge-pill">Equity</span>
#  <span class="badge badge-success badge-pill">Fertility benefits</span>
#  <span class="badge badge-success badge-pill">Flex hours</span>
#  <span class="badge badge-success badge-pill">Parental leave</span>
#  <span class="badge badge-success badge-pill">Startup environment</span>
#  <span class="badge badge-success badge-pill">+1</span>
#  </a>,
#  <a class="col list-group-item-action px-2 py-3" href="/job/26115-consumer-research-data-analyst/" title="View full details of `Consumer Research &amp; Data Analyst` vacancy">
#  <div class="float-right text-right d-inline-block w-25 ml-2">
#  <span class="d-block d-md-none text-break job-list-item-location">Chicago</span>
#  <span class="d-none d-md-block text-break job-list-item-location">Chicago</span>
#  <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
#  <div class="d-block">
#  <span class="badge badge-info badge-pill my-md-1 d-md-none">Senior</span>
#  <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Senior-level</span>
#  </div>
#  <div class="d-block">
#  <span class="badge badge-success badge-pill d-none d-md-inline-block">USD 50K - 85K *</span>
#  <span class="badge badge-success badge-pill d-md-none">USD 50K+ *</span>
#  </div>
#  </div>
#  <p class="m-0 text-muted job-list-item-company">Mintel</p>
#  <h2 class="h4 mb-1">Consumer Research &amp; Data Analyst</h2>
#  <span class="badge badge-light badge-pill">Data analysis</span>
#  <span class="badge badge-light badge-pill">Data Analytics</span>
#  <span class="badge badge-light badge-pill">Finance</span>
#  <span class="badge badge-light badge-pill">R</span>
#  <span class="badge badge-light badge-pill">Research</span>
#  <span class="badge badge-light badge-pill">Statistics</span>
#  <span class="badge badge-light badge-pill">Survey data</span>
#  <br/>
#  <span class="badge badge-success badge-pill">Career development</span>
#  </a>,
#  <a class="col list-group-item-action px-2 py-3" href="/job/26166-insight-analyst/" title="View full details of `Insight Analyst` vacancy">
#  <div class="float-right text-right d-inline-block w-25 ml-2">
#  <span class="d-block d-md-none text-break job-list-item-location">United Kingdom</span>
#  <span class="d-none d-md-block text-break job-list-item-location">United Kingdom</span>
#  <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
#  <div class="d-block">
#  <span class="badge badge-info badge-pill my-md-1 d-md-none">Mid</span>
#  <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Mid-level</span>
#  </div>
#  </div>
#  <p class="m-0 text-muted job-list-item-company">So Energy</p>
#  <h2 class="h4 mb-1">Insight Analyst</h2>
#  <span class="badge badge-light badge-pill">Agile</span>
#  <span class="badge badge-light badge-pill">BigQuery</span>
#  <span class="badge badge-light badge-pill">Consulting</span>
#  <span class="badge badge-light badge-pill">Data analysis</span>
#  <span class="badge badge-light badge-pill">Data Analytics</span>
#  <span class="badge badge-light badge-pill">Data Mining</span>
#  <span class="badge badge-light badge-pill">Data visualization</span>
#  <span class="badge badge-light badge-pill">+12</span>
#  <br/>
#  <span class="badge badge-success badge-pill">Career development</span>
#  <span class="badge badge-success badge-pill">Competitive pay</span>
#  </a>,
#  <a class="col list-group-item-action px-2 py-3" href="/job/26120-regional-data-analyst-cross-border-based-in-malaysia/" title="View full details of `Regional Data Analyst, Cross Border (based in Malaysia)` vacancy">
#  <div class="float-right text-right d-inline-block w-25 ml-2">
#  <span class="d-block d-md-none text-break job-list-item-location">Shah Alam, Malaysia</span>
#  <span class="d-none d-md-block text-break job-list-item-location">Shah Alam, Malaysia</span>
#  <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
#  <div class="d-block">
#  <span class="badge badge-success badge-pill d-none d-md-inline-block">USD 50K - 85K *</span>
#  <span class="badge badge-success badge-pill d-md-none">USD 50K+ *</span>
#  </div>
#  </div>
#  <p class="m-0 text-muted job-list-item-company">Ninja Van</p>
#  <h2 class="h4 mb-1">Regional Data Analyst, Cross Border (based in Malaysia)</h2>
#  <span class="badge badge-light badge-pill">Business Intelligence</span>
#  <span class="badge badge-light badge-pill">Data Analytics</span>
#  <span class="badge badge-light badge-pill">Excel</span>
#  <span class="badge badge-light badge-pill">KPIs</span>
#  <span class="badge badge-light badge-pill">Python</span>
#  <span class="badge badge-light badge-pill">SQL</span>
#  <br/>
#  </a>]

# %%
needed_info
# Out:
# [<a class="col list-group-item-action px-2 py-3" href="/job/24108-business-intelligence-analyst/" title="View full details of `Business Intelligence Analyst` vacancy">
#  <div class="float-right text-right d-inline-block w-25 ml-2">
#  <span class="d-block d-md-none text-break job-list-item-location">Lincoln, RI, 02865</span>
#  <span class="d-none d-md-block text-break job-list-item-location">Lincoln, RI, 02865</span>
#  <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
#  <div class="d-block">
#  <span class="badge badge-info badge-pill my-md-1 d-md-none">Mid</span>
#  <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Mid-level</span>
#  </div>
#  </div>
#  <p class="m-0 text-muted job-list-item-company">Amica Mutual Insurance Company</p>
#  <h2 class="h4 mb-1">Business Intelligence Analyst</h2>
#  <span class="badge badge-light badge-pill">Business Intelligence</span>
#  <span class="badge badge-light badge-pill">Data management</span>
#  <span class="badge badge-light badge-pill">Power BI</span>
#  <span class="badge badge-light badge-pill">Python</span>
#  <span class="badge badge-light badge-pill">R</span>
#  <span class="badge badge-light badge-pill">SAS</span>
#  <span class="badge badge-light badge-pill">SQL</span>
#  <span class="badge badge-light badge-pill">+2</span>
#  <br/>
#  <span class="badge badge-success badge-pill">Competitive pay</span>
#  <span class="badge badge-success badge-pill">Conferences</span>
#  <span class="badge badge-success badge-pill">Fitness / gym</span>
#  <span class="badge badge-success badge-pill">Health care</span>
#  <span class="badge badge-success badge-pill">Insurance</span>
#  <span class="badge badge-success badge-pill">+3</span>
#  </a>,
#  <a class="col list-group-item-action px-2 py-3" href="/job/24107-lead-business-intelligence-analyst/" title="View full details of `Lead Business Intelligence Analyst` vacancy">
#  <div class="float-right text-right d-inline-block w-25 ml-2">
#  <span class="d-block d-md-none text-break job-list-item-location">Lincoln, RI, 02865</span>
#  <span class="d-none d-md-block text-break job-list-item-location">Lincoln, RI, 02865</span>
#  <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
#  <div class="d-block">
#  <span class="badge badge-info badge-pill my-md-1 d-md-none">Senior</span>
#  <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Senior-level</span>
#  </div>
#  </div>
#  <p class="m-0 text-muted job-list-item-company">Amica Mutual Insurance Company</p>
#  <h2 class="h4 mb-1">Lead Business Intelligence Analyst</h2>
#  <span class="badge badge-light badge-pill">Business Intelligence</span>
#  <span class="badge badge-light badge-pill">Data management</span>
#  <span class="badge badge-light badge-pill">KPIs</span>
#  <span class="badge badge-light badge-pill">Python</span>
#  <span class="badge badge-light badge-pill">R</span>
#  <span class="badge badge-light badge-pill">SAS</span>
#  <span class="badge badge-light badge-pill">SQL</span>
#  <span class="badge badge-light badge-pill">+1</span>
#  <br/>
#  <span class="badge badge-success badge-pill">Competitive pay</span>
#  <span class="badge badge-success badge-pill">Conferences</span>
#  <span class="badge badge-success badge-pill">Fitness / gym</span>
#  <span class="badge badge-success badge-pill">Flex vacation</span>
#  <span class="badge badge-success badge-pill">Health care</span>
#  <span class="badge badge-success badge-pill">+4</span>
#  </a>,
#  <a class="col list-group-item-action px-2 py-3" href="/job/26580-junior-data-analyst/" title="View full details of `Junior Data Analyst` vacancy">
#  <div class="float-right text-right d-inline-block w-25 ml-2">
#  <span class="d-block d-md-none text-break job-list-item-location">Poland</span>
#  <span class="d-none d-md-block text-break job-list-item-location">Poland</span>
#  <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
#  <div class="d-block">
#  <span class="badge badge-info badge-pill my-md-1 d-md-none">Entry</span>
#  <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Entry-level</span>
#  </div>
#  <div class="d-block">
#  <span class="badge badge-success badge-pill d-none d-md-inline-block">USD 30K - 80K *</span>
#  <span class="badge badge-success badge-pill d-md-none">USD 30K+ *</span>
#  </div>
#  </div>
#  <p class="m-0 text-muted job-list-item-company">Nielsen</p>
#  <h2 class="h4 mb-1">Junior Data Analyst</h2>
#  <span class="badge badge-light badge-pill">Consulting</span>
#  <span class="badge badge-light badge-pill">Data analysis</span>
#  <span class="badge badge-light badge-pill">Econometrics</span>
#  <span class="badge badge-light badge-pill">Excel</span>
#  <span class="badge badge-light badge-pill">Market research</span>
#  <span class="badge badge-light badge-pill">Python</span>
#  <span class="badge badge-light badge-pill">R</span>
#  <span class="badge badge-light badge-pill">+5</span>
#  <br/>
#  <span class="badge badge-success badge-pill">Career development</span>
#  </a>,
#  <a class="col list-group-item-action px-2 py-3" href="/job/26584-senior-vice-president-data-analytics-bi/" title="View full details of `Senior Vice President, Data Analytics &amp; BI` vacancy">
#  <div class="float-right text-right d-inline-block w-25 ml-2">
#  <span class="d-block d-md-none text-break job-list-item-location">Los Angeles, California, United …</span>
#  <span class="d-none d-md-block text-break job-list-item-location">Los Angeles, California, United States - Remote</span>
#  <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
#  <div class="d-block">
#  <span class="badge badge-info badge-pill my-md-1 d-md-none">Senior</span>
#  <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Senior-level</span>
#  </div>
#  </div>
#  <p class="m-0 text-muted job-list-item-company">Athletic Greens</p>
#  <h2 class="h4 mb-1">Senior Vice President, Data Analytics &amp; BI</h2>
#  <span class="badge badge-light badge-pill">Airflow</span>
#  <span class="badge badge-light badge-pill">BigQuery</span>
#  <span class="badge badge-light badge-pill">Business Intelligence</span>
#  <span class="badge badge-light badge-pill">Data Analytics</span>
#  <span class="badge badge-light badge-pill">Data management</span>
#  <span class="badge badge-light badge-pill">Data strategy</span>
#  <span class="badge badge-light badge-pill">E-commerce</span>
#  <span class="badge badge-light badge-pill">+6</span>
#  <br/>
#  <span class="badge badge-success badge-pill">401(k) matching</span>
#  <span class="badge badge-success badge-pill">Flex vacation</span>
#  <span class="badge badge-success badge-pill">Gear</span>
#  <span class="badge badge-success badge-pill">Health care</span>
#  <span class="badge badge-success badge-pill">Home office stipend</span>
#  <span class="badge badge-success badge-pill">+5</span>
#  </a>,
#  <a class="col list-group-item-action px-2 py-3" href="/job/26569-staff-analytics-engineer-central-data/" title="View full details of `Staff Analytics Engineer, Central Data` vacancy">
#  <div class="float-right text-right d-inline-block w-25 ml-2">
#  <span class="d-block d-md-none text-break job-list-item-location">United States</span>
#  <span class="d-none d-md-block text-break job-list-item-location">United States</span>
#  <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
#  <div class="d-block">
#  <span class="badge badge-info badge-pill my-md-1 d-md-none">Senior</span>
#  <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Senior-level</span>
#  </div>
#  <div class="d-block">
#  <span class="badge badge-success badge-pill d-none d-md-inline-block">USD 180K - 245K</span>
#  <span class="badge badge-success badge-pill d-md-none">USD 180K+</span>
#  </div>
#  </div>
#  <p class="m-0 text-muted job-list-item-company">Airbnb</p>
#  <h2 class="h4 mb-1">Staff Analytics Engineer, Central Data</h2>
#  <span class="badge badge-light badge-pill">Airflow</span>
#  <span class="badge badge-light badge-pill">Data analysis</span>
#  <span class="badge badge-light badge-pill">Engineering</span>
#  <span class="badge badge-light badge-pill">ETL</span>
#  <span class="badge badge-light badge-pill">Machine Learning</span>
#  <span class="badge badge-light badge-pill">Pipelines</span>
#  <span class="badge badge-light badge-pill">Predictive modeling</span>
#  <span class="badge badge-light badge-pill">+6</span>
#  <br/>
#  <span class="badge badge-success badge-pill">Career development</span>
#  <span class="badge badge-success badge-pill">Salary bonus</span>
#  </a>,
#  <a class="col list-group-item-action px-2 py-3" href="/job/26572-data-analyst-clinical-informatics/" title="View full details of `Data Analyst - Clinical Informatics` vacancy">
#  <div class="float-right text-right d-inline-block w-25 ml-2">
#  <span class="d-block d-md-none text-break job-list-item-location">Chicago, IL</span>
#  <span class="d-none d-md-block text-break job-list-item-location">Chicago, IL</span>
#  <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
#  <div class="d-block">
#  <span class="badge badge-success badge-pill d-none d-md-inline-block">USD 50K - 85K *</span>
#  <span class="badge badge-success badge-pill d-md-none">USD 50K+ *</span>
#  </div>
#  </div>
#  <p class="m-0 text-muted job-list-item-company">Tempus</p>
#  <h2 class="h4 mb-1">Data Analyst - Clinical Informatics</h2>
#  <span class="badge badge-light badge-pill">Data pipelines</span>
#  <span class="badge badge-light badge-pill">Pipelines</span>
#  <span class="badge badge-light badge-pill">Python</span>
#  <span class="badge badge-light badge-pill">SQL</span>
#  <br/>
#  </a>,
#  <a class="col list-group-item-action px-2 py-3" href="/job/26573-senior-product-data-analytics/" title="View full details of `Senior Product Data Analytics` vacancy">
#  <div class="float-right text-right d-inline-block w-25 ml-2">
#  <span class="d-block d-md-none text-break job-list-item-location">Sao Paulo</span>
#  <span class="d-none d-md-block text-break job-list-item-location">Sao Paulo</span>
#  <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
#  <div class="d-block">
#  <span class="badge badge-info badge-pill my-md-1 d-md-none">Senior</span>
#  <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Senior-level</span>
#  </div>
#  </div>
#  <p class="m-0 text-muted job-list-item-company">Adyen</p>
#  <h2 class="h4 mb-1">Senior Product Data Analytics</h2>
#  <span class="badge badge-light badge-pill">Airflow</span>
#  <span class="badge badge-light badge-pill">Big Data</span>
#  <span class="badge badge-light badge-pill">Data Analytics</span>
#  <span class="badge badge-light badge-pill">Data pipelines</span>
#  <span class="badge badge-light badge-pill">Engineering</span>
#  <span class="badge badge-light badge-pill">ETL</span>
#  <span class="badge badge-light badge-pill">Pipelines</span>
#  <span class="badge badge-light badge-pill">+5</span>
#  <br/>
#  <span class="badge badge-success badge-pill">Startup environment</span>
#  </a>,
#  <a class="col list-group-item-action px-2 py-3" href="/job/26526-data-scientist-international-analytics/" title="View full details of `Data Scientist, International Analytics` vacancy">
#  <div class="float-right text-right d-inline-block w-25 ml-2">
#  <span class="d-block d-md-none text-break job-list-item-location">Toronto, ON</span>
#  <span class="d-none d-md-block text-break job-list-item-location">Toronto, ON</span>
#  <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
#  <div class="d-block">
#  <span class="badge badge-info badge-pill my-md-1 d-md-none">Senior</span>
#  <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Senior-level</span>
#  </div>
#  <div class="d-block">
#  <span class="badge badge-success badge-pill d-none d-md-inline-block">USD 68K - 135K *</span>
#  <span class="badge badge-success badge-pill d-md-none">USD 68K+ *</span>
#  </div>
#  </div>
#  <p class="m-0 text-muted job-list-item-company">DoorDash</p>
#  <h2 class="h4 mb-1">Data Scientist, International Analytics</h2>
#  <span class="badge badge-light badge-pill">A/B testing</span>
#  <span class="badge badge-light badge-pill">Consulting</span>
#  <span class="badge badge-light badge-pill">Data Analytics</span>
#  <span class="badge badge-light badge-pill">Economics</span>
#  <span class="badge badge-light badge-pill">ETL</span>
#  <span class="badge badge-light badge-pill">Excel</span>
#  <span class="badge badge-light badge-pill">Looker</span>
#  <span class="badge badge-light badge-pill">+8</span>
#  <br/>
#  <span class="badge badge-success badge-pill">Flex vacation</span>
#  </a>,
#  <a class="col list-group-item-action px-2 py-3" href="/job/26575-data-analyst/" title="View full details of `Data Analyst` vacancy">
#  <div class="float-right text-right d-inline-block w-25 ml-2">
#  <span class="d-block d-md-none text-break job-list-item-location">Remote</span>
#  <span class="d-none d-md-block text-break job-list-item-location">Remote</span>
#  <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
#  <div class="d-block">
#  <span class="badge badge-info badge-pill my-md-1 d-md-none">Senior</span>
#  <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Senior-level</span>
#  </div>
#  <div class="d-block">
#  <span class="badge badge-success badge-pill d-none d-md-inline-block">USD 50K - 85K *</span>
#  <span class="badge badge-success badge-pill d-md-none">USD 50K+ *</span>
#  </div>
#  </div>
#  <p class="m-0 text-muted job-list-item-company">Archive</p>
#  <h2 class="h4 mb-1">Data Analyst</h2>
#  <span class="badge badge-light badge-pill">Data visualization</span>
#  <span class="badge badge-light badge-pill">Looker</span>
#  <span class="badge badge-light badge-pill">SQL</span>
#  <span class="badge badge-light badge-pill">Tableau</span>
#  <br/>
#  </a>,
#  <a class="col list-group-item-action px-2 py-3" href="/job/26570-analytics-engineer-remote/" title="View full details of `Analytics Engineer - Remote` vacancy">
#  <div class="float-right text-right d-inline-block w-25 ml-2">
#  <span class="d-block d-md-none text-break job-list-item-location">Canada</span>
#  <span class="d-none d-md-block text-break job-list-item-location">Canada</span>
#  <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
#  <div class="d-block">
#  <span class="badge badge-info badge-pill my-md-1 d-md-none">Senior</span>
#  <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Senior-level</span>
#  </div>
#  </div>
#  <p class="m-0 text-muted job-list-item-company">KOHO</p>
#  <h2 class="h4 mb-1">Analytics Engineer - Remote</h2>
#  <span class="badge badge-light badge-pill">Data Analytics</span>
#  <span class="badge badge-light badge-pill">Engineering</span>
#  <span class="badge badge-light badge-pill">Machine Learning</span>
#  <span class="badge badge-light badge-pill">Python</span>
#  <span class="badge badge-light badge-pill">SQL</span>
#  <span class="badge badge-light badge-pill">Testing</span>
#  <br/>
#  <span class="badge badge-success badge-pill">Home office stipend</span>
#  </a>,
#  <a class="col list-group-item-action px-2 py-3" href="/job/26541-data-analyst-bi-developer-mfd/" title="View full details of `Data Analyst / BI Developer (m/f/d)` vacancy">
#  <div class="float-right text-right d-inline-block w-25 ml-2">
#  <span class="d-block d-md-none text-break job-list-item-location">Remote</span>
#  <span class="d-none d-md-block text-break job-list-item-location">Remote</span>
#  <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
#  <div class="d-block">
#  <span class="badge badge-info badge-pill my-md-1 d-md-none">Senior</span>
#  <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Senior-level</span>
#  </div>
#  </div>
#  <p class="m-0 text-muted job-list-item-company">SoSafe</p>
#  <h2 class="h4 mb-1">Data Analyst / BI Developer (m/f/d)</h2>
#  <span class="badge badge-light badge-pill">Business Intelligence</span>
#  <span class="badge badge-light badge-pill">Data analysis</span>
#  <span class="badge badge-light badge-pill">Data visualization</span>
#  <span class="badge badge-light badge-pill">KPIs</span>
#  <span class="badge badge-light badge-pill">Power BI</span>
#  <span class="badge badge-light badge-pill">Python</span>
#  <span class="badge badge-light badge-pill">Security</span>
#  <span class="badge badge-light badge-pill">+3</span>
#  <br/>
#  <span class="badge badge-success badge-pill">Career development</span>
#  <span class="badge badge-success badge-pill">Competitive pay</span>
#  <span class="badge badge-success badge-pill">Flex vacation</span>
#  <span class="badge badge-success badge-pill">Lunch / meals</span>
#  <span class="badge badge-success badge-pill">Salary bonus</span>
#  <span class="badge badge-success badge-pill">+1</span>
#  </a>,
#  <a class="col list-group-item-action px-2 py-3" href="/job/26579-data-analytics-lead/" title="View full details of `Data Analytics Lead` vacancy">
#  <div class="float-right text-right d-inline-block w-25 ml-2">
#  <span class="d-block d-md-none text-break job-list-item-location">London</span>
#  <span class="d-none d-md-block text-break job-list-item-location">London</span>
#  <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
#  </div>
#  <p class="m-0 text-muted job-list-item-company">Mintel</p>
#  <h2 class="h4 mb-1">Data Analytics Lead</h2>
#  <span class="badge badge-light badge-pill">Consulting</span>
#  <span class="badge badge-light badge-pill">Data Analytics</span>
#  <span class="badge badge-light badge-pill">Looker</span>
#  <span class="badge badge-light badge-pill">Market research</span>
#  <span class="badge badge-light badge-pill">Power BI</span>
#  <span class="badge badge-light badge-pill">Research</span>
#  <span class="badge badge-light badge-pill">SQL</span>
#  <span class="badge badge-light badge-pill">+1</span>
#  <br/>
#  <span class="badge badge-success badge-pill">Career development</span>
#  <span class="badge badge-success badge-pill">Flex vacation</span>
#  </a>,
#  <a class="col list-group-item-action px-2 py-3" href="/job/26583-senior-data-analyst/" title="View full details of `Senior Data Analyst` vacancy">
#  <div class="float-right text-right d-inline-block w-25 ml-2">
#  <span class="d-block d-md-none text-break job-list-item-location">London, England, United Kingdom …</span>
#  <span class="d-none d-md-block text-break job-list-item-location">London, England, United Kingdom - Remote</span>
#  <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
#  <div class="d-block">
#  <span class="badge badge-info badge-pill my-md-1 d-md-none">Mid</span>
#  <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Mid-level</span>
#  </div>
#  <div class="d-block">
#  <span class="badge badge-success badge-pill d-none d-md-inline-block">USD 51K - 90K *</span>
#  <span class="badge badge-success badge-pill d-md-none">USD 51K+ *</span>
#  </div>
#  </div>
#  <p class="m-0 text-muted job-list-item-company">FitXR</p>
#  <h2 class="h4 mb-1">Senior Data Analyst</h2>
#  <span class="badge badge-light badge-pill">A/B testing</span>
#  <span class="badge badge-light badge-pill">BigQuery</span>
#  <span class="badge badge-light badge-pill">DevOps</span>
#  <span class="badge badge-light badge-pill">Engineering</span>
#  <span class="badge badge-light badge-pill">Julia</span>
#  <span class="badge badge-light badge-pill">Python</span>
#  <span class="badge badge-light badge-pill">R</span>
#  <span class="badge badge-light badge-pill">+2</span>
#  <br/>
#  <span class="badge badge-success badge-pill">Career development</span>
#  <span class="badge badge-success badge-pill">Competitive pay</span>
#  <span class="badge badge-success badge-pill">Equity</span>
#  <span class="badge badge-success badge-pill">Flex vacation</span>
#  <span class="badge badge-success badge-pill">Gear</span>
#  <span class="badge badge-success badge-pill">+3</span>
#  </a>,
#  <a class="col list-group-item-action px-2 py-3" href="/job/26582-senior-data-analyst-thailand/" title="View full details of `Senior Data Analyst - Thailand` vacancy">
#  <div class="float-right text-right d-inline-block w-25 ml-2">
#  <span class="d-block d-md-none text-break job-list-item-location">Bangkok, Bangkok, Thailand</span>
#  <span class="d-none d-md-block text-break job-list-item-location">Bangkok, Bangkok, Thailand</span>
#  <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
#  <div class="d-block">
#  <span class="badge badge-info badge-pill my-md-1 d-md-none">Mid</span>
#  <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Mid-level</span>
#  </div>
#  <div class="d-block">
#  <span class="badge badge-success badge-pill d-none d-md-inline-block">USD 51K - 90K *</span>
#  <span class="badge badge-success badge-pill d-md-none">USD 51K+ *</span>
#  </div>
#  </div>
#  <p class="m-0 text-muted job-list-item-company">LingoAce</p>
#  <h2 class="h4 mb-1">Senior Data Analyst - Thailand</h2>
#  <span class="badge badge-light badge-pill">Data Analytics</span>
#  <span class="badge badge-light badge-pill">Economics</span>
#  <span class="badge badge-light badge-pill">Statistics</span>
#  <br/>
#  <span class="badge badge-success badge-pill">Startup environment</span>
#  </a>,
#  <a class="col list-group-item-action px-2 py-3" href="/job/26576-financial-data-analyst-latam-remote/" title="View full details of `Financial Data Analyst - LATAM- REMOTE` vacancy">
#  <div class="float-right text-right d-inline-block w-25 ml-2">
#  <span class="d-block d-md-none text-break job-list-item-location">Mexico City</span>
#  <span class="d-none d-md-block text-break job-list-item-location">Mexico City</span>
#  <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
#  <div class="d-block">
#  <span class="badge badge-info badge-pill my-md-1 d-md-none">Senior</span>
#  <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Senior-level</span>
#  </div>
#  <div class="d-block">
#  <span class="badge badge-success badge-pill d-none d-md-inline-block">USD 50K - 85K *</span>
#  <span class="badge badge-success badge-pill d-md-none">USD 50K+ *</span>
#  </div>
#  </div>
#  <p class="m-0 text-muted job-list-item-company">WPP</p>
#  <h2 class="h4 mb-1">Financial Data Analyst - LATAM- REMOTE</h2>
#  <span class="badge badge-light badge-pill">Consulting</span>
#  <span class="badge badge-light badge-pill">ETL</span>
#  <span class="badge badge-light badge-pill">Finance</span>
#  <span class="badge badge-light badge-pill">Oracle</span>
#  <br/>
#  </a>,
#  <a class="col list-group-item-action px-2 py-3" href="/job/26542-research-engineer-static-analysis-web3/" title="View full details of `Research Engineer, Static Analysis - Web3` vacancy">
#  <div class="float-right text-right d-inline-block w-25 ml-2">
#  <span class="d-block d-md-none text-break job-list-item-location">Bangalore, India</span>
#  <span class="d-none d-md-block text-break job-list-item-location">Bangalore, India</span>
#  <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
#  <div class="d-block">
#  <span class="badge badge-info badge-pill my-md-1 d-md-none">Senior</span>
#  <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Senior-level</span>
#  </div>
#  </div>
#  <p class="m-0 text-muted job-list-item-company">DeepSource</p>
#  <h2 class="h4 mb-1">Research Engineer, Static Analysis - Web3</h2>
#  <span class="badge badge-light badge-pill">Engineering</span>
#  <span class="badge badge-light badge-pill">Research</span>
#  <span class="badge badge-light badge-pill">Testing</span>
#  <br/>
#  </a>,
#  <a class="col list-group-item-action px-2 py-3" href="/job/26574-data-analyst-business-delivery-services/" title="View full details of `Data Analyst, Business Delivery Services` vacancy">
#  <div class="float-right text-right d-inline-block w-25 ml-2">
#  <span class="d-block d-md-none text-break job-list-item-location">Remote</span>
#  <span class="d-none d-md-block text-break job-list-item-location">Remote</span>
#  <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
#  <div class="d-block">
#  <span class="badge badge-info badge-pill my-md-1 d-md-none">Senior</span>
#  <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Senior-level</span>
#  </div>
#  <div class="d-block">
#  <span class="badge badge-success badge-pill d-none d-md-inline-block">USD 80K - 92K</span>
#  <span class="badge badge-success badge-pill d-md-none">USD 80K+</span>
#  </div>
#  </div>
#  <p class="m-0 text-muted job-list-item-company">Argo Group</p>
#  <h2 class="h4 mb-1">Data Analyst, Business Delivery Services</h2>
#  <span class="badge badge-light badge-pill">Agile</span>
#  <span class="badge badge-light badge-pill">Data analysis</span>
#  <span class="badge badge-light badge-pill">Data Mining</span>
#  <span class="badge badge-light badge-pill">Excel</span>
#  <span class="badge badge-light badge-pill">Python</span>
#  <span class="badge badge-light badge-pill">SQL</span>
#  <span class="badge badge-light badge-pill">Statistics</span>
#  <br/>
#  <span class="badge badge-success badge-pill">401(k) matching</span>
#  <span class="badge badge-success badge-pill">Career development</span>
#  <span class="badge badge-success badge-pill">Competitive pay</span>
#  <span class="badge badge-success badge-pill">Equity</span>
#  <span class="badge badge-success badge-pill">Flex hours</span>
#  <span class="badge badge-success badge-pill">+9</span>
#  </a>,
#  <a class="col list-group-item-action px-2 py-3" href="/job/26581-data-analyst/" title="View full details of `Data Analyst` vacancy">
#  <div class="float-right text-right d-inline-block w-25 ml-2">
#  <span class="d-block d-md-none text-break job-list-item-location">Jakarta</span>
#  <span class="d-none d-md-block text-break job-list-item-location">Jakarta</span>
#  <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
#  <div class="d-block">
#  <span class="badge badge-info badge-pill my-md-1 d-md-none">Senior</span>
#  <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Senior-level</span>
#  </div>
#  <div class="d-block">
#  <span class="badge badge-success badge-pill d-none d-md-inline-block">USD 50K - 85K *</span>
#  <span class="badge badge-success badge-pill d-md-none">USD 50K+ *</span>
#  </div>
#  </div>
#  <p class="m-0 text-muted job-list-item-company">Horangi Cyber Security</p>
#  <h2 class="h4 mb-1">Data Analyst</h2>
#  <span class="badge badge-light badge-pill">Agile</span>
#  <span class="badge badge-light badge-pill">AWS</span>
#  <span class="badge badge-light badge-pill">Consulting</span>
#  <span class="badge badge-light badge-pill">Data visualization</span>
#  <span class="badge badge-light badge-pill">Docker</span>
#  <span class="badge badge-light badge-pill">Economics</span>
#  <span class="badge badge-light badge-pill">Engineering</span>
#  <span class="badge badge-light badge-pill">+10</span>
#  <br/>
#  <span class="badge badge-success badge-pill">Team events</span>
#  </a>,
#  <a class="col list-group-item-action px-2 py-3" href="/job/26585-compliance-data-analyst/" title="View full details of `Compliance Data Analyst` vacancy">
#  <div class="float-right text-right d-inline-block w-25 ml-2">
#  <span class="d-block d-md-none text-break job-list-item-location">Scottsdale, Arizona, United States …</span>
#  <span class="d-none d-md-block text-break job-list-item-location">Scottsdale, Arizona, United States - Remote</span>
#  <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
#  <div class="d-block">
#  <span class="badge badge-info badge-pill my-md-1 d-md-none">Entry</span>
#  <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Entry-level</span>
#  </div>
#  <div class="d-block">
#  <span class="badge badge-success badge-pill d-none d-md-inline-block">USD 30K - 80K *</span>
#  <span class="badge badge-success badge-pill d-md-none">USD 30K+ *</span>
#  </div>
#  </div>
#  <p class="m-0 text-muted job-list-item-company">Nuvei</p>
#  <h2 class="h4 mb-1">Compliance Data Analyst</h2>
#  <span class="badge badge-light badge-pill">Data analysis</span>
#  <span class="badge badge-light badge-pill">Data Mining</span>
#  <br/>
#  <span class="badge badge-success badge-pill">401(k) matching</span>
#  <span class="badge badge-success badge-pill">Health care</span>
#  <span class="badge badge-success badge-pill">Yoga</span>
#  </a>,
#  <a class="col list-group-item-action px-2 py-3" href="/job/26578-senior-data-analyst/" title="View full details of `Senior Data Analyst` vacancy">
#  <div class="float-right text-right d-inline-block w-25 ml-2">
#  <span class="d-block d-md-none text-break job-list-item-location">Vitoria, Brazil or Remote, …</span>
#  <span class="d-none d-md-block text-break job-list-item-location">Vitoria, Brazil or Remote, Brazil</span>
#  <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
#  <div class="d-block">
#  <span class="badge badge-info badge-pill my-md-1 d-md-none">Senior</span>
#  <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Senior-level</span>
#  </div>
#  <div class="d-block">
#  <span class="badge badge-success badge-pill d-none d-md-inline-block">USD 50K - 85K *</span>
#  <span class="badge badge-success badge-pill d-md-none">USD 50K+ *</span>
#  </div>
#  </div>
#  <p class="m-0 text-muted job-list-item-company">Trustly</p>
#  <h2 class="h4 mb-1">Senior Data Analyst</h2>
#  <span class="badge badge-light badge-pill">AWS</span>
#  <span class="badge badge-light badge-pill">Banking</span>
#  <span class="badge badge-light badge-pill">Big Data</span>
#  <span class="badge badge-light badge-pill">Data Analytics</span>
#  <span class="badge badge-light badge-pill">Data Mining</span>
#  <span class="badge badge-light badge-pill">Data pipelines</span>
#  <span class="badge badge-light badge-pill">Engineering</span>
#  <span class="badge badge-light badge-pill">+7</span>
#  <br/>
#  <span class="badge badge-success badge-pill">Career development</span>
#  <span class="badge badge-success badge-pill">Flex hours</span>
#  <span class="badge badge-success badge-pill">Flex vacation</span>
#  <span class="badge badge-success badge-pill">Health care</span>
#  <span class="badge badge-success badge-pill">Home office stipend</span>
#  <span class="badge badge-success badge-pill">+5</span>
#  </a>,
#  <a class="col list-group-item-action px-2 py-3" href="/job/26577-technical-data-analyst/" title="View full details of `Technical Data Analyst` vacancy">
#  <div class="float-right text-right d-inline-block w-25 ml-2">
#  <span class="d-block d-md-none text-break job-list-item-location">Remote</span>
#  <span class="d-none d-md-block text-break job-list-item-location">Remote</span>
#  <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
#  <div class="d-block">
#  <span class="badge badge-info badge-pill my-md-1 d-md-none">Senior</span>
#  <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Senior-level</span>
#  </div>
#  <div class="d-block">
#  <span class="badge badge-success badge-pill d-none d-md-inline-block">USD 90K - 108K</span>
#  <span class="badge badge-success badge-pill d-md-none">USD 90K+</span>
#  </div>
#  </div>
#  <p class="m-0 text-muted job-list-item-company">Argo Group</p>
#  <h2 class="h4 mb-1">Technical Data Analyst</h2>
#  <span class="badge badge-light badge-pill">Agile</span>
#  <span class="badge badge-light badge-pill">Data Mining</span>
#  <span class="badge badge-light badge-pill">Excel</span>
#  <span class="badge badge-light badge-pill">MS SQL</span>
#  <span class="badge badge-light badge-pill">Oracle</span>
#  <span class="badge badge-light badge-pill">Power BI</span>
#  <span class="badge badge-light badge-pill">Snowflake</span>
#  <span class="badge badge-light badge-pill">+1</span>
#  <br/>
#  <span class="badge badge-success badge-pill">401(k) matching</span>
#  <span class="badge badge-success badge-pill">Career development</span>
#  <span class="badge badge-success badge-pill">Competitive pay</span>
#  <span class="badge badge-success badge-pill">Equity</span>
#  <span class="badge badge-success badge-pill">Flex hours</span>
#  <span class="badge badge-success badge-pill">+9</span>
#  </a>,
#  <a class="col list-group-item-action px-2 py-3" href="/job/26503-operations-data-analyst-pune-india/" title="View full details of `Operations Data Analyst - Pune India` vacancy">
#  <div class="float-right text-right d-inline-block w-25 ml-2">
#  <span class="d-block d-md-none text-break job-list-item-location">Pune, Maharashtra, India</span>
#  <span class="d-none d-md-block text-break job-list-item-location">Pune, Maharashtra, India</span>
#  <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
#  <div class="d-block">
#  <span class="badge badge-success badge-pill d-none d-md-inline-block">USD 50K - 85K *</span>
#  <span class="badge badge-success badge-pill d-md-none">USD 50K+ *</span>
#  </div>
#  </div>
#  <p class="m-0 text-muted job-list-item-company">Precision Medicine Group</p>
#  <h2 class="h4 mb-1">Operations Data Analyst - Pune India</h2>
#  <span class="badge badge-light badge-pill">Consulting</span>
#  <span class="badge badge-light badge-pill">Engineering</span>
#  <span class="badge badge-light badge-pill">Excel</span>
#  <span class="badge badge-light badge-pill">Python</span>
#  <span class="badge badge-light badge-pill">Research</span>
#  <span class="badge badge-light badge-pill">Snowflake</span>
#  <span class="badge badge-light badge-pill">SQL</span>
#  <br/>
#  </a>,
#  <a class="col list-group-item-action px-2 py-3" href="/job/26444-senior-analytics-engineer-airbnborg/" title="View full details of `Senior Analytics Engineer, Airbnb.org` vacancy">
#  <div class="float-right text-right d-inline-block w-25 ml-2">
#  <span class="d-block d-md-none text-break job-list-item-location">San Francisco, CA</span>
#  <span class="d-none d-md-block text-break job-list-item-location">San Francisco, CA</span>
#  <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
#  <div class="d-block">
#  <span class="badge badge-info badge-pill my-md-1 d-md-none">Senior</span>
#  <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Senior-level</span>
#  </div>
#  <div class="d-block">
#  <span class="badge badge-success badge-pill d-none d-md-inline-block">USD 152K - 203K</span>
#  <span class="badge badge-success badge-pill d-md-none">USD 152K+</span>
#  </div>
#  </div>
#  <p class="m-0 text-muted job-list-item-company">Airbnb</p>
#  <h2 class="h4 mb-1">Senior Analytics Engineer, Airbnb.org</h2>
#  <span class="badge badge-light badge-pill">Airflow</span>
#  <span class="badge badge-light badge-pill">Data analysis</span>
#  <span class="badge badge-light badge-pill">Engineering</span>
#  <span class="badge badge-light badge-pill">ETL</span>
#  <span class="badge badge-light badge-pill">Machine Learning</span>
#  <span class="badge badge-light badge-pill">Pipelines</span>
#  <span class="badge badge-light badge-pill">Predictive modeling</span>
#  <span class="badge badge-light badge-pill">+5</span>
#  <br/>
#  <span class="badge badge-success badge-pill">Career development</span>
#  <span class="badge badge-success badge-pill">Salary bonus</span>
#  </a>,
#  <a class="col list-group-item-action px-2 py-3" href="/job/26502-business-data-analyst-consultant/" title="View full details of `Business Data Analyst - Consultant` vacancy">
#  <div class="float-right text-right d-inline-block w-25 ml-2">
#  <span class="d-block d-md-none text-break job-list-item-location">Amsterdam, Netherlands</span>
#  <span class="d-none d-md-block text-break job-list-item-location">Amsterdam, Netherlands</span>
#  <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
#  <div class="d-block">
#  <span class="badge badge-info badge-pill my-md-1 d-md-none">Senior</span>
#  <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Senior-level</span>
#  </div>
#  </div>
#  <p class="m-0 text-muted job-list-item-company">sennder</p>
#  <h2 class="h4 mb-1">Business Data Analyst - Consultant</h2>
#  <span class="badge badge-light badge-pill">Banking</span>
#  <span class="badge badge-light badge-pill">Consulting</span>
#  <span class="badge badge-light badge-pill">Data visualization</span>
#  <span class="badge badge-light badge-pill">Excel</span>
#  <span class="badge badge-light badge-pill">KPIs</span>
#  <span class="badge badge-light badge-pill">Looker</span>
#  <span class="badge badge-light badge-pill">SQL</span>
#  <br/>
#  <span class="badge badge-success badge-pill">Career development</span>
#  <span class="badge badge-success badge-pill">Startup environment</span>
#  <span class="badge badge-success badge-pill">Team events</span>
#  </a>,
#  <a class="col list-group-item-action px-2 py-3" href="/job/26505-data-analytics-teamlead/" title="View full details of `Data analytics Teamlead` vacancy">
#  <div class="float-right text-right d-inline-block w-25 ml-2">
#  <span class="d-block d-md-none text-break job-list-item-location">Slovakia</span>
#  <span class="d-none d-md-block text-break job-list-item-location">Slovakia</span>
#  <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
#  <div class="d-block">
#  <span class="badge badge-info badge-pill my-md-1 d-md-none">Mid</span>
#  <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Mid-level</span>
#  </div>
#  </div>
#  <p class="m-0 text-muted job-list-item-company">CloudTalk</p>
#  <h2 class="h4 mb-1">Data analytics Teamlead</h2>
#  <span class="badge badge-light badge-pill">Data analysis</span>
#  <span class="badge badge-light badge-pill">Data Analytics</span>
#  <span class="badge badge-light badge-pill">Data strategy</span>
#  <span class="badge badge-light badge-pill">Data Warehousing</span>
#  <span class="badge badge-light badge-pill">E-commerce</span>
#  <span class="badge badge-light badge-pill">Engineering</span>
#  <span class="badge badge-light badge-pill">Finance</span>
#  <span class="badge badge-light badge-pill">+4</span>
#  <br/>
#  <span class="badge badge-success badge-pill">Career development</span>
#  <span class="badge badge-success badge-pill">Flex hours</span>
#  <span class="badge badge-success badge-pill">Flex vacation</span>
#  <span class="badge badge-success badge-pill">Gear</span>
#  <span class="badge badge-success badge-pill">Health care</span>
#  <span class="badge badge-success badge-pill">+2</span>
#  </a>,
#  <a class="col list-group-item-action px-2 py-3" href="/job/26475-data-engineer-scot-aim-inventory-research-and-analytics/" title="View full details of `Data Engineer, SCOT AIM: Inventory Research and Analytics` vacancy">
#  <div class="float-right text-right d-inline-block w-25 ml-2">
#  <span class="d-block d-md-none text-break job-list-item-location">Austin, Texas, USA</span>
#  <span class="d-none d-md-block text-break job-list-item-location">Austin, Texas, USA</span>
#  <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
#  <div class="d-block">
#  <span class="badge badge-info badge-pill my-md-1 d-md-none">Senior</span>
#  <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Senior-level</span>
#  </div>
#  <div class="d-block">
#  <span class="badge badge-success badge-pill d-none d-md-inline-block">USD 76K - 150K *</span>
#  <span class="badge badge-success badge-pill d-md-none">USD 76K+ *</span>
#  </div>
#  </div>
#  <p class="m-0 text-muted job-list-item-company">Amazon.com</p>
#  <h2 class="h4 mb-1">Data Engineer, SCOT AIM: Inventory Research and Analytics</h2>
#  <span class="badge badge-light badge-pill">Big Data</span>
#  <span class="badge badge-light badge-pill">Business Intelligence</span>
#  <span class="badge badge-light badge-pill">Data management</span>
#  <span class="badge badge-light badge-pill">Data Warehousing</span>
#  <span class="badge badge-light badge-pill">Distributed Systems</span>
#  <span class="badge badge-light badge-pill">Engineering</span>
#  <span class="badge badge-light badge-pill">ETL</span>
#  <span class="badge badge-light badge-pill">+12</span>
#  <br/>
#  </a>,
#  <a class="col list-group-item-action px-2 py-3" href="/job/26445-senior-analytics-engineer/" title="View full details of `Senior Analytics Engineer` vacancy">
#  <div class="float-right text-right d-inline-block w-25 ml-2">
#  <span class="d-block d-md-none text-break job-list-item-location">Porto</span>
#  <span class="d-none d-md-block text-break job-list-item-location">Porto</span>
#  <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
#  <div class="d-block">
#  <span class="badge badge-info badge-pill my-md-1 d-md-none">Senior</span>
#  <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Senior-level</span>
#  </div>
#  </div>
#  <p class="m-0 text-muted job-list-item-company">GetGround</p>
#  <h2 class="h4 mb-1">Senior Analytics Engineer</h2>
#  <span class="badge badge-light badge-pill">Agile</span>
#  <span class="badge badge-light badge-pill">BigQuery</span>
#  <span class="badge badge-light badge-pill">Business Analytics</span>
#  <span class="badge badge-light badge-pill">Data pipelines</span>
#  <span class="badge badge-light badge-pill">DevOps</span>
#  <span class="badge badge-light badge-pill">Engineering</span>
#  <span class="badge badge-light badge-pill">JavaScript</span>
#  <span class="badge badge-light badge-pill">+6</span>
#  <br/>
#  <span class="badge badge-success badge-pill">Career development</span>
#  <span class="badge badge-success badge-pill">Competitive pay</span>
#  <span class="badge badge-success badge-pill">Conferences</span>
#  <span class="badge badge-success badge-pill">Equity</span>
#  <span class="badge badge-success badge-pill">Flex hours</span>
#  <span class="badge badge-success badge-pill">+2</span>
#  </a>,
#  <a class="col list-group-item-action px-2 py-3" href="/job/26497-associate-hr-data-analyst/" title="View full details of `Associate HR Data Analyst` vacancy">
#  <div class="float-right text-right d-inline-block w-25 ml-2">
#  <span class="d-block d-md-none text-break job-list-item-location">United States, Remote</span>
#  <span class="d-none d-md-block text-break job-list-item-location">United States, Remote</span>
#  <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
#  <div class="d-block">
#  <span class="badge badge-info badge-pill my-md-1 d-md-none">Mid</span>
#  <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Mid-level</span>
#  </div>
#  <div class="d-block">
#  <span class="badge badge-success badge-pill d-none d-md-inline-block">USD 51K - 90K *</span>
#  <span class="badge badge-success badge-pill d-md-none">USD 51K+ *</span>
#  </div>
#  </div>
#  <p class="m-0 text-muted job-list-item-company">Ivanti</p>
#  <h2 class="h4 mb-1">Associate HR Data Analyst</h2>
#  <span class="badge badge-light badge-pill">Excel</span>
#  <span class="badge badge-light badge-pill">Finance</span>
#  <span class="badge badge-light badge-pill">Testing</span>
#  <br/>
#  <span class="badge badge-success badge-pill">Competitive pay</span>
#  <span class="badge badge-success badge-pill">Flex vacation</span>
#  </a>,
#  <a class="col list-group-item-action px-2 py-3" href="/job/26499-data-analyst/" title="View full details of `Data Analyst` vacancy">
#  <div class="float-right text-right d-inline-block w-25 ml-2">
#  <span class="d-block d-md-none text-break job-list-item-location">Cluj-Napoca, Cluj, Romania</span>
#  <span class="d-none d-md-block text-break job-list-item-location">Cluj-Napoca, Cluj, Romania</span>
#  <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
#  <div class="d-block">
#  <span class="badge badge-info badge-pill my-md-1 d-md-none">Senior</span>
#  <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Senior-level</span>
#  </div>
#  <div class="d-block">
#  <span class="badge badge-success badge-pill d-none d-md-inline-block">USD 50K - 85K *</span>
#  <span class="badge badge-success badge-pill d-md-none">USD 50K+ *</span>
#  </div>
#  </div>
#  <p class="m-0 text-muted job-list-item-company">ComplyAdvantage</p>
#  <h2 class="h4 mb-1">Data Analyst</h2>
#  <span class="badge badge-light badge-pill">Agile</span>
#  <span class="badge badge-light badge-pill">Data analysis</span>
#  <span class="badge badge-light badge-pill">Data Analytics</span>
#  <span class="badge badge-light badge-pill">Data visualization</span>
#  <span class="badge badge-light badge-pill">Economics</span>
#  <span class="badge badge-light badge-pill">Looker</span>
#  <span class="badge badge-light badge-pill">Python</span>
#  <span class="badge badge-light badge-pill">+4</span>
#  <br/>
#  <span class="badge badge-success badge-pill">Career development</span>
#  <span class="badge badge-success badge-pill">Competitive pay</span>
#  <span class="badge badge-success badge-pill">Equity</span>
#  <span class="badge badge-success badge-pill">Medical leave</span>
#  <span class="badge badge-success badge-pill">Parental leave</span>
#  <span class="badge badge-success badge-pill">+1</span>
#  </a>,
#  <a class="col list-group-item-action px-2 py-3" href="/job/26506-senior-data-analyst/" title="View full details of `Senior Data Analyst` vacancy">
#  <div class="float-right text-right d-inline-block w-25 ml-2">
#  <span class="d-block d-md-none text-break job-list-item-location">Los Angeles, California, United …</span>
#  <span class="d-none d-md-block text-break job-list-item-location">Los Angeles, California, United States - Remote</span>
#  <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
#  <div class="d-block">
#  <span class="badge badge-info badge-pill my-md-1 d-md-none">Mid</span>
#  <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Mid-level</span>
#  </div>
#  <div class="d-block">
#  <span class="badge badge-success badge-pill d-none d-md-inline-block">USD 51K - 90K *</span>
#  <span class="badge badge-success badge-pill d-md-none">USD 51K+ *</span>
#  </div>
#  </div>
#  <p class="m-0 text-muted job-list-item-company">Athletic Greens</p>
#  <h2 class="h4 mb-1">Senior Data Analyst</h2>
#  <span class="badge badge-light badge-pill">BigQuery</span>
#  <span class="badge badge-light badge-pill">Data Studio</span>
#  <span class="badge badge-light badge-pill">Data visualization</span>
#  <span class="badge badge-light badge-pill">E-commerce</span>
#  <span class="badge badge-light badge-pill">Engineering</span>
#  <span class="badge badge-light badge-pill">Finance</span>
#  <span class="badge badge-light badge-pill">KPIs</span>
#  <span class="badge badge-light badge-pill">+12</span>
#  <br/>
#  <span class="badge badge-success badge-pill">401(k) matching</span>
#  <span class="badge badge-success badge-pill">Career development</span>
#  <span class="badge badge-success badge-pill">Flex vacation</span>
#  <span class="badge badge-success badge-pill">Gear</span>
#  <span class="badge badge-success badge-pill">Health care</span>
#  <span class="badge badge-success badge-pill">+6</span>
#  </a>,
#  <a class="col list-group-item-action px-2 py-3" href="/job/26504-research-data-analyst/" title="View full details of `Research &amp; Data Analyst` vacancy">
#  <div class="float-right text-right d-inline-block w-25 ml-2">
#  <span class="d-block d-md-none text-break job-list-item-location">Mexico</span>
#  <span class="d-none d-md-block text-break job-list-item-location">Mexico</span>
#  <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
#  <div class="d-block">
#  <span class="badge badge-info badge-pill my-md-1 d-md-none">Mid</span>
#  <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Mid-level</span>
#  </div>
#  <div class="d-block">
#  <span class="badge badge-success badge-pill d-none d-md-inline-block">USD 51K - 90K *</span>
#  <span class="badge badge-success badge-pill d-md-none">USD 51K+ *</span>
#  </div>
#  </div>
#  <p class="m-0 text-muted job-list-item-company">Euromonitor</p>
#  <h2 class="h4 mb-1">Research &amp; Data Analyst</h2>
#  <span class="badge badge-light badge-pill">Business Intelligence</span>
#  <span class="badge badge-light badge-pill">Excel</span>
#  <span class="badge badge-light badge-pill">Market research</span>
#  <span class="badge badge-light badge-pill">Research</span>
#  <br/>
#  <span class="badge badge-success badge-pill">Career development</span>
#  <span class="badge badge-success badge-pill">Competitive pay</span>
#  <span class="badge badge-success badge-pill">Flex hours</span>
#  <span class="badge badge-success badge-pill">Health care</span>
#  <span class="badge badge-success badge-pill">Insurance</span>
#  <span class="badge badge-success badge-pill">+1</span>
# ...
#  <div class="d-block">
#  <span class="badge badge-info badge-pill my-md-1 d-md-none">Mid</span>
#  <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Mid-level</span>
#  </div>
#  <div class="d-block">
#  <span class="badge badge-success badge-pill d-none d-md-inline-block">USD 51K - 90K *</span>
#  <span class="badge badge-success badge-pill d-md-none">USD 51K+ *</span>
#  </div>
#  </div>
#  <p class="m-0 text-muted job-list-item-company">So Energy</p>
#  <h2 class="h4 mb-1">Data Analyst -MS SQL (SSIS, SSRS, SSAS)</h2>
#  <span class="badge badge-light badge-pill">Engineering</span>
#  <span class="badge badge-light badge-pill">Looker</span>
#  <span class="badge badge-light badge-pill">MS SQL</span>
#  <span class="badge badge-light badge-pill">Power BI</span>
#  <span class="badge badge-light badge-pill">Python</span>
#  <span class="badge badge-light badge-pill">SQL</span>
#  <span class="badge badge-light badge-pill">SSIS</span>
#  <br/>
#  <span class="badge badge-success badge-pill">Career development</span>
#  <span class="badge badge-success badge-pill">Competitive pay</span>
#  <span class="badge badge-success badge-pill">Flex hours</span>
#  <span class="badge badge-success badge-pill">Salary bonus</span>
#  </a>,
#  <a class="col list-group-item-action px-2 py-3" href="/job/26165-insight-analyst/" title="View full details of `Insight Analyst` vacancy">
#  <div class="float-right text-right d-inline-block w-25 ml-2">
#  <span class="d-block d-md-none text-break job-list-item-location">London, England, United Kingdom</span>
#  <span class="d-none d-md-block text-break job-list-item-location">London, England, United Kingdom</span>
#  <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
#  <div class="d-block">
#  <span class="badge badge-info badge-pill my-md-1 d-md-none">Mid</span>
#  <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Mid-level</span>
#  </div>
#  </div>
#  <p class="m-0 text-muted job-list-item-company">Multiverse</p>
#  <h2 class="h4 mb-1">Insight Analyst</h2>
#  <span class="badge badge-light badge-pill">Excel</span>
#  <span class="badge badge-light badge-pill">Machine Learning</span>
#  <span class="badge badge-light badge-pill">SQL</span>
#  <span class="badge badge-light badge-pill">Tableau</span>
#  <br/>
#  <span class="badge badge-success badge-pill">Career development</span>
#  <span class="badge badge-success badge-pill">Health care</span>
#  <span class="badge badge-success badge-pill">Insurance</span>
#  <span class="badge badge-success badge-pill">Team events</span>
#  </a>,
#  <a class="col list-group-item-action px-2 py-3" href="/job/26113-finance-analyst-aws-ai-and-machine-learning-aws-ai-ml-service-finance-aws-aiml/" title="View full details of `Finance Analyst, AWS AI and Machine Learning, AWS AI-ML Service Finance, AWS AI/ML` vacancy">
#  <div class="float-right text-right d-inline-block w-25 ml-2">
#  <span class="d-block d-md-none text-break job-list-item-location">Arlington, Virginia, USA</span>
#  <span class="d-none d-md-block text-break job-list-item-location">Arlington, Virginia, USA</span>
#  <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
#  <div class="d-block">
#  <span class="badge badge-info badge-pill my-md-1 d-md-none">Senior</span>
#  <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Senior-level</span>
#  </div>
#  </div>
#  <p class="m-0 text-muted job-list-item-company">Amazon.com</p>
#  <h2 class="h4 mb-1">Finance Analyst, AWS AI and Machine Learning, AWS AI-ML Service Finance, AWS AI/ML</h2>
#  <span class="badge badge-light badge-pill">AWS</span>
#  <span class="badge badge-light badge-pill">Big Data</span>
#  <span class="badge badge-light badge-pill">Economics</span>
#  <span class="badge badge-light badge-pill">Engineering</span>
#  <span class="badge badge-light badge-pill">Excel</span>
#  <span class="badge badge-light badge-pill">Finance</span>
#  <span class="badge badge-light badge-pill">Machine Learning</span>
#  <span class="badge badge-light badge-pill">+2</span>
#  <br/>
#  </a>,
#  <a class="col list-group-item-action px-2 py-3" href="/job/26116-data-analytics-logistics/" title="View full details of `Data Analytics - Logistics` vacancy">
#  <div class="float-right text-right d-inline-block w-25 ml-2">
#  <span class="d-block d-md-none text-break job-list-item-location">Buenos Aires, Buenos Aires, …</span>
#  <span class="d-none d-md-block text-break job-list-item-location">Buenos Aires, Buenos Aires, Argentina</span>
#  <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
#  <div class="d-block">
#  <span class="badge badge-info badge-pill my-md-1 d-md-none">Senior</span>
#  <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Senior-level</span>
#  </div>
#  </div>
#  <p class="m-0 text-muted job-list-item-company">Shopee</p>
#  <h2 class="h4 mb-1">Data Analytics - Logistics</h2>
#  <span class="badge badge-light badge-pill">Data Analytics</span>
#  <span class="badge badge-light badge-pill">Data Studio</span>
#  <span class="badge badge-light badge-pill">Engineering</span>
#  <span class="badge badge-light badge-pill">Power BI</span>
#  <span class="badge badge-light badge-pill">Python</span>
#  <span class="badge badge-light badge-pill">SQL</span>
#  <span class="badge badge-light badge-pill">Statistics</span>
#  <br/>
#  </a>,
#  <a class="col list-group-item-action px-2 py-3" href="/job/26118-data-analytics-engineer-co-op-fall-2022/" title="View full details of `Data Analytics Engineer Co-op - Fall 2022` vacancy">
#  <div class="float-right text-right d-inline-block w-25 ml-2">
#  <span class="d-block d-md-none text-break job-list-item-location">Canada, Remote</span>
#  <span class="d-none d-md-block text-break job-list-item-location">Canada, Remote</span>
#  <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
#  </div>
#  <p class="m-0 text-muted job-list-item-company">Wonolo</p>
#  <h2 class="h4 mb-1">Data Analytics Engineer Co-op - Fall 2022</h2>
#  <span class="badge badge-light badge-pill">CAD</span>
#  <span class="badge badge-light badge-pill">Data Analytics</span>
#  <span class="badge badge-light badge-pill">Data pipelines</span>
#  <span class="badge badge-light badge-pill">Engineering</span>
#  <span class="badge badge-light badge-pill">ETL</span>
#  <span class="badge badge-light badge-pill">Pipelines</span>
#  <span class="badge badge-light badge-pill">Python</span>
#  <span class="badge badge-light badge-pill">+1</span>
#  <br/>
#  <span class="badge badge-success badge-pill">Career development</span>
#  <span class="badge badge-success badge-pill">Competitive pay</span>
#  <span class="badge badge-success badge-pill">Equity</span>
#  <span class="badge badge-success badge-pill">Flex hours</span>
#  <span class="badge badge-success badge-pill">Startup environment</span>
#  <span class="badge badge-success badge-pill">+2</span>
#  </a>,
#  <a class="col list-group-item-action px-2 py-3" href="/job/26111-lead-analyst-data-management/" title="View full details of `Lead Analyst, Data Management` vacancy">
#  <div class="float-right text-right d-inline-block w-25 ml-2">
#  <span class="d-block d-md-none text-break job-list-item-location">Sydney, New South Wales, …</span>
#  <span class="d-none d-md-block text-break job-list-item-location">Sydney, New South Wales, Australia</span>
#  <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
#  <div class="d-block">
#  <span class="badge badge-info badge-pill my-md-1 d-md-none">Executive</span>
#  <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Executive-level</span>
#  </div>
#  </div>
#  <p class="m-0 text-muted job-list-item-company">Quantium</p>
#  <h2 class="h4 mb-1">Lead Analyst, Data Management</h2>
#  <span class="badge badge-light badge-pill">Agile</span>
#  <span class="badge badge-light badge-pill">Big Data</span>
#  <span class="badge badge-light badge-pill">Consulting</span>
#  <span class="badge badge-light badge-pill">Data analysis</span>
#  <span class="badge badge-light badge-pill">Data Analytics</span>
#  <span class="badge badge-light badge-pill">Data management</span>
#  <span class="badge badge-light badge-pill">Engineering</span>
#  <span class="badge badge-light badge-pill">+4</span>
#  <br/>
#  <span class="badge badge-success badge-pill">Career development</span>
#  <span class="badge badge-success badge-pill">Startup environment</span>
#  <span class="badge badge-success badge-pill">Team events</span>
#  </a>,
#  <a class="col list-group-item-action px-2 py-3" href="/job/26114-sr-data-analyst-cmg-analytics/" title="View full details of `Sr. Data Analyst (CMG Analytics)` vacancy">
#  <div class="float-right text-right d-inline-block w-25 ml-2">
#  <span class="d-block d-md-none text-break job-list-item-location">Seoul, South Korea</span>
#  <span class="d-none d-md-block text-break job-list-item-location">Seoul, South Korea</span>
#  <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
#  <div class="d-block">
#  <span class="badge badge-info badge-pill my-md-1 d-md-none">Senior</span>
#  <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Senior-level</span>
#  </div>
#  <div class="d-block">
#  <span class="badge badge-success badge-pill d-none d-md-inline-block">USD 50K - 85K *</span>
#  <span class="badge badge-success badge-pill d-md-none">USD 50K+ *</span>
#  </div>
#  </div>
#  <p class="m-0 text-muted job-list-item-company">Coupang</p>
#  <h2 class="h4 mb-1">Sr. Data Analyst (CMG Analytics)</h2>
#  <span class="badge badge-light badge-pill">Airflow</span>
#  <span class="badge badge-light badge-pill">E-commerce</span>
#  <span class="badge badge-light badge-pill">Looker</span>
#  <span class="badge badge-light badge-pill">Power BI</span>
#  <span class="badge badge-light badge-pill">Python</span>
#  <span class="badge badge-light badge-pill">Qlik</span>
#  <span class="badge badge-light badge-pill">R</span>
#  <span class="badge badge-light badge-pill">+2</span>
#  <br/>
#  </a>,
#  <a class="col list-group-item-action px-2 py-3" href="/job/26117-sr-data-analyst-marketing/" title="View full details of `Sr. Data Analyst, Marketing` vacancy">
#  <div class="float-right text-right d-inline-block w-25 ml-2">
#  <span class="d-block d-md-none text-break job-list-item-location">Seattle, WA</span>
#  <span class="d-none d-md-block text-break job-list-item-location">Seattle, WA</span>
#  <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
#  <div class="d-block">
#  <span class="badge badge-info badge-pill my-md-1 d-md-none">Senior</span>
#  <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Senior-level</span>
#  </div>
#  <div class="d-block">
#  <span class="badge badge-success badge-pill d-none d-md-inline-block">USD 50K - 85K *</span>
#  <span class="badge badge-success badge-pill d-md-none">USD 50K+ *</span>
#  </div>
#  </div>
#  <p class="m-0 text-muted job-list-item-company">Clari</p>
#  <h2 class="h4 mb-1">Sr. Data Analyst, Marketing</h2>
#  <span class="badge badge-light badge-pill">A/B testing</span>
#  <span class="badge badge-light badge-pill">Consulting</span>
#  <span class="badge badge-light badge-pill">Finance</span>
#  <span class="badge badge-light badge-pill">Python</span>
#  <span class="badge badge-light badge-pill">R</span>
#  <span class="badge badge-light badge-pill">SQL</span>
#  <span class="badge badge-light badge-pill">Tableau</span>
#  <span class="badge badge-light badge-pill">+1</span>
#  <br/>
#  <span class="badge badge-success badge-pill">Equity</span>
#  <span class="badge badge-success badge-pill">Fertility benefits</span>
#  <span class="badge badge-success badge-pill">Flex hours</span>
#  <span class="badge badge-success badge-pill">Parental leave</span>
#  <span class="badge badge-success badge-pill">Startup environment</span>
#  <span class="badge badge-success badge-pill">+1</span>
#  </a>,
#  <a class="col list-group-item-action px-2 py-3" href="/job/26115-consumer-research-data-analyst/" title="View full details of `Consumer Research &amp; Data Analyst` vacancy">
#  <div class="float-right text-right d-inline-block w-25 ml-2">
#  <span class="d-block d-md-none text-break job-list-item-location">Chicago</span>
#  <span class="d-none d-md-block text-break job-list-item-location">Chicago</span>
#  <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
#  <div class="d-block">
#  <span class="badge badge-info badge-pill my-md-1 d-md-none">Senior</span>
#  <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Senior-level</span>
#  </div>
#  <div class="d-block">
#  <span class="badge badge-success badge-pill d-none d-md-inline-block">USD 50K - 85K *</span>
#  <span class="badge badge-success badge-pill d-md-none">USD 50K+ *</span>
#  </div>
#  </div>
#  <p class="m-0 text-muted job-list-item-company">Mintel</p>
#  <h2 class="h4 mb-1">Consumer Research &amp; Data Analyst</h2>
#  <span class="badge badge-light badge-pill">Data analysis</span>
#  <span class="badge badge-light badge-pill">Data Analytics</span>
#  <span class="badge badge-light badge-pill">Finance</span>
#  <span class="badge badge-light badge-pill">R</span>
#  <span class="badge badge-light badge-pill">Research</span>
#  <span class="badge badge-light badge-pill">Statistics</span>
#  <span class="badge badge-light badge-pill">Survey data</span>
#  <br/>
#  <span class="badge badge-success badge-pill">Career development</span>
#  </a>,
#  <a class="col list-group-item-action px-2 py-3" href="/job/26166-insight-analyst/" title="View full details of `Insight Analyst` vacancy">
#  <div class="float-right text-right d-inline-block w-25 ml-2">
#  <span class="d-block d-md-none text-break job-list-item-location">United Kingdom</span>
#  <span class="d-none d-md-block text-break job-list-item-location">United Kingdom</span>
#  <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
#  <div class="d-block">
#  <span class="badge badge-info badge-pill my-md-1 d-md-none">Mid</span>
#  <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Mid-level</span>
#  </div>
#  </div>
#  <p class="m-0 text-muted job-list-item-company">So Energy</p>
#  <h2 class="h4 mb-1">Insight Analyst</h2>
#  <span class="badge badge-light badge-pill">Agile</span>
#  <span class="badge badge-light badge-pill">BigQuery</span>
#  <span class="badge badge-light badge-pill">Consulting</span>
#  <span class="badge badge-light badge-pill">Data analysis</span>
#  <span class="badge badge-light badge-pill">Data Analytics</span>
#  <span class="badge badge-light badge-pill">Data Mining</span>
#  <span class="badge badge-light badge-pill">Data visualization</span>
#  <span class="badge badge-light badge-pill">+12</span>
#  <br/>
#  <span class="badge badge-success badge-pill">Career development</span>
#  <span class="badge badge-success badge-pill">Competitive pay</span>
#  </a>,
#  <a class="col list-group-item-action px-2 py-3" href="/job/26120-regional-data-analyst-cross-border-based-in-malaysia/" title="View full details of `Regional Data Analyst, Cross Border (based in Malaysia)` vacancy">
#  <div class="float-right text-right d-inline-block w-25 ml-2">
#  <span class="d-block d-md-none text-break job-list-item-location">Shah Alam, Malaysia</span>
#  <span class="d-none d-md-block text-break job-list-item-location">Shah Alam, Malaysia</span>
#  <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
#  <div class="d-block">
#  <span class="badge badge-success badge-pill d-none d-md-inline-block">USD 50K - 85K *</span>
#  <span class="badge badge-success badge-pill d-md-none">USD 50K+ *</span>
#  </div>
#  </div>
#  <p class="m-0 text-muted job-list-item-company">Ninja Van</p>
#  <h2 class="h4 mb-1">Regional Data Analyst, Cross Border (based in Malaysia)</h2>
#  <span class="badge badge-light badge-pill">Business Intelligence</span>
#  <span class="badge badge-light badge-pill">Data Analytics</span>
#  <span class="badge badge-light badge-pill">Excel</span>
#  <span class="badge badge-light badge-pill">KPIs</span>
#  <span class="badge badge-light badge-pill">Python</span>
#  <span class="badge badge-light badge-pill">SQL</span>
#  <br/>
#  </a>]

# %%
# check number of entries
len(needed_info)
# Out:
# 100

# %% [markdown]
# Comment
#
#     10 more jobs added from the last time srapping was done

# %%
# take a peep into sample of the needed_info
needed_info[12]
# Out:
# <a class="col list-group-item-action px-2 py-3" href="/job/26583-senior-data-analyst/" title="View full details of `Senior Data Analyst` vacancy">
# <div class="float-right text-right d-inline-block w-25 ml-2">
# <span class="d-block d-md-none text-break job-list-item-location">London, England, United Kingdom …</span>
# <span class="d-none d-md-block text-break job-list-item-location">London, England, United Kingdom - Remote</span>
# <span class="badge badge-secondary badge-pill my-md-1">Full Time</span>
# <div class="d-block">
# <span class="badge badge-info badge-pill my-md-1 d-md-none">Mid</span>
# <span class="badge badge-info badge-pill my-md-1 d-none d-md-inline-block">Mid-level</span>
# </div>
# <div class="d-block">
# <span class="badge badge-success badge-pill d-none d-md-inline-block">USD 51K - 90K *</span>
# <span class="badge badge-success badge-pill d-md-none">USD 51K+ *</span>
# </div>
# </div>
# <p class="m-0 text-muted job-list-item-company">FitXR</p>
# <h2 class="h4 mb-1">Senior Data Analyst</h2>
# <span class="badge badge-light badge-pill">A/B testing</span>
# <span class="badge badge-light badge-pill">BigQuery</span>
# <span class="badge badge-light badge-pill">DevOps</span>
# <span class="badge badge-light badge-pill">Engineering</span>
# <span class="badge badge-light badge-pill">Julia</span>
# <span class="badge badge-light badge-pill">Python</span>
# <span class="badge badge-light badge-pill">R</span>
# <span class="badge badge-light badge-pill">+2</span>
# <br/>
# <span class="badge badge-success badge-pill">Career development</span>
# <span class="badge badge-success badge-pill">Competitive pay</span>
# <span class="badge badge-success badge-pill">Equity</span>
# <span class="badge badge-success badge-pill">Flex vacation</span>
# <span class="badge badge-success badge-pill">Gear</span>
# <span class="badge badge-success badge-pill">+3</span>
# </a>

# %%
#pulling out content from each index of the list 
needed_info[0].find('span', {'class':'badge badge-secondary badge-pill my-md-1'}).get_text()
# Out:
# 'Full Time'

# %% [markdown]
# ## Extracting Content from Each Element of in Need_Info: Test

# %% [markdown]
# ### Title

# %%
# Approach 1
needed_info[0].find('h2', {'class':'h4 mb-1'}).string
# Out:
# 'Business Intelligence Analyst'

# %%
# Approach 2. Use when you are sure there is only one of h2 in the webpage content
needed_info[0].h2.string
# Out:
# 'Business Intelligence Analyst'

# %%
# Approach 3
needed_info[0].find('h2', {'class':'h4 mb-1'}).get_text()
# Out:
# 'Business Intelligence Analyst'

# %%
# Approach 4. Use when you are sure there is only one of h2 in the webpage content
needed_info[0].h2.get_text()
# Out:
# 'Business Intelligence Analyst'

# %% [markdown]
# ### Skill

# %%
# Loop to get skills list. Approah 1
[x.get_text() for x in needed_info[0].find_all('span', 'badge badge-light badge-pill')]
# Out:
# ['Business Intelligence',
#  'Data management',
#  'Power BI',
#  'Python',
#  'R',
#  'SAS',
#  'SQL',
#  '+2']

# %%
# Loop to get skills list. Approah 2
skill_list =[]
for i in needed_info[0].find_all('span', {'class':'badge badge-light badge-pill'}):
    g = i.get_text()
    skill_list.append(g)
skill_list
# Out:
# ['Business Intelligence',
#  'Data management',
#  'Power BI',
#  'Python',
#  'R',
#  'SAS',
#  'SQL',
#  '+2']

# %% [markdown]
# ### Benefits

# %%
# Loop to get benefits list. Approah 1
[j.string for j in needed_info[0].find_all('span', 'badge badge-success badge-pill')]
# note the class is not stated. Only a comma between the span and class name
# Out:
# ['Competitive pay',
#  'Conferences',
#  'Fitness / gym',
#  'Health care',
#  'Insurance',
#  '+3']

# %%
# Loop to get benefits list. Approah 2
[j.string for j in needed_info[0].find_all('span', {'class':'badge badge-success badge-pill'})]
# note the class is stated and followed by a column before the class name in quotation marks
# Out:
# ['Competitive pay',
#  'Conferences',
#  'Fitness / gym',
#  'Health care',
#  'Insurance',
#  '+3']

# %% [markdown]
# ### Company

# %%
needed_info[0].find('p', {'class':'m-0 text-muted job-list-item-company'}).get_text()
# Out:
# 'Amica Mutual Insurance Company'

# %%
needed_info[0].find('p', {'class':'m-0 text-muted job-list-item-company'}).string
# Out:
# 'Amica Mutual Insurance Company'

# %% [markdown]
# ### Location

# %%
needed_info[0].find('span', 'd-block d-md-none text-break job-list-item-location').get_text()
# Out:
# 'Lincoln, RI, 02865'

# %% [markdown]
# ### Job Type

# %%
needed_info[0].find('span', 'badge badge-secondary badge-pill my-md-1').string
# Out:
# 'Full Time'

# %% [markdown]
# ### Level

# %%
needed_info[0].find('span', 'badge badge-info badge-pill my-md-1 d-none d-md-inline-block').get_text()
# Out:
# 'Mid-level'

# %% [markdown]
# ### Salary

# %%
needed_info[12].find('span', 'badge badge-success badge-pill d-md-none').string
# Out:
# 'USD 51K+ *'

# %% [markdown]
# ## Job Type

# %%
needed_info[0].find('span', 'badge badge-secondary badge-pill my-md-1').get_text()
# Out:
# 'Full Time'

# %% [markdown]
# ## Creating Data Frame by Looping Over Entire Needed_Info Content

# %%
# create empty lists of variables to tbe extracted
job_title = []
company = []
location = []
level = []
job_type = []
salary = []
skills = []
benefits = []


# loop over the soup content to extract required information
for needed_info in needed_info:
    try:
        job_title.append(needed_info.find('h2', {'class':'h4 mb-1'}).get_text())
    except:
        job_title.append('not_stated')
        
    try:
        company.append(needed_info.find('p', {'class':'m-0 text-muted job-list-item-company'}).get_text())
    except:
        company.append('not_stated')
    
    try:
        location.append(needed_info.find('span', {'class':'d-block d-md-none text-break job-list-item-location'}).get_text())
    except:
        location.append('not_stated')
        
    try:
        level.append(needed_info.find('span', {'class':'badge badge-info badge-pill my-md-1 d-none d-md-inline-block'}).get_text())
    except:
        level.append('not_stated')
    
    try:
        job_type.append(needed_info.find('span', {'class':'badge badge-secondary badge-pill my-md-1'}).get_text())
    except:
        job_type.append('not_stated')
        
    try:
        salary.append(needed_info.find('span', {'class':'badge badge-success badge-pill d-md-none'}).get_text()) 
    except:
        salary.append('not_stated')
    
    try:
        skills.append([x.get_text() for x in needed_info.find_all('span', {'class':'badge badge-light badge-pill'})])
    except:
        skills.append('not_stated')
    
    try:
        benefits.append([j.string for j in needed_info.find_all('span', {'class':'badge badge-success badge-pill'})])
    except:
        benefits.append('not_stated')

# %%
# view salary column
salary
# Out:
# ['not_stated',
#  'not_stated',
#  'USD 30K+ *',
#  'not_stated',
#  'USD 180K+',
#  'USD 50K+ *',
#  'not_stated',
#  'USD 68K+ *',
#  'USD 50K+ *',
#  'not_stated',
#  'not_stated',
#  'not_stated',
#  'USD 51K+ *',
#  'USD 51K+ *',
#  'USD 50K+ *',
#  'not_stated',
#  'USD 80K+',
#  'USD 50K+ *',
#  'USD 30K+ *',
#  'USD 50K+ *',
#  'USD 90K+',
#  'USD 50K+ *',
#  'USD 152K+',
#  'not_stated',
#  'not_stated',
#  'USD 76K+ *',
#  'not_stated',
#  'USD 51K+ *',
#  'USD 50K+ *',
#  'USD 51K+ *',
#  'USD 51K+ *',
#  'not_stated',
#  'not_stated',
#  'USD 50K+ *',
#  'USD 50K+ *',
#  'not_stated',
#  'not_stated',
#  'USD 50K+ *',
#  'not_stated',
#  'USD 50K+ *',
#  'USD 50K+ *',
#  'not_stated',
#  'USD 68K+ *',
#  'USD 51K+ *',
#  'not_stated',
#  'USD 50K+ *',
#  'USD 50K+ *',
#  'not_stated',
#  'not_stated',
#  'USD 50K+ *',
#  'USD 50K+ *',
#  'USD 50K+ *',
#  'USD 50K+ *',
#  'USD 51K+ *',
#  'USD 50K+ *',
#  'not_stated',
#  'USD 50K+ *',
#  'USD 51K+ *',
#  'USD 50K+ *',
#  'not_stated',
#  'USD 51K+ *',
#  'USD 50K+ *',
#  'USD 51K+ *',
#  'USD 50K+ *',
#  'not_stated',
#  'USD 50K+ *',
#  'USD 50K+ *',
#  'not_stated',
#  'USD 50K+ *',
#  'USD 50K+ *',
#  'USD 50K+ *',
#  'not_stated',
#  'USD 50K+ *',
#  'USD 50K+ *',
#  'USD 50K+ *',
#  'USD 50K+ *',
#  'USD 51K+ *',
#  'USD 50K+ *',
#  'USD 68K+ *',
#  'USD 50K+ *',
#  'USD 50K+ *',
#  'not_stated',
#  'USD 50K+ *',
#  'USD 50K+ *',
#  'not_stated',
#  'USD 50K+ *',
#  'USD 50K+ *',
#  'not_stated',
#  'not_stated',
#  'USD 51K+ *',
#  'not_stated',
#  'not_stated',
#  'not_stated',
#  'not_stated',
#  'not_stated',
#  'USD 50K+ *',
#  'USD 50K+ *',
#  'USD 50K+ *',
#  'not_stated',
#  'USD 50K+ *']

# %%
#give column header names to each columns
df = pd.DataFrame({'job_title': job_title, 'company': company, 'location': location, 'level':level,
                        'job_type': job_type, 'salary_range': salary, 'required_skills': skills, 'benefits': benefits})

# %%
df
# Out:
#                                             job_title  \
# 0                       Business Intelligence Analyst
# 1                  Lead Business Intelligence Analyst
# 2                                 Junior Data Analyst
# 3          Senior Vice President, Data Analytics & BI
# 4              Staff Analytics Engineer, Central Data
# ..                                                ...
# 95                   Sr. Data Analyst (CMG Analytics)
# 96                        Sr. Data Analyst, Marketing
# 97                   Consumer Research & Data Analyst
# 98                                    Insight Analyst
# 99  Regional Data Analyst, Cross Border (based in ...
#
#                            company                           location  \
# 0   Amica Mutual Insurance Company                 Lincoln, RI, 02865
# 1   Amica Mutual Insurance Company                 Lincoln, RI, 02865
# 2                          Nielsen                             Poland
# 3                  Athletic Greens  Los Angeles, California, United …
# 4                           Airbnb                      United States
# ..                             ...                                ...
# 95                         Coupang                 Seoul, South Korea
# 96                           Clari                        Seattle, WA
# 97                          Mintel                            Chicago
# 98                       So Energy                     United Kingdom
# 99                       Ninja Van                Shah Alam, Malaysia
#
#            level   job_type salary_range  \
# 0      Mid-level  Full Time   not_stated
# 1   Senior-level  Full Time   not_stated
# 2    Entry-level  Full Time   USD 30K+ *
# 3   Senior-level  Full Time   not_stated
# 4   Senior-level  Full Time    USD 180K+
# ..           ...        ...          ...
# 95  Senior-level  Full Time   USD 50K+ *
# 96  Senior-level  Full Time   USD 50K+ *
# 97  Senior-level  Full Time   USD 50K+ *
# 98     Mid-level  Full Time   not_stated
# 99    not_stated  Full Time   USD 50K+ *
#
#                                       required_skills  \
# 0   [Business Intelligence, Data management, Power...
# 1   [Business Intelligence, Data management, KPIs,...
# 2   [Consulting, Data analysis, Econometrics, Exce...
# 3   [Airflow, BigQuery, Business Intelligence, Dat...
# 4   [Airflow, Data analysis, Engineering, ETL, Mac...
# ..                                                ...
# 95  [Airflow, E-commerce, Looker, Power BI, Python...
# 96  [A/B testing, Consulting, Finance, Python, R, ...
# 97  [Data analysis, Data Analytics, Finance, R, Re...
# 98  [Agile, BigQuery, Consulting, Data analysis, D...
# 99  [Business Intelligence, Data Analytics, Excel,...
#
#                                              benefits
# 0   [Competitive pay, Conferences, Fitness / gym, ...
# 1   [Competitive pay, Conferences, Fitness / gym, ...
# 2                                [Career development]
# 3   [401(k) matching, Flex vacation, Gear, Health ...
# 4                  [Career development, Salary bonus]
# ..                                                ...
# 95                                                 []
# 96  [Equity, Fertility benefits, Flex hours, Paren...
# 97                               [Career development]
# 98              [Career development, Competitive pay]
# 99                                                 []
#
# [100 rows x 8 columns]

# %%
# export extracted dataset
df.to_csv('Data-Analyst-Job-Postings.csv')

# %%
# view statistical summary
df.describe()
# Out:
#            job_title     company location         level   job_type  \
# count            100         100      100           100        100
# unique            77          76       74             5          2
# top     Data Analyst  Amazon.com   Remote  Senior-level  Full Time
# freq              12           5        8            69         99
#
#        salary_range                                    required_skills  \
# count           100                                                100
# unique           10                                                 99
# top      USD 50K+ *  [Data Analytics, Data visualization, Industria...
# freq             43                                                  2
#
#        benefits
# count       100
# unique       62
# top          []
# freq         24

# %% [markdown]
# # Define Plot Functions

# %% [markdown]
# ### Function 1

# %%
# define function name and arguments
def barplot (data, title, ylabel):
    # define figure size
    plt.figure(figsize=(17,9))
    # define style to use
    style.use('seaborn')
    # define chart type / plot data of interest
    data.value_counts().plot(kind='bar')
    # set chart title
    plt.title(title, fontsize=25)
    # set y-axis label
    plt.ylabel(ylabel, fontsize=15);

# %% [markdown]
# #### 1. What is the Job Distribution by Title?

# %%
barplot (df['job_title'], 'Job Distribution By Title', 'Number of Jobs')

# %% [markdown]
# Comment
#
#     The roles come captioned in diverse forms as the company sees fit. So be on the look out

# %% [markdown]
# #### 2. What is the Job Posting Distribution By Company?

# %%
barplot(df['company'], 'Job Posting Distribution By Company', 'Number of Jobs')

# %% [markdown]
# Comment
#
#     The highest recruiters are Amazon, Nielsen, Airbnb and WPP. As a newbie, you might want to tailor your learning path to
#     suit what these companies require.

# %% [markdown]
# #### 3. What is the Job Posting Distribution By Location?

# %%
barplot(df['location'], 'Job Posting Distribution By Location', 'Number of Jobs')

# %% [markdown]
# Comment
#
#     Most job posting are remote. That is good news for all who seek to work at their comfort locations

# %% [markdown]
# #### 4. What is the Number of Jobs Posted by Level and Their Respective Percentages of the Total Job Postings?

# %%
barplot(df['level'], 'Job Posting Distribution By Location', 'Number of Jobs')

# %%
# Plot pie chart to display percentage of job distribution by level

# define lables to use
labels = df['level'].value_counts().keys()
# define figure size
plt.figure(figsize=(9,7))
# plot dataset of interest
plt.pie(df['level'].value_counts(), labels=labels, autopct='%1.1f%%', pctdistance=0.7, textprops={'fontsize':13})

# plot circle to change pie chart above to doughnut chart
inner_circle = plt.Circle((0,0), 0.5, color = 'White')
# get current figure i.e. pie chart above
plot_figure = plt.gcf() # gcf means "get current figure"
# get current axes and imprint plot circle on pie chart
plot_figure.gca().add_artist(inner_circle) # gca means "get current axis"
# define chart tile
plt.title('Job Distribution by Level', fontsize=25);

# %% [markdown]
# Comment
#
#     Most job postings are senior-level or Mid level i.e. 69 % and 17 % respectively. Only 3 % turned out to be labelled
#     Entry level, however, it could be that the 9 % whose levels were not stated might be entry levels. So try your luck
#     regardless.
